# %% [markdown]
# # 多个loss

# %%
# !nvidia-smi
# Out:
# Thu Aug 20 23:39:09 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.100      Driver Version: 440.100      CUDA Version: 10.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce RTX 208...  Off  | 00000000:1A:00.0 Off |                  N/A |
# | 54%   70C    P2   230W / 250W |  10996MiB / 11019MiB |     79%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce RTX 208...  Off  | 00000000:1B:00.0 Off |                  N/A |
# | 16%   32C    P8     2W / 250W |      0MiB / 11019MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   2  GeForce RTX 208...  Off  | 00000000:3D:00.0 Off |                  N/A |
# | 52%   70C    P2   242W / 250W |  10996MiB / 11019MiB |     70%      Default |
# +-------------------------------+----------------------+----------------------+
# |   3  GeForce RTX 208...  Off  | 00000000:3E:00.0 Off |                  N/A |
# | 16%   32C    P8    20W / 250W |      0MiB / 11019MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   4  GeForce RTX 208...  Off  | 00000000:88:00.0 Off |                  N/A |
# | 16%   27C    P8     1W / 250W |      0MiB / 11019MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   5  GeForce RTX 208...  Off  | 00000000:89:00.0 Off |                  N/A |
# | 16%   27C    P8     4W / 250W |      0MiB / 11019MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   6  GeForce RTX 208...  Off  | 00000000:B1:00.0 Off |                  N/A |
# | 17%   28C    P8     1W / 250W |      0MiB / 11019MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   7  GeForce RTX 208...  Off  | 00000000:B2:00.0 Off |                  N/A |
# | 16%   27C    P8     3W / 250W |      0MiB / 11019MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |    0     39229      C   ...qibot/miniconda3/envs/tf_2.1/bin/python 10985MiB |
# |    2     37845      C   ...qibot/miniconda3/envs/tf_2.1/bin/python 10985MiB |
# +-----------------------------------------------------------------------------+

# %%
seed = 0
import random
import numpy as np
import tensorflow as tf
import os
random.seed(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
os.environ["CUDA_DEVICE_ORDER"] = 'PCI_BUS_ID'
# os.environ["CUDA_VISIBLE_DEVICES"] = '6'
os.environ["PYTHONHASHSEED"] = str(seed)
os.environ["CUDA_VISIBLE_DEVICES"] = "3"
os.environ['TF_DETERMINISTIC_OPS'] = '1'

# %%
import numpy as np
import pandas as pd
# 选择比较好的模型
import seaborn as sns

import matplotlib.pyplot as plt
from tqdm import tqdm
from scipy.signal import resample
from tensorflow.keras import layers
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
import os
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score

from sklearn.preprocessing import StandardScaler,MinMaxScaler
# %load_ext autoreload
# %autoreload 2


def acc_combo(y, y_pred):
    # 数值ID与行为编码的对应关系
    mapping = {0: 'A_0', 1: 'A_1', 2: 'A_2', 3: 'A_3', 
        4: 'D_4', 5: 'A_5', 6: 'B_1',7: 'B_5', 
        8: 'B_2', 9: 'B_3', 10: 'B_0', 11: 'A_6', 
        12: 'C_1', 13: 'C_3', 14: 'C_0', 15: 'B_6', 
        16: 'C_2', 17: 'C_5', 18: 'C_6'}
    # 将行为ID转为编码
    code_y, code_y_pred = mapping[y], mapping[y_pred]
    if code_y == code_y_pred: #编码完全相同得分1.0
        return 1.0
    elif code_y.split("_")[0] == code_y_pred.split("_")[0]: #编码仅字母部分相同得分1.0/7
        return 1.0/7
    elif code_y.split("_")[1] == code_y_pred.split("_")[1]: #编码仅数字部分相同得分1.0/3
        return 1.0/3
    else:
        return 0.0


sample_num = 60

# %%
# !ls ../../zp
# Out:
# ls: 无法访问'../../zp': 没有那个文件或目录

# %%
root_path  = '../../data/'
train = pd.read_csv(root_path+'sensor_train.csv')
test = pd.read_csv(root_path+'sensor_test.csv')
sub = pd.read_csv(root_path+'提交结果示例.csv')
y = train.groupby('fragment_id')['behavior_id'].min()

# %%
def add_features(df):
    print(df.columns)
    df['acc'] = (df.acc_x ** 2 + df.acc_y ** 2 + df.acc_z ** 2) ** .5
    df['accg'] = (df.acc_xg ** 2 + df.acc_yg ** 2 + df.acc_zg ** 2) ** .5
    df['thetax']=np.arctan(df.acc_xg/
                           np.sqrt(df.acc_yg*df.acc_yg+df.acc_zg*df.acc_zg))*180/np.pi
    df['thetay']=np.arctan(df.acc_yg/
                           np.sqrt(df.acc_xg*df.acc_xg+df.acc_zg*df.acc_zg))*180/np.pi
    df['thetaz']=np.arctan(df.acc_zg/
                           np.sqrt(df.acc_yg*df.acc_yg+df.acc_xg*df.acc_xg))*180/np.pi

    df['xy'] = (df['acc_x'] ** 2 + df['acc_y'] ** 2) ** 0.5
    df['xy_g'] = (df['acc_xg'] ** 2 + df['acc_yg'] ** 2) ** 0.5    
    
    df['g'] = ((df["acc_x"] - df["acc_xg"]) ** 2 + 
                 (df["acc_y"] - df["acc_yg"]) ** 2 + (df["acc_z"] - df["acc_zg"]) ** 2) ** 0.5

    print(df.columns)
    return df

# %%
train=add_features(train)
test=add_features(test)
# Out:
# Index(['fragment_id', 'time_point', 'acc_x', 'acc_y', 'acc_z', 'acc_xg',
#        'acc_yg', 'acc_zg', 'behavior_id'],
#       dtype='object')
# Index(['fragment_id', 'time_point', 'acc_x', 'acc_y', 'acc_z', 'acc_xg',
#        'acc_yg', 'acc_zg', 'behavior_id', 'acc', 'accg', 'thetax', 'thetay',
#        'thetaz', 'xy', 'xy_g', 'g'],
#       dtype='object')
# Index(['fragment_id', 'time_point', 'acc_x', 'acc_y', 'acc_z', 'acc_xg',
#        'acc_yg', 'acc_zg'],
#       dtype='object')
# Index(['fragment_id', 'time_point', 'acc_x', 'acc_y', 'acc_z', 'acc_xg',
#        'acc_yg', 'acc_zg', 'acc', 'accg', 'thetax', 'thetay', 'thetaz', 'xy',
#        'xy_g', 'g'],
#       dtype='object')

# %%
group1 = [x for x in train.columns if x not in ['fragment_id', 'time_point','behavior_id']]
group1
# Out:
# ['acc_x',
#  'acc_y',
#  'acc_z',
#  'acc_xg',
#  'acc_yg',
#  'acc_zg',
#  'acc',
#  'accg',
#  'thetax',
#  'thetay',
#  'thetaz',
#  'xy',
#  'xy_g',
#  'g']

# %%
FEATURE_NUM=14

# %%
x = np.zeros((7292, sample_num, FEATURE_NUM, 1))
t = np.zeros((7500, sample_num, FEATURE_NUM, 1))

from scipy.fftpack import fft
from scipy.signal import resample
def get_fft_values(y_values, N, f_s):
    f_values = np.linspace(0.0, f_s/2.0, N//2)
    fft_values_ = fft(y_values)
    plt.plot(fft_values_)
    plt.show()
    print(fft_values_.shape)
    fft_values = 2.0/N * np.abs(fft_values_[0:N//2])
    print(fft_values.shape)
    return f_values, fft_values

# tmp = train[train.fragment_id == 0][:sample_num]

# get_fft_values(tmp["acc"].values,60,5)

# %%
test['fragment_id'] += 10000
data = pd.concat([train, test], sort=False)
ss_tool = StandardScaler()
data[group1] = ss_tool.fit_transform(data[group1])
train = data[data["behavior_id"].isna()==False].reset_index(drop=True)
test = data[data["behavior_id"].isna()==True].reset_index(drop=True)
test['fragment_id'] -= 10000                         
train = train[['fragment_id', 'time_point', 'behavior_id']+group1]
test = test[['fragment_id', 'time_point']+group1]
print(train.columns)

for i in tqdm(range(7292)):
    tmp = train[train.fragment_id == i][:sample_num]
    x[i,:,:,0] = fft(resample(tmp.drop(['fragment_id', 'time_point', 'behavior_id'],
                                    axis=1)[group1], sample_num, np.array(tmp.time_point))[0]).reshape(sample_num,FEATURE_NUM)
for i in tqdm(range(7500)):
    tmp = test[test.fragment_id == i][:sample_num]
    t[i,:,:,0] = fft(resample(tmp.drop(['fragment_id', 'time_point'],
                                    axis=1)[group1], sample_num, np.array(tmp.time_point))[0]).reshape(sample_num,FEATURE_NUM)
# Out:
#   0%|          | 0/7292 [00:00<?, ?it/s]/home/zhangqibot/miniconda3/envs/tf_2.1/lib/python3.7/site-packages/ipykernel_launcher.py:15: ComplexWarning: Casting complex values to real discards the imaginary part
#   from ipykernel import kernelapp as app
#   1%|          | 50/7292 [00:00<00:14, 491.30it/s]
# Index(['fragment_id', 'time_point', 'behavior_id', 'acc_x', 'acc_y', 'acc_z',
#        'acc_xg', 'acc_yg', 'acc_zg', 'acc', 'accg', 'thetax', 'thetay',
#        'thetaz', 'xy', 'xy_g', 'g'],
#       dtype='object')
# 100%|██████████| 7292/7292 [00:15<00:00, 470.82it/s]
#   0%|          | 0/7500 [00:00<?, ?it/s]/home/zhangqibot/miniconda3/envs/tf_2.1/lib/python3.7/site-packages/ipykernel_launcher.py:19: ComplexWarning: Casting complex values to real discards the imaginary part
# 100%|██████████| 7500/7500 [00:15<00:00, 490.04it/s]

# %%
import tensorflow as tf
import os
from tensorflow_addons.optimizers import AdamW

import numpy as np

from tensorflow.python.keras import backend as K
from tensorflow.python.util.tf_export import keras_export
from tensorflow.keras.callbacks import Callback


def lr_schedule(epoch):
    """Learning Rate Schedule
    Learning rate is scheduled to be reduced after 20, 30 epochs.
    Called automatically every epoch as part of callbacks during training.
    # Arguments
        epoch (int): The number of epochs
    # Returns
        lr (float32): learning rate
    """
    lr = 5e-4
    if epoch >= 150:
        lr *= 1e-1
    elif epoch >= 100:
        lr *= 1e-1
    elif epoch >= 50:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr


def wd_schedule(epoch):
    """Weight Decay Schedule
    Weight decay is scheduled to be reduced after 20, 30 epochs.
    Called automatically every epoch as part of callbacks during training.
    # Arguments
        epoch (int): The number of epochs
    # Returns
        wd (float32): weight decay
    """
    wd = 2e-5

    if epoch >= 100:
        wd *= 2e-2
    elif epoch >= 50:
        wd *= 1e-1
    print('Weight decay: ', wd)
    return wd


# just copy the implement of LearningRateScheduler, and then change the lr with weight_decay
@keras_export('keras.callbacks.WeightDecayScheduler')
class WeightDecayScheduler(Callback):
    """Weight Decay Scheduler.

    Arguments:
        schedule: a function that takes an epoch index as input
            (integer, indexed from 0) and returns a new
            weight decay as output (float).
        verbose: int. 0: quiet, 1: update messages.

    ```python
    # This function keeps the weight decay at 0.001 for the first ten epochs
    # and decreases it exponentially after that.
    def scheduler(epoch):
      if epoch < 10:
        return 0.001
      else:
        return 0.001 * tf.math.exp(0.1 * (10 - epoch))

    callback = WeightDecayScheduler(scheduler)
    model.fit(data, labels, epochs=100, callbacks=[callback],
              validation_data=(val_data, val_labels))
    ```
    """

    def __init__(self, schedule, verbose=0):
        super(WeightDecayScheduler, self).__init__()
        self.schedule = schedule
        self.verbose = verbose

    def on_epoch_begin(self, epoch, logs=None):
        if not hasattr(self.model.optimizer, 'weight_decay'):
            raise ValueError('Optimizer must have a "weight_decay" attribute.')
        try:  # new API
            weight_decay = float(K.get_value(self.model.optimizer.weight_decay))
            weight_decay = self.schedule(epoch, weight_decay)
        except TypeError:  # Support for old API for backward compatibility
            weight_decay = self.schedule(epoch)
        if not isinstance(weight_decay, (float, np.float32, np.float64)):
            raise ValueError('The output of the "schedule" function '
                             'should be float.')
        K.set_value(self.model.optimizer.weight_decay, weight_decay)
        if self.verbose > 0:
            print('\nEpoch %05d: WeightDecayScheduler reducing weight '
                  'decay to %s.' % (epoch + 1, weight_decay))

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        logs['weight_decay'] = K.get_value(self.model.optimizer.weight_decay)


# if __name__ == '__main__':
#     os.environ["CUDA_VISIBLE_DEVICES"] = '1'

#     gpus = tf.config.experimental.list_physical_devices(device_type='GPU')
#     for gpu in gpus:
#         tf.config.experimental.set_memory_growth(gpu, enable=True)
#     print(gpus)
#     cifar10 = tf.keras.datasets.cifar10

#     (x_train, y_train), (x_test, y_test) = cifar10.load_data()
#     x_train, x_test = x_train / 255.0, x_test / 255.0

#     model = tf.keras.models.Sequential([
#         tf.keras.layers.Conv2D(16, (3, 3), padding='same', activation='relu', input_shape=(32, 32, 3)),
#         tf.keras.layers.AveragePooling2D(),
#         tf.keras.layers.Conv2D(32, (3, 3), padding='same', activation='relu'),
#         tf.keras.layers.AveragePooling2D(),
#         tf.keras.layers.Flatten(),
#         tf.keras.layers.Dense(10, activation='softmax')
#     ])

#     optimizer = AdamW(learning_rate=lr_schedule(0), weight_decay=wd_schedule(0))
#     # optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)

#     tb_callback = tf.keras.callbacks.TensorBoard(os.path.join('logs', 'adamw'),
#                                                  profile_batch=0)
#     lr_callback = tf.keras.callbacks.LearningRateScheduler(lr_schedule)
#     wd_callback = WeightDecayScheduler(wd_schedule)

#     model.compile(optimizer=optimizer,
#                   loss='sparse_categorical_crossentropy',
#                   metrics=['accuracy'])

#     model.fit(x_train, y_train, epochs=40, validation_split=0.1,
#               callbacks=[tb_callback, lr_callback, wd_callback])

#     model.evaluate(x_test, y_test, verbose=2)

# %%
def ConvBNRelu(X,filters,kernal_size=(3,3)):
    X = Conv2D(filters=filters,
               kernel_size=kernal_size,
#                activation='relu',
               use_bias=False,
               padding='same')(X)
    X = BatchNormalization()(X)
    X = Activation('relu')(X)
    return X


def ConvRelu(X,filters,kernal_size=(3,3)):
    X = Conv2D(filters=filters,
               kernel_size=kernal_size,
               activation='relu',
               use_bias=False,
               padding='same')(X)
    return X


def squeeze_excitation_layer(x, out_dim,ratio=8):
    '''
    SE module performs inter-channel weighting.
    '''
    squeeze = GlobalAveragePooling2D()(x)

    excitation = Dense(units=out_dim // ratio)(squeeze)
    excitation = Activation('relu')(excitation)
    excitation = Dense(units=out_dim)(excitation)
    excitation = Activation('sigmoid')(excitation)
    excitation = Reshape((1,1,out_dim))(excitation)
    scale = multiply([x,excitation])
    return scale

# def SE_Residual(X):
#     A = 
#     X = squeeze_excitation_layer(X,128)
#     X =  Add()([X,A])
    

def lenet5(input):
    A = ConvBNRelu(input,64,kernal_size=(3,3))
#     B = ConvBNRelu(input,16,kernal_size=(5,1))
#     C = ConvBNRelu(input,16,kernal_size=(7,1))
#     ABC = layers.Concatenate()([A,B,C])
    X = ConvBNRelu(A,128)
#     X = squeeze_excitation_layer(X,128)
    X = Dropout(0.2)(X)

    X = AveragePooling2D()(X)
    
    X = ConvBNRelu(X,256)
    X = Dropout(0.3)(X)
#     X = squeeze_excitation_layer(X,256)
    X = ConvBNRelu(X,512)   
    X = Dropout(0.5)(X)
#     X = squeeze_excitation_layer(X,512)
#     X = GlobalMaxPooling2D()(X)
    X = GlobalAveragePooling2D()(X)
    
#     X = BatchNormalization()(X)
    return X
import tensorflow as tf
def Net(sample_num):
    input1 = Input(shape=(sample_num, FEATURE_NUM, 1))
    part = tf.split(input1,axis=2, num_or_size_splits = [6, 2, 6])
#     res = tf.split(c, axis = 3, num_or_size_splits = [2, 2, 4])
    
    
    X1 = Concatenate(axis=-2)([part[0],part[1]])
    X1 = lenet5(X1)
    X1 = BatchNormalization()(X1)
    X1 = Dense(128, activation='relu')(X1)
    X1 = BatchNormalization()(X1)
    X1 = Dropout(0.2)(X1)

    X2 = Concatenate(axis=-2)([part[0],part[2]])
    X2 = lenet5(X2)    
    X2 = BatchNormalization()(X2)
#     X = Dense(512, activation='relu')(X)
#     X = BatchNormalization()(X)
    X2 = Dense(128, activation='relu')(X2)
    X2 = BatchNormalization()(X2)
    X2 = Dropout(0.2)(X2)
    
    X = Concatenate(axis=-1)([X1,X2])
    
#     X = Dense(256)(X)    
    
    output1 = Dense(4, activation='softmax', name='4class')(X)   # 大类-字母
#     output2 = Dense(128)(X)
#     output2 = Dense(64)(X)
    X = Dense(64)(X)
    output2 = Dense(7, activation='softmax', name='7class')(X)   # 大类-数字
#     X = Dense(32)(X)
#     X = Concatenate(axis=-1)([X,output1,output2])
    X = Dense(64)(X)
    output3 = Dense(19, activation='softmax',name='19class')(X) #小类
    
    
    return Model([input1], [output1,output2,output3])

model = Net(30)
model.summary()
# Out:
# Model: "model_10"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_11 (InputLayer)           [(None, 30, 14, 1)]  0
# __________________________________________________________________________________________________
# tf_op_layer_split_10 (TensorFlo [(None, 30, 6, 1), ( 0           input_11[0][0]
# __________________________________________________________________________________________________
# concatenate_30 (Concatenate)    (None, 30, 8, 1)     0           tf_op_layer_split_10[0][0]
#                                                                  tf_op_layer_split_10[0][1]
# __________________________________________________________________________________________________
# concatenate_31 (Concatenate)    (None, 30, 12, 1)    0           tf_op_layer_split_10[0][0]
#                                                                  tf_op_layer_split_10[0][2]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 30, 8, 64)    576         concatenate_30[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 30, 12, 64)   576         concatenate_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_120 (BatchN (None, 30, 8, 64)    256         conv2d_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_126 (BatchN (None, 30, 12, 64)   256         conv2d_84[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 30, 8, 64)    0           batch_normalization_120[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 30, 12, 64)   0           batch_normalization_126[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 30, 8, 128)   73728       activation_80[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 30, 12, 128)  73728       activation_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_121 (BatchN (None, 30, 8, 128)   512         conv2d_81[0][0]
# __________________________________________________________________________________________________
# batch_normalization_127 (BatchN (None, 30, 12, 128)  512         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 30, 8, 128)   0           batch_normalization_121[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 30, 12, 128)  0           batch_normalization_127[0][0]
# __________________________________________________________________________________________________
# dropout_80 (Dropout)            (None, 30, 8, 128)   0           activation_81[0][0]
# __________________________________________________________________________________________________
# dropout_84 (Dropout)            (None, 30, 12, 128)  0           activation_85[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_20 (AveragePo (None, 15, 4, 128)   0           dropout_80[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_21 (AveragePo (None, 15, 6, 128)   0           dropout_84[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 15, 4, 256)   294912      average_pooling2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 15, 6, 256)   294912      average_pooling2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_122 (BatchN (None, 15, 4, 256)   1024        conv2d_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_128 (BatchN (None, 15, 6, 256)   1024        conv2d_86[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 15, 4, 256)   0           batch_normalization_122[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 15, 6, 256)   0           batch_normalization_128[0][0]
# __________________________________________________________________________________________________
# dropout_81 (Dropout)            (None, 15, 4, 256)   0           activation_82[0][0]
# __________________________________________________________________________________________________
# dropout_85 (Dropout)            (None, 15, 6, 256)   0           activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 15, 4, 512)   1179648     dropout_81[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 15, 6, 512)   1179648     dropout_85[0][0]
# __________________________________________________________________________________________________
# batch_normalization_123 (BatchN (None, 15, 4, 512)   2048        conv2d_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_129 (BatchN (None, 15, 6, 512)   2048        conv2d_87[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 15, 4, 512)   0           batch_normalization_123[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 15, 6, 512)   0           batch_normalization_129[0][0]
# __________________________________________________________________________________________________
# dropout_82 (Dropout)            (None, 15, 4, 512)   0           activation_83[0][0]
# __________________________________________________________________________________________________
# dropout_86 (Dropout)            (None, 15, 6, 512)   0           activation_87[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_20 (Gl (None, 512)          0           dropout_82[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_21 (Gl (None, 512)          0           dropout_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_124 (BatchN (None, 512)          2048        global_average_pooling2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_130 (BatchN (None, 512)          2048        global_average_pooling2d_21[0][0]
# __________________________________________________________________________________________________
# dense_40 (Dense)                (None, 128)          65664       batch_normalization_124[0][0]
# __________________________________________________________________________________________________
# dense_41 (Dense)                (None, 128)          65664       batch_normalization_130[0][0]
# __________________________________________________________________________________________________
# batch_normalization_125 (BatchN (None, 128)          512         dense_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_131 (BatchN (None, 128)          512         dense_41[0][0]
# __________________________________________________________________________________________________
# dropout_83 (Dropout)            (None, 128)          0           batch_normalization_125[0][0]
# __________________________________________________________________________________________________
# dropout_87 (Dropout)            (None, 128)          0           batch_normalization_131[0][0]
# __________________________________________________________________________________________________
# concatenate_32 (Concatenate)    (None, 256)          0           dropout_83[0][0]
#                                                                  dropout_87[0][0]
# __________________________________________________________________________________________________
# dense_42 (Dense)                (None, 64)           16448       concatenate_32[0][0]
# __________________________________________________________________________________________________
# dense_43 (Dense)                (None, 64)           4160        dense_42[0][0]
# __________________________________________________________________________________________________
# 4class (Dense)                  (None, 4)            1028        concatenate_32[0][0]
# __________________________________________________________________________________________________
# 7class (Dense)                  (None, 7)            455         dense_42[0][0]
# __________________________________________________________________________________________________
# 19class (Dense)                 (None, 19)           1235        dense_43[0][0]
# ==================================================================================================
# Total params: 3,265,182
# Trainable params: 3,258,782
# Non-trainable params: 6,400
# __________________________________________________________________________________________________

# %%
# 两个输出    
mapping = {0: 'A_0', 1: 'A_1', 2: 'A_2', 3: 'A_3', 
4: 'D_4', 5: 'A_5', 6: 'B_1',7: 'B_5', 
8: 'B_2', 9: 'B_3', 10: 'B_0', 11: 'A_6', 
12: 'C_1', 13: 'C_3', 14: 'C_0', 15: 'B_6', 
16: 'C_2', 17: 'C_5', 18: 'C_6'}
# 每一个大类输出 4
new_mapping = {'A':0,'B':1,'C':2,'D':3}

from sklearn.utils.class_weight import compute_class_weight
# y_train_weight = compute_sample_weight("balanced", train['behavior_id'])
classweights1=compute_class_weight("balanced",['A','B','C','D'],\
                                   pd.read_csv(root_path+'sensor_train.csv')['behavior_id'].apply(lambda x:mapping[x][0]))
classweights1=pd.DataFrame(classweights1)[0].to_dict()



classweights2=compute_class_weight("balanced",list(range(7)),\
                                   pd.read_csv(root_path+'sensor_train.csv')['behavior_id'].apply(lambda x:int(mapping[x][2])))
classweights2=pd.DataFrame(classweights2)[0].to_dict()



from sklearn.utils.class_weight import compute_class_weight
# y_train_weight = compute_sample_weight("balanced", train['behavior_id'])
classweights3=compute_class_weight("balanced",np.array(range(19)), pd.read_csv(root_path+'sensor_train.csv')['behavior_id'])
classweights3=pd.DataFrame(classweights3)[0].to_dict()
classweights1,classweights2,classweights3
# Out:
# ({0: 0.7453285438934641,
#   1: 0.7866762590992484,
#   2: 0.8681079382183908,
#   3: 4.251549256356949},
#  {0: 1.757195321956318,
#   1: 0.4815479398086302,
#   2: 0.9616022823865589,
#   3: 1.1412232173040497,
#   4: 2.4294567179182565,
#   5: 1.2367567913331454,
#   6: 0.8210787010495146},
#  {0: 1.6146639588513296,
#   1: 0.5658077637797579,
#   2: 0.9428223116223914,
#   3: 1.1544614165363905,
#   4: 0.895063001338305,
#   5: 1.120093850476494,
#   6: 0.5129293816036677,
#   7: 1.6147804233607677,
#   8: 1.1629774436090226,
#   9: 1.3287818013695207,
#   10: 1.639495846903968,
#   11: 0.8571276001942526,
#   12: 0.5209381219191084,
#   13: 1.3164363042146117,
#   14: 3.1705588145409553,
#   15: 0.8020390423628304,
#   16: 1.108447580802777,
#   17: 1.4649467209444893,
#   18: 1.12076674790857})

# %%
# [:,:,:,[1]]
train = x
test = t

fold_num=5
kfold = StratifiedKFold(fold_num,random_state=42,shuffle=True)
proba_t = np.zeros((7500, 19+7+4))
proba_oof = np.zeros((7292, 19+7+4))

oof_score = []
oof_comm = []
history = []

from tensorflow.keras.losses import categorical_crossentropy
def custom_loss(y_true, y_pred):
    return categorical_crossentropy(y_true, y_pred, label_smoothing=0.05)

# 两个输出    
mapping = {0: 'A_0', 1: 'A_1', 2: 'A_2', 3: 'A_3', 
4: 'D_4', 5: 'A_5', 6: 'B_1',7: 'B_5', 
8: 'B_2', 9: 'B_3', 10: 'B_0', 11: 'A_6', 
12: 'C_1', 13: 'C_3', 14: 'C_0', 15: 'B_6', 
16: 'C_2', 17: 'C_5', 18: 'C_6'}
# 每一个大类输出 4
new_mapping = {'A':0,'B':1,'C':2,'D':3}
y_1 = to_categorical([new_mapping[mapping[x][0]] for x in y], num_classes=4)
# 每一个大类输出 
new_mapping = {'A':0,'B':1,'C':2,'D':3}
y_2 = to_categorical([mapping[x][2] for x in y], num_classes=7)
# 每一个小类的输出 19
y_3 = to_categorical(y, num_classes=19)

seeds = [42,39,17]
for seed in seeds:
    kfold = StratifiedKFold(fold_num,random_state=seed,shuffle=True)
    for fold, (xx, yy) in enumerate(kfold.split(train, y)):

        mapping = {0: 'A_0', 1: 'A_1', 2: 'A_2', 3: 'A_3', 
        4: 'D_4', 5: 'A_5', 6: 'B_1',7: 'B_5', 
        8: 'B_2', 9: 'B_3', 10: 'B_0', 11: 'A_6', 
        12: 'C_1', 13: 'C_3', 14: 'C_0', 15: 'B_6', 
        16: 'C_2', 17: 'C_5', 18: 'C_6'}
        new_mapping = {'A':0,'B':1,'C':2,'D':3}

        model = Net(60)
        model.summary()
        optimizer = AdamW(learning_rate=lr_schedule(0), weight_decay=wd_schedule(0))
        lr_callback = tf.keras.callbacks.LearningRateScheduler(lr_schedule)
        wd_callback = WeightDecayScheduler(wd_schedule)
        model.compile(loss=[custom_loss,custom_loss,custom_loss],loss_weights=[3,7,21],
                      optimizer=optimizer,
                      metrics=["acc"])#'',localscore
        plateau = ReduceLROnPlateau(monitor="19class_acc",
                                    verbose=1,
                                    mode='max',
                                    factor=0.5,
                                    patience=18)
        early_stopping = EarlyStopping(monitor="val_19class_acc",
                                       verbose=1,
                                       mode='max',
                                       patience=60)

        checkpoint = ModelCheckpoint(f'spetron{fold}.h5',
                                     monitor="val_19class_acc",
                                     verbose=0,
                                     mode='max',
                                     save_best_only=True)

        train_res = model.fit(train[xx], [y_1[xx], y_2[xx], y_3[xx]],
                  epochs=400,
                  batch_size=32,
                  verbose=1,
                  shuffle=True,
                  validation_data=(train[yy], [y_1[yy], y_2[yy],y_3[yy]]),
                  callbacks=[lr_callback, wd_callback, checkpoint],
                             class_weight=[classweights1,classweights2,classweights3])
        history.append(train_res)


    #     # 找到对应最高的 val_acc 对应的epoch，预测left+1+right次
    #     left=2
    #     right=2
    #     max_acc_index=history[fold].history['val_acc'].index(np.max(history[fold].history['val_acc']))+1

    #     save_filelist=os.listdir(save_dir)
    #     save_filelist.sort()
    #     select_blending=save_filelist[max_acc_index-left : max_acc_index+right]
    #     print(select_blending)
    #     for file in select_blending:
    #         model.load_weights(save_dir+'/'+file)
    #         proba_t += model.predict(t, verbose=0, batch_size=1024) / (fold_num*len(select_blending))
    #         proba_oof[yy] = model.predict(train[yy],verbose=0,batch_size=1024) / len(select_blending)

        model.load_weights(f'spetron{fold}.h5')
        proba_t[:,:19] += model.predict(test, verbose=0, batch_size=1024)[2] / fold_num /len(seeds)
        proba_oof[yy,:19] += model.predict(train[yy],verbose=0,batch_size=1024) [2]/len(seeds)

        proba_t[:,19:23] += model.predict(test, verbose=0, batch_size=1024)[0] / fold_num /len(seeds)
        proba_oof[yy,19:23] += model.predict(train[yy],verbose=0,batch_size=1024) [0]/len(seeds)

        proba_t[:,23:] += model.predict(test, verbose=0, batch_size=1024)[1] / fold_num /len(seeds)
        proba_oof[yy,23:] += model.predict(train[yy],verbose=0,batch_size=1024) [1]/len(seeds)


        oof_y = np.argmax(proba_oof[yy,:19], axis=1)
        acc = round(accuracy_score(y[yy], oof_y),3)
        print(acc)
        oof_score.append(acc)
        scores = sum(acc_combo(y_true, y_pred) for y_true, y_pred in zip(y[yy], oof_y)) / oof_y.shape[0]
        oof_comm.append(scores)   
        print(round(scores, 5))
# Out:
# Model: "model_11"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_12 (InputLayer)           [(None, 60, 14, 1)]  0
# __________________________________________________________________________________________________
# tf_op_layer_split_11 (TensorFlo [(None, 60, 6, 1), ( 0           input_12[0][0]
# __________________________________________________________________________________________________
# concatenate_33 (Concatenate)    (None, 60, 8, 1)     0           tf_op_layer_split_11[0][0]
#                                                                  tf_op_layer_split_11[0][1]
# __________________________________________________________________________________________________
# concatenate_34 (Concatenate)    (None, 60, 12, 1)    0           tf_op_layer_split_11[0][0]
#                                                                  tf_op_layer_split_11[0][2]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 60, 8, 64)    576         concatenate_33[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 60, 12, 64)   576         concatenate_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_132 (BatchN (None, 60, 8, 64)    256         conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_138 (BatchN (None, 60, 12, 64)   256         conv2d_92[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 60, 8, 64)    0           batch_normalization_132[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 60, 12, 64)   0           batch_normalization_138[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 60, 8, 128)   73728       activation_88[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 60, 12, 128)  73728       activation_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_133 (BatchN (None, 60, 8, 128)   512         conv2d_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_139 (BatchN (None, 60, 12, 128)  512         conv2d_93[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 60, 8, 128)   0           batch_normalization_133[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 60, 12, 128)  0           batch_normalization_139[0][0]
# __________________________________________________________________________________________________
# dropout_88 (Dropout)            (None, 60, 8, 128)   0           activation_89[0][0]
# __________________________________________________________________________________________________
# dropout_92 (Dropout)            (None, 60, 12, 128)  0           activation_93[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_22 (AveragePo (None, 30, 4, 128)   0           dropout_88[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_23 (AveragePo (None, 30, 6, 128)   0           dropout_92[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 30, 4, 256)   294912      average_pooling2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 30, 6, 256)   294912      average_pooling2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_134 (BatchN (None, 30, 4, 256)   1024        conv2d_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_140 (BatchN (None, 30, 6, 256)   1024        conv2d_94[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 30, 4, 256)   0           batch_normalization_134[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 30, 6, 256)   0           batch_normalization_140[0][0]
# __________________________________________________________________________________________________
# dropout_89 (Dropout)            (None, 30, 4, 256)   0           activation_90[0][0]
# __________________________________________________________________________________________________
# dropout_93 (Dropout)            (None, 30, 6, 256)   0           activation_94[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 30, 4, 512)   1179648     dropout_89[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 30, 6, 512)   1179648     dropout_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_135 (BatchN (None, 30, 4, 512)   2048        conv2d_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_141 (BatchN (None, 30, 6, 512)   2048        conv2d_95[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 30, 4, 512)   0           batch_normalization_135[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 30, 6, 512)   0           batch_normalization_141[0][0]
# __________________________________________________________________________________________________
# dropout_90 (Dropout)            (None, 30, 4, 512)   0           activation_91[0][0]
# __________________________________________________________________________________________________
# dropout_94 (Dropout)            (None, 30, 6, 512)   0           activation_95[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_22 (Gl (None, 512)          0           dropout_90[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_23 (Gl (None, 512)          0           dropout_94[0][0]
# __________________________________________________________________________________________________
# batch_normalization_136 (BatchN (None, 512)          2048        global_average_pooling2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_142 (BatchN (None, 512)          2048        global_average_pooling2d_23[0][0]
# __________________________________________________________________________________________________
# dense_44 (Dense)                (None, 128)          65664       batch_normalization_136[0][0]
# __________________________________________________________________________________________________
# dense_45 (Dense)                (None, 128)          65664       batch_normalization_142[0][0]
# __________________________________________________________________________________________________
# batch_normalization_137 (BatchN (None, 128)          512         dense_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_143 (BatchN (None, 128)          512         dense_45[0][0]
# __________________________________________________________________________________________________
# dropout_91 (Dropout)            (None, 128)          0           batch_normalization_137[0][0]
# __________________________________________________________________________________________________
# dropout_95 (Dropout)            (None, 128)          0           batch_normalization_143[0][0]
# __________________________________________________________________________________________________
# concatenate_35 (Concatenate)    (None, 256)          0           dropout_91[0][0]
#                                                                  dropout_95[0][0]
# __________________________________________________________________________________________________
# dense_46 (Dense)                (None, 64)           16448       concatenate_35[0][0]
# __________________________________________________________________________________________________
# dense_47 (Dense)                (None, 64)           4160        dense_46[0][0]
# __________________________________________________________________________________________________
# 4class (Dense)                  (None, 4)            1028        concatenate_35[0][0]
# __________________________________________________________________________________________________
# 7class (Dense)                  (None, 7)            455         dense_46[0][0]
# __________________________________________________________________________________________________
# 19class (Dense)                 (None, 19)           1235        dense_47[0][0]
# ==================================================================================================
# Total params: 3,265,182
# Trainable params: 3,258,782
# Non-trainable params: 6,400
# __________________________________________________________________________________________________
# Learning rate:  0.0005
# Weight decay:  2e-05
# Train on 5833 samples, validate on 1459 samples
# Learning rate:  0.0005
# Weight decay:  2e-05
# Epoch 1/400
# 5833/5833 [==============================] - 9s 2ms/sample - loss: 62.8574 - 4class_loss: 1.1238 - 7class_loss: 1.6389 - 19class_loss: 2.2873 - 4class_acc: 0.5117 - 7class_acc: 0.3758 - 19class_acc: 0.2808 - val_loss: 64.9041 - val_4class_loss: 1.1564 - val_7class_loss: 1.6245 - val_19class_loss: 2.3899 - val_4class_acc: 0.4901 - val_7class_acc: 0.3112 - val_19class_acc: 0.2296
# Learning rate:  0.0005
# Weight decay:  2e-05
# Epoch 2/400
# 5833/5833 [==============================] - 5s 860us/sample - loss: 52.3951 - 4class_loss: 0.9436 - 7class_loss: 1.3913 - 19class_loss: 1.8957 - 4class_acc: 0.5954 - 7class_acc: 0.4571 - 19class_acc: 0.3730 - val_loss: 49.2208 - val_4class_loss: 0.9191 - val_7class_loss: 1.2701 - val_19class_loss: 1.7918 - val_4class_acc: 0.6621 - val_7class_acc: 0.5744 - val_19class_acc: 0.4428
# Learning rate:  0.0005
# Weight decay:  2e-05
# Epoch
# Learning rate:  0.0005
# Weight decay:  2e-05
# Epoch 30/400
# 5834/5834 [==============================] - 5s 865us/sample - loss: 25.5258 - 4class_loss: 0.4894 - 7class_loss: 0.6851 - 19class_loss: 0.9156 - 4class_acc: 0.8450 - 7class_acc: 0.7873 - 19class_acc: 0.7549 - val_loss: 30.3541 - val_4class_loss: 0.5222 - val_7class_loss: 0.8278 - val_19class_loss: 1.0897 - val_4class_acc: 0.8368 - val_7class_acc: 0.7689 - val_19class_acc: 0.7318
# Learning rate:  0.0005
# Weight decay:  2e-05
# Epoch 31/400
# 5834/5834 [==============================] - 5s 855us/sample - loss: 25.0314 - 4class_loss: 0.4854 - 7class_loss: 0.6758 - 19class_loss: 0.8980 - 4class_acc: 0.8408 - 7class_acc: 0.7938 - 19class_acc: 0.7617 - val_loss: 32.2638 - val_4class_loss: 0.5565 - val_7class_loss: 0.8466 - val_19class_loss: 1.1676 - val_4class_acc: 0.8285 - val_7class_acc: 0.7277 - val_19class_acc: 0.6626
# Learning rate:  0.0005
# Weight decay:  2e-05
# Epoch 32/400
# 5834/5834 [==============================] - 5s 852us/sample - loss: 25.3255 - 4class_loss: 0.4954 - 7class_loss: 0.6804 - 19class_loss: 0.9107 - 4class_acc: 0.8368 - 7class_acc: 0.7931 - 19class_acc: 0.7590 - val_loss: 35.4621 - val_4class_loss: 0.7711 - val_7class_loss: 0.9145 - val_19class_loss: 1.2659 - val_4class_acc: 0.7401 - val_7class_acc: 0.7209 - val_19class_acc: 0.6461
# Learning rate:  0.0005
# Weight decay:  2e-05
# Epoch 33/400
# 5834/5834 [==============================] - 5s 843us/sample - loss: 24.7476 - 4class_loss: 0.4854 - 7class_loss: 0.6732 - 19class_loss: 0.8864 - 4class_acc: 0.8425 - 7class_acc: 0.7972 - 19class_acc: 0.7652 - val_loss: 29.7010 - val_4class_loss: 0.5127 - val_7class_loss: 0.8084 - val_19class_loss: 1.0657 - val_4class_acc: 0.8340 - val_7class_acc: 0.7353 - val_19class_acc: 0.6975
# Learning rate:  0.0005
# Weight decay:  2e-05
# Epoch 34/400
# 5834/5834 [==============================] - 5s 897us/sample - loss: 24.8021 - 4class_loss: 0.4782 - 7class_loss: 0.6705 - 19class_loss: 0.8883 - 4class_acc: 0.8445 - 7class_acc: 0.7953 - 19class_acc: 0.7665 - val_loss: 34.9335 - val_4class_loss: 0.5542 - val_7class_loss: 0.9904 - val_19class_loss: 1.2455 - val_4class_acc: 0.8196 - val_7class_acc: 0.6406 - val_19class_acc: 0.6241
# Learning rate:  0.0005
# Weight decay:  2e-05
# Epoch 35/400
# 5834/5834 [==============================] - 5s 875us/sample - loss: 24.0343 - 4class_loss: 0.4714 - 7class_loss: 0.6576 - 19class_loss: 0.8570 - 4class_acc: 0.8478 - 7class_acc: 0.8053 - 19class_acc: 0.7818 - val_loss: 28.8281 - val_4class_loss: 0.5194 - val_7class_loss: 0.7429 - val_19class_loss: 1.0450 - val_4class_acc: 0.8107 - val_7class_acc: 0.7723 - val_19class_acc: 0.7147
# Learning rate:  0.0005
# Weight decay:  2e-05
# Epoch 36/400
# 3488/5834 [================>.............] - ETA: 1s - loss: 23.7431 - 4class_loss: 0.4782 - 7class_loss: 0.6424 - 19class_loss: 0.8482 - 4class_acc: 0.8481 - 7class_acc: 0.8062 - 19class_acc: 0.7884

# %%
import matplotlib.pyplot as plt   
plt.figure(figsize=(12,20))
start=5
for i in range(5):
    min_acc_index=history[i].history['val_19class_loss'].index(np.min(history[i].history['val_19class_loss']))
    print(str(i)+' val_19class_loss'+str(history[i].history['val_19class_loss'][min_acc_index])+'val_19class_acc'+str(history[i].history['val_19class_acc'][min_acc_index]))
for i in range(5):
    min_acc_index=history[i].history['val_19class_loss'].index(np.min(history[i].history['val_19class_loss']))
    length=len(history[i].history['19class_loss'][start:])
    plt.subplot(5,1,i+1)
    plt.plot(range(length),history[i].history['19class_loss'][start:],label='19class_loss')
    plt.plot(range(length),history[i].history['19class_acc'][start:],label='19class_acc')
    plt.plot(range(length),history[i].history['val_19class_loss'][start:],label='val_19class_loss')
    plt.plot(range(length),history[i].history['val_19class_acc'][start:],label='val_19class_acc')
    plt.title(str(i)+' val_19class_loss'+str(history[i].history['val_19class_loss'][min_acc_index])+'val_19class_acc'+str(history[i].history['val_19class_acc'][min_acc_index]))
    plt.legend(loc='best')
    
print(oof_score,np.mean(oof_score))
print(oof_comm,np.mean(oof_comm))
'''baseline
0 val_19class_loss0.90247583val_19class_acc0.81768334
1 val_19class_loss0.9712743val_19class_acc0.7930089
2 val_19class_loss0.9203671val_19class_acc0.8072702
3 val_19class_loss0.9375971val_19class_acc0.8052126
4 val_19class_loss0.88216704val_19class_acc0.8203018
[0.822, 0.796, 0.811, 0.809, 0.835] 0.8146000000000001
[0.8470903097359558, 0.8268873004993619, 0.8386243386243368, 0.8387223202038004, 0.8584166176758752] 0.841948177347866
'''
# Out:
# 0 val_19class_loss0.893312val_19class_acc0.82385194
# 1 val_19class_loss0.9150883val_19class_acc0.7875257
# 2 val_19class_loss0.8823624val_19class_acc0.7956104
# 3 val_19class_loss0.89798826val_19class_acc0.8100137
# 4 val_19class_loss0.86693716val_19class_acc0.7990398
# [0.827, 0.812, 0.837, 0.824, 0.828, 0.833, 0.844, 0.831, 0.822, 0.837, 0.83, 0.842] 0.8305833333333333
# [0.8513332680570499, 0.8413133587910818, 0.8604742308445997, 0.8509373571101949, 0.8539421255470621, 0.8594601651489914, 0.8690884167237811, 0.8565223071395898, 0.8490757071003966, 0.860310928212161, 0.8546949965729932, 0.8651718398120025] 0.8560270584216587
# 'baseline\n0 val_19class_loss0.90247583val_19class_acc0.81768334\n1 val_19class_loss0.9712743val_19class_acc0.7930089\n2 val_19class_loss0.9203671val_19class_acc0.8072702\n3 val_19class_loss0.9375971val_19class_acc0.8052126\n4 val_19class_loss0.88216704val_19class_acc0.8203018\n[0.822, 0.796, 0.811, 0.809, 0.835] 0.8146000000000001\n[0.8470903097359558, 0.8268873004993619, 0.8386243386243368, 0.8387223202038004, 0.8584166176758752] 0.841948177347866\n'

# %%
for index,i in enumerate(oof_comm):
    print(index,i,oof_score[index])

oof_dict = {
    "oof":proba_oof,
    "test":proba_t,
    "acc":oof_comm,
}
import joblib 
joblib.dump(oof_dict,"DeNspetronML3seedsDeNormal_%.5f_dict.pkl"% np.mean(oof_comm))
# Out:
# 0 0.7620353144684865 0.725
# 1 0.762492248441528 0.724
# 2 0.7854203409758961 0.747
# 3 0.7739564961787172 0.734
# 4 0.7671957671957655 0.728
# 5 0.7836417637651348 0.746
# 6 0.7864812820261746 0.751
# 7 0.7853876804494078 0.749
# 8 0.7903847410020234 0.757
# 9 0.7851263962375065 0.75
# 10 0.7851431182479838 0.748
# 11 0.8040406018473172 0.773
# 12 0.7888170357306147 0.753
# 13 0.809458488470833 0.774
# 14 0.8004441831602316 0.767
# ['DeNspetronML3seedsDeNormal_0.78467_dict.pkl']

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score

def acc_combo(y, y_pred):
    # 数值ID与行为编码的对应关系
    mapping = {0: 'A_0', 1: 'A_1', 2: 'A_2', 3: 'A_3', 
        4: 'D_4', 5: 'A_5', 6: 'B_1',7: 'B_5', 
        8: 'B_2', 9: 'B_3', 10: 'B_0', 11: 'A_6', 
        12: 'C_1', 13: 'C_3', 14: 'C_0', 15: 'B_6', 
        16: 'C_2', 17: 'C_5', 18: 'C_6'}
    # 将行为ID转为编码
    code_y, code_y_pred = mapping[y], mapping[y_pred]
    if code_y == code_y_pred: #编码完全相同得分1.0
        return 1.0
    elif code_y.split("_")[0] == code_y_pred.split("_")[0]: #编码仅字母部分相同得分1.0/7
        return 1.0/7
    elif code_y.split("_")[1] == code_y_pred.split("_")[1]: #编码仅数字部分相同得分1.0/3
        return 1.0/3
    else:
        return 0.0

train_y = y
labels = np.argmax(proba_t[:,:19], axis=1)
oof_y = np.argmax(proba_oof[:,:19], axis=1)
print(round(accuracy_score(train_y, oof_y), 5))
scores = sum(acc_combo(y_true, y_pred) for y_true, y_pred in zip(train_y, oof_y)) / oof_y.shape[0]
print(round(scores, 5))
data_path = '../../data/'
sub = pd.read_csv(data_path+'提交结果示例.csv')
sub['behavior_id'] = labels

vc = pd.Series(train_y).value_counts().sort_index()
sns.barplot(vc.index, vc.values)
plt.show()

vc = pd.Series(oof_y).value_counts().sort_index()
sns.barplot(vc.index, vc.values)
plt.show()

vc = sub['behavior_id'].value_counts().sort_index()
sns.barplot(vc.index, vc.values)
plt.show()
sub.to_csv('0728_conv2_multoloss_nn%.5f.csv' % scores, index=False)
sub.info()
# Out:
# 0.76303
# 0.79758
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   fragment_id  7500 non-null   int64
#  1   behavior_id  7500 non-null   int64
# dtypes: int64(2)
# memory usage: 117.3 KB

# %%
# %matplotlib inline
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import numpy as np

def plot_confusion_matrix(cm,classes,title='Confusion Matrix'):

    plt.figure(figsize=(12, 9), dpi=100)
    np.set_printoptions(precision=2)
    
    sns.heatmap(cm,annot=True)
    plt.title(title)
    plt.xticks(ticks=range(19),labels=classes)
    plt.yticks(ticks=range(19),labels=classes)
    
    plt.ylabel('Actual label')
    plt.xlabel('Predict label')
    plt.show()
    
# classes表示不同类别的名称，比如这有6个类别
num2detail_mapping = {0: 'A_0', 1: 'A_1', 2: 'A_2', 3: 'A_3', 
        4: 'D_4', 5: 'A_5', 6: 'B_1',7: 'B_5', 
        8: 'B_2', 9: 'B_3', 10: 'B_0', 11: 'A_6', 
        12: 'C_1', 13: 'C_3', 14: 'C_0', 15: 'B_6', 
        16: 'C_2', 17: 'C_5', 18: 'C_6'}

classes = [num2detail_mapping[int(i)]for i in range(19)]
print(classes)
# 获取混淆矩阵
cm = confusion_matrix(train_y, oof_y,normalize='true')
cm = np.round(cm,2)
plot_confusion_matrix(cm,classes, title='confusion matrix')
# Out:
# ['A_0', 'A_1', 'A_2', 'A_3', 'D_4', 'A_5', 'B_1', 'B_5', 'B_2', 'B_3', 'B_0', 'A_6', 'C_1', 'C_3', 'C_0', 'B_6', 'C_2', 'C_5', 'C_6']

# %%
for i in range(19):
    sns.distplot(proba_test[i],label=num2detail_mapping[i])
plt.xlim([0,1])
plt.legend()
plt.show()

# %%
# Out:
# 1496

# %%
class0_distribution = list(filter(lambda x:x>0.8,proba_test[1]))
sum(sum(proba_test > 0.99))
# Out:
# 1496

# %%
proba_test = np.zeros((7500, 19))
best_fold = [6,10,14,13]
for fold in best_fold:
    model = Net()
    model.load_weights(f'fold{fold}.h5')
    proba_test += model.predict(test, verbose=0, batch_size=1024) / len(best_fold)
    
labels = np.argmax(proba_test, axis=1)
data_path = '../../data/'
sub = pd.read_csv(data_path+'提交结果示例.csv')
sub['behavior_id'] = labels
vc = sub['behavior_id'].value_counts().sort_index()
sns.barplot(vc.index, vc.values)
plt.show()

scores = np.mean(np.array(oof_comm)[best_fold])
print(scores)
sub.to_csv('nn%.5f.csv' % scores, index=False)

# %%
joblib.load('0721_conv2_2_net_dict.pkl')
# Out:
# {'oof': array([[3.18406701e-01, 2.36933485e-01, 1.29989944e-02, ...,
#          8.72732606e-03, 6.40281290e-03, 1.30743925e-02],
#         [1.07079066e-01, 3.62501025e-01, 2.19051819e-03, ...,
#          7.76054990e-03, 6.55048410e-04, 7.28931231e-03],
#         [1.49847195e-01, 2.80115899e-04, 2.89210235e-04, ...,
#          1.19885977e-03, 1.81183306e-04, 2.98684882e-03],
#         ...,
#         [1.10205892e-03, 5.34337130e-04, 7.54885492e-04, ...,
#          1.08488568e-03, 7.02964666e-04, 9.88503635e-01],
#         [1.02081185e-03, 2.95973528e-04, 1.18560542e-03, ...,
#          1.09350705e-03, 1.52534037e-03, 9.87515688e-01],
#         [8.57781339e-03, 1.38868792e-02, 6.18984364e-03, ...,
#          2.84842937e-03, 1.60700958e-02, 4.76815194e-01]]),
#  'test': array([[1.88265373e-03, 3.60564419e-03, 2.64962610e-03, ...,
#          8.61187167e-03, 1.02914133e-02, 1.80201526e-03],
#         [2.53818692e-04, 1.35248894e-03, 7.73188145e-04, ...,
#          9.13258300e-04, 5.26467717e-04, 6.73125087e-04],
#         [2.75521779e-03, 1.01167987e-01, 5.97173462e-03, ...,
#          8.15660664e-03, 1.65569765e-03, 6.93138249e-03],
#         ...,
#         [1.04418015e-02, 3.46966203e-04, 7.18481021e-04, ...,
#          2.77271878e-03, 1.03564035e-04, 3.95393576e-04],
#         [1.45256489e-03, 5.80887428e-04, 1.37690782e-03, ...,
#          2.61072243e-03, 1.41819289e-03, 1.18138443e-03],
#         [1.58706227e-01, 9.83442106e-02, 1.57500958e-02, ...,
#          9.81043407e-03, 1.67188372e-02, 2.21417620e-03]]),
#  'acc': [0.8526714318352413,
#   0.8317503834981544,
#   0.8365667254556124,
#   0.8568489124044661,
#   0.8554118492390078]}
