# %%
import numpy as np
import pandas as pd
import lightgbm as lgb
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import entropy
import gc
import os
from tqdm import tqdm
pd.set_option('display.max_columns', 600)
pd.set_option('display.max_rows', 600)
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
7 * 400 * 5 / 60 / 60
# Out:
# 3.888888888888889

# %%
# from tensorflow_addons.optimizers import AdamW
# import tensorflow

# %%
root_path  = '../data/final_data/'
data_train = pd.read_csv(root_path+'sensor_train_final.csv')
data_test = pd.read_csv(root_path+'sensor_test_final.csv')
sub = pd.read_csv(root_path+'submit_example.csv')
y = data_train.groupby('fragment_id')['behavior_id'].min()
data_test['fragment_id'] += 100000
label = 'behavior_id'

# %%
data_train.head()
# Out:
#    fragment_id  time_point  acc_x  acc_y  acc_z  acc_xg  acc_yg  acc_zg  \
# 0            0          37   -0.1    0.0   -0.1   -0.49    1.31    9.51
# 1            0         123    0.0    0.0   -0.1   -0.49    1.31    9.51
# 2            0         210    0.0   -0.0    0.1   -0.41    1.29    9.58
# 3            0         291    0.0    0.0    0.0   -0.38    1.32    9.52
# 4            0         375    0.1    0.0    0.1   -0.31    1.29    9.58
#
#    behavior_id
# 0           11
# 1           11
# 2           11
# 3           11
# 4           11

# %%
data = pd.concat([data_train, data_test], sort=False,ignore_index=True)
df = data.drop_duplicates(subset=['fragment_id']).reset_index(drop=True)[['fragment_id', 'behavior_id']]

data['acc'] = (data['acc_x'] ** 2 + data['acc_y'] ** 2 + data['acc_z'] ** 2) ** 0.5
data['accg'] = (data['acc_xg'] ** 2 + data['acc_yg'] ** 2 + data['acc_zg'] ** 2) ** 0.5

data = data.sort_values(['fragment_id','time_point'],ascending=False)
# data = data.set_index(['fragment_id','time_point'])
data['acc_time_diff'] = data.groupby(["fragment_id"])["time_point"].diff(1)
# data = data.reset_index()
for fdata in tqdm([f for f in data.columns if 'acc' in f]):
    for stat in ['min', 'max', 'mean', 'median', 'std', 'skew']:
        df[fdata+'_'+stat] = data.groupby('fragment_id')[fdata].agg(stat).values

# df["time_count"] = df.merge(d/"ata.groupby("fragment_id")["acc"].count(),on='fragment_id',how='left')
# Out:
# 100%|██████████| 9/9 [00:30<00:00,  3.34s/it]

# %%
 data.groupby(["fragment_id"])["time_point"].diff(-1)
# Out:
# 0        -86.0
# 0        -85.0
# 1        -87.0
# 1        -83.0
# 2        -81.0
#           ...
# 420416   -82.0
# 420417   -85.0
# 420418   -82.0
# 420419   -84.0
# 420420     NaN
# Name: time_point, Length: 812215, dtype: float64

# %%
data.groupby("fragment_id")["acc"].count()
# Out:
# fragment_id
# 0         20
# 1         22
# 2         39
# 3         28
# 4         10
#           ..
# 115995    42
# 115996    52
# 115997    33
# 115998    12
# 115999    28
# Name: acc, Length: 31000, dtype: int64

# %%
train_df = df[df[label].isna()==False].reset_index(drop=True)
test_df = df[df[label].isna()==True].reset_index(drop=True)

drop_feat = []
used_feat = [f for f in train_df.columns if f not in (['fragment_id', label] + drop_feat)]
print(len(used_feat))
print(used_feat)

train_x = train_df[used_feat]
train_y = train_df[label]
test_x = test_df[used_feat]
# Out:
# 48
# ['acc_x_min', 'acc_x_max', 'acc_x_mean', 'acc_x_median', 'acc_x_std', 'acc_x_skew', 'acc_y_min', 'acc_y_max', 'acc_y_mean', 'acc_y_median', 'acc_y_std', 'acc_y_skew', 'acc_z_min', 'acc_z_max', 'acc_z_mean', 'acc_z_median', 'acc_z_std', 'acc_z_skew', 'acc_xg_min', 'acc_xg_max', 'acc_xg_mean', 'acc_xg_median', 'acc_xg_std', 'acc_xg_skew', 'acc_yg_min', 'acc_yg_max', 'acc_yg_mean', 'acc_yg_median', 'acc_yg_std', 'acc_yg_skew', 'acc_zg_min', 'acc_zg_max', 'acc_zg_mean', 'acc_zg_median', 'acc_zg_std', 'acc_zg_skew', 'acc_min', 'acc_max', 'acc_mean', 'acc_median', 'acc_std', 'acc_skew', 'accg_min', 'accg_max', 'accg_mean', 'accg_median', 'accg_std', 'accg_skew']

# %%
train_df = df[df[label].isna()==False].reset_index(drop=True)
test_df = df[df[label].isna()==True].reset_index(drop=True)

drop_feat = []
used_feat = [f for f in train_df.columns if f not in (['fragment_id', label] + drop_feat)]
print(len(used_feat))
print(used_feat)

train_x = train_df[used_feat]
train_y = train_df[label]
test_x = test_df[used_feat]
# Out:
# 48
# ['acc_x_min', 'acc_x_max', 'acc_x_mean', 'acc_x_median', 'acc_x_std', 'acc_x_skew', 'acc_y_min', 'acc_y_max', 'acc_y_mean', 'acc_y_median', 'acc_y_std', 'acc_y_skew', 'acc_z_min', 'acc_z_max', 'acc_z_mean', 'acc_z_median', 'acc_z_std', 'acc_z_skew', 'acc_xg_min', 'acc_xg_max', 'acc_xg_mean', 'acc_xg_median', 'acc_xg_std', 'acc_xg_skew', 'acc_yg_min', 'acc_yg_max', 'acc_yg_mean', 'acc_yg_median', 'acc_yg_std', 'acc_yg_skew', 'acc_zg_min', 'acc_zg_max', 'acc_zg_mean', 'acc_zg_median', 'acc_zg_std', 'acc_zg_skew', 'acc_min', 'acc_max', 'acc_mean', 'acc_median', 'acc_std', 'acc_skew', 'accg_min', 'accg_max', 'accg_mean', 'accg_median', 'accg_std', 'accg_skew']

# %%
scores = []
imp = pd.DataFrame()
imp['feat'] = used_feat

params = {
    'learning_rate': 0.1,
    'metric': 'multi_error',
    'objective': 'multiclass',
    'num_class': 20,
    'feature_fraction': 0.80,
    'bagging_fraction': 0.75,
    'bagging_freq': 2,
    'n_jobs': 4,
    'seed': 2020,
    'max_depth': 10,
    'num_leaves': 64,
    'lambda_l1': 0.5,
    'lambda_l2': 0.5,
}

oof_train = np.zeros((len(train_x), 20))
preds = np.zeros((len(test_x), 20))
folds = 5
seeds = [44, 2020, 527, 1527]
for seed in seeds:
    kfold = StratifiedKFold(n_splits=folds, shuffle=True, random_state=seed)
    for fold, (trn_idx, val_idx) in enumerate(kfold.split(train_x, train_y)):
        x_trn, y_trn, x_val, y_val = train_x.iloc[trn_idx], train_y.iloc[trn_idx], train_x.iloc[val_idx], train_y.iloc[val_idx]
        train_set = lgb.Dataset(x_trn, y_trn)
        val_set = lgb.Dataset(x_val, y_val)

        model = lgb.train(params, train_set, num_boost_round=500000,
                          valid_sets=(train_set, val_set), early_stopping_rounds=50,
                          verbose_eval=20)
        oof_train[val_idx] += model.predict(x_val) / len(seeds)
        preds += model.predict(test_x) / folds / len(seeds)
        scores.append(model.best_score['valid_1']['multi_error'])
        imp['gain' + str(fold + 1)] = model.feature_importance(importance_type='gain')
        imp['split' + str(fold + 1)] = model.feature_importance(importance_type='split')
        del x_trn, y_trn, x_val, y_val, model, train_set, val_set
        gc.collect()
# Out:
# Training until validation scores don't improve for 50 rounds
# [20]	training's multi_error: 0.0965833	valid_1's multi_error: 0.272
# [40]	training's multi_error: 0.037	valid_1's multi_error: 0.256
# [60]	training's multi_error: 0.0109167	valid_1's multi_error: 0.243667
# [80]	training's multi_error: 0.00291667	valid_1's multi_error: 0.236333
# [100]	training's multi_error: 0.000416667	valid_1's multi_error: 0.234
# [120]	training's multi_error: 0.000333333	valid_1's multi_error: 0.233667
# [140]	training's multi_error: 8.33333e-05	valid_1's multi_error: 0.231667
# [160]	training's multi_error: 8.33333e-05	valid_1's multi_error: 0.23
# [180]	training's multi_error: 8.33333e-05	valid_1's multi_error: 0.231
# [200]	training's multi_error: 0	valid_1's multi_error: 0.227667
# [220]	training's multi_error: 0	valid_1's multi_error: 0.227
# [240]	training's multi_error: 0	valid_1's multi_error: 0.226667
# [260]	training's multi_error: 0	valid_1's multi_error: 0.226
# [280]	training's multi_error: 0	valid_1's multi_error: 0.226333
# Early stopping, best iteration is:
# [244]	training's multi_error: 0	valid_1's multi_error: 0.225
# 584
# Training until validation scores don't improve for 50 rounds
# [20]	training's multi_error: 0.099	valid_1's multi_error: 0.286667
# [40]	training's multi_error: 0.0368333	valid_1's multi_error: 0.264
# [60]	training's multi_error: 0.0115833	valid_1's multi_error: 0.253333
# [80]	training's multi_error: 0.00291667	valid_1's multi_error: 0.253667
# [100]	training's multi_error: 0.000583333	valid_1's multi_error: 0.248333
# [120]	training's multi_error: 0.0005	valid_1's multi_error: 0.247
# [140]	training's multi_error: 0.00025	valid_1's multi_error: 0.245667
# [160]	training's multi_error: 0.00025	valid_1's multi_error: 0.245333
# [180]	training's multi_error: 0.000166667	valid_1's multi_error: 0.245
# Early stopping, best iteration is:
# [142]	training's multi_error: 0.00025	valid_1's multi_error: 0.243
# 412
# Training until validation scores don't improve for 50 rounds
# [20]	training's multi_error: 0.101	valid_1's multi_error: 0.277333
# [40]	training's multi_error: 0.0389167	valid_1's multi_error: 0.257
# [60]	training's multi_error: 0.0119167	valid_1's multi_error: 0.247333
# [80]	training's multi_error: 0.00233333	valid_1's multi_error: 0.239333
# [100]	training's multi_error: 0.00125	valid_1's multi_error: 0.237
# [120]	training's multi_error: 0.000666667	valid_1's multi_error: 0.237333
# [140]	training's multi_error: 0.000583333	valid_1's multi_error: 0.235667
# [160]	training's multi_error: 0.000416667	valid_1's multi_error: 0.233
# [180]	training's multi_error: 0.000416667	valid_1's multi_error: 0.233
# [200]	training's multi_error: 0.000416667	valid_1's multi_error: 0.23
# [220]	training's multi_error: 0.000416667	valid_1's multi_error: 0.229333
# [240]	training's multi_error: 0.000416667	valid_1's multi_error: 0.229667
# Early stopping, best iteration is:
# [206]	training's multi_error: 0.000416667	valid_1's multi_error: 0.229
# 6567
# Training until validation scores don't improve for 50 rounds
# [20]	training's multi_error: 0.0980833	valid_1's multi_error: 0.296333
# [40]	training's multi_error: 0.0401667	valid_1's multi_error: 0.270333
# [60]	training's multi_error: 0.0114167	valid_1's multi_error: 0.260333
# [80]	training's multi_error: 0.0025	valid_1's multi_error: 0.254667
# [100]	training's multi_error: 0.00125	valid_1's multi_error: 0.250667
# [120]	training's multi_error: 0.000833333	valid_1's multi_error: 0.246667
# [140]	training's multi_error: 0.000583333	valid_1's multi_error: 0.246333
# [160]	training's multi_error: 0.000416667	valid_1's multi_error: 0.243333
# [180]	training's multi_error: 0.000416667	valid_1's multi_error: 0.240333
# [200]	training's multi_error: 0.000333333	valid_1's multi_error: 0.242667
# [220]	training's multi_error: 0.00025	valid_1's multi_error: 0.240333
# Early stopping, best iteration is:
# [181]	training's multi_error: 0.000416667	valid_1's multi_error: 0.239667
# 568
# Training until validation scores don't improve for 50 rounds
# [20]	training's multi_error: 0.101167	valid_1's multi_error: 0.287333
# [40]	training's multi_error: 0.0399167	valid_1's multi_error: 0.267667
# [60]	training's multi_error: 0.0103333	valid_1's multi_error: 0.258
# [80]	training's multi_error: 0.00225	valid_1's multi_error: 0.249333
# [100]	training's multi_error: 0.000583333	valid_1's multi_error: 0.244333
# [120]	training's multi_error: 0.0005	valid_1's multi_error: 0.245333
# [140]	training's multi_error: 0.000333333	valid_1's multi_error: 0.243333
# [160]	training's multi_error: 0.000333333	valid_1's multi_error: 0.242
# [180]	training's multi_error: 0.00025	valid_1's multi_error: 0.244333
# Early stopping, best iteration is:
# [144]	training's multi_error: 0.00025	valid_1's multi_error: 0.242
# 420
# Training until validation scores don't improve for 50 rounds
# [20]	training's multi_error: 0.0963333	valid_1's multi_error: 0.291
# [40]	training's multi_error: 0.0375833	valid_1's multi_error: 0.268
# [60]	training's multi_error: 0.0108333	valid_1's multi_error: 0.257333
# [80]	training's multi_error: 0.00341667	valid_1's multi_error: 0.254667
# [100]	training's multi_error: 0.000916667	valid_1's multi_error: 0.252
# [120]	training's multi_error: 0.000416667	valid_1's multi_error: 0.246
# [140]	training's multi_error: 0.000416667	valid_1's multi_error: 0.244333
# [160]	training's multi_error: 0.000333333	valid_1's multi_error: 0.244667
# [180]	training's multi_error: 0.000416667	valid_1's multi_error: 0.241
# [200]	training's multi_error: 0.00025	valid_1's multi_error: 0.240667
# [220]	training's multi_error: 0.00025	valid_1's multi_error: 0.239667
# [240]	training's multi_error: 0.00025	valid_1's multi_error: 0.240333
# [260]	training's multi_error: 0.00025	valid_1's multi_error: 0.24
# [280]	training's multi_error: 0.00025	valid_1's multi_error: 0.239
# [300]	training's multi_error: 0.00025	valid_1's multi_error: 0.240667
# [320]	training's multi_error: 0.00025	valid_1's multi_error: 0.240333
# Early stopping, best iteration is:
# [271]	training's multi_error: 0.00025	valid_1's multi_error: 0.238
# 156
# Training until validation scores don't improve for 50 rounds
# [20]	training's multi_error: 0.0993333	valid_1's multi_error: 0.273667
# [40]	training's multi_error: 0.0390833	valid_1's multi_error: 0.256667
# [60]	training's multi_error: 0.0108333	valid_1's multi_error: 0.242333
# [80]	training's multi_error: 0.00283333	valid_1's multi_error: 0.238667
# [100]	training's multi_error: 0.000916667	valid_1's multi_error: 0.236667
# [120]	training's multi_error: 0.000583333	valid_1's multi_error: 0.235
# [140]	training's multi_error: 0.000416667	valid_1's multi_error: 0.232667
# [160]	training's multi_error: 0.000416667	valid_1's multi_error: 0.232333
# [180]	training's multi_error: 0.000416667	valid_1's multi_error: 0.232667
# [200]	training's multi_error: 0.000333333	valid_1's multi_error: 0.230333
# [220]	training's multi_error: 0.000333333	valid_1's multi_error: 0.229
# [240]	training's multi_error: 0.000333333	valid_1's multi_error: 0.229667
# [260]	training's multi_error: 0.000333333	valid_1's multi_error: 0.228667
# [280]	training's multi_error: 0.000333333	valid_1's multi_error: 0.228333
# Early stopping, best iteration is:
# [248]	training's multi_error: 0.000333333	valid_1's multi_error: 0.227333
# 68
# Training until validation scores don't improve for 50 rounds
# [20]	training's multi_error: 0.1	valid_1's multi_error: 0.289667
# [40]	training's multi_error: 0.04025	valid_1's multi_error: 0.270333
# [60]	training's multi_error: 0.0114167	valid_1's multi_error: 0.258
# [80]	training's multi_error: 0.00291667	valid_1's multi_error: 0.256667
# [100]	training's multi_error: 0.000833333	valid_1's multi_error: 0.249667
# [120]	training's multi_error: 0.000333333	valid_1's multi_error: 0.245667
# [140]	training's multi_error: 0.000166667	valid_1's multi_error: 0.245667
# [160]	training's multi_error: 8.33333e-05	valid_1's multi_error: 0.245667
# [180]	training's multi_error: 8.33333e-05	valid_1's multi_error: 0.244667
# Early stopping, best iteration is:
# [135]	training's multi_error: 0.00025	valid_1's multi_error: 0.243667
# 384
# Training until validation scores don't improve for 50 rounds
# [20]	training's multi_error: 0.09925	valid_1's multi_error: 0.277
# [40]	training's multi_error: 0.0383333	valid_1's multi_error: 0.249
# [60]	training's multi_error: 0.01025	valid_1's multi_error: 0.241667
# [80]	training's multi_error: 0.00241667	valid_1's multi_error: 0.236333
# [100]	training's multi_error: 0.000416667	valid_1's multi_error: 0.236
# [120]	training's multi_error: 0.000333333	valid_1's multi_error: 0.235333
# [140]	training's multi_error: 0.000166667	valid_1's multi_error: 0.229333
# [160]	training's multi_error: 0.000166667	valid_1's multi_error: 0.229
# [180]	training's multi_error: 8.33333e-05	valid_1's multi_error: 0.227667
# [200]	training's multi_error: 8.33333e-05	valid_1's multi_error: 0.228667
# [220]	training's multi_error: 8.33333e-05	valid_1's multi_error: 0.226667
# [240]	training's multi_error: 8.33333e-05	valid_1's multi_error: 0.225667
# [260]	training's multi_error: 8.33333e-05	valid_1's multi_error: 0.224333
# [280]	training's multi_error: 8.33333e-05	valid_1's multi_error: 0.225667
# Early stopping, best iteration is:
# [231]	training's multi_error: 8.33333e-05	valid_1's multi_error: 0.224333
# 12
# Training until validation scores don't improve for 50 rounds
# [20]	training's multi_error: 0.0971667	valid_1's multi_error: 0.285333
# [40]	training's multi_error: 0.039	valid_1's multi_error: 0.264333
# [60]	training's multi_error: 0.01075	valid_1's multi_error: 0.249
# [80]	training's multi_error: 0.00225	valid_1's multi_error: 0.244333
# [100]	training's multi_error: 0.000833333	valid_1's multi_error: 0.237667
# [120]	training's multi_error: 0.00025	valid_1's multi_error: 0.237667
# [140]	training's multi_error: 0.000166667	valid_1's multi_error: 0.236667
# Early stopping, best iteration is:
# [107]	training's multi_error: 0.0005	valid_1's multi_error: 0.236
# 272
# Training until validation scores don't improve for 50 rounds
# [20]	training's multi_error: 0.0986667	valid_1's multi_error: 0.275667
# [40]	training's multi_error: 0.0386667	valid_1's multi_error: 0.255
# [60]	training's multi_error: 0.0115	valid_1's multi_error: 0.243333
# [80]	training's multi_error: 0.00241667	valid_1's multi_error: 0.237
# [100]	training's multi_error: 0.000666667	valid_1's multi_error: 0.233333
# [120]	training's multi_error: 0.000416667	valid_1's multi_error: 0.233
# [140]	training's multi_error: 0.00025	valid_1's multi_error: 0.233667
# [160]	training's multi_error: 0.00025	valid_1's multi_error: 0.229667
# [180]	training's multi_error: 0.000166667	valid_1's multi_error: 0.23
# [200]	training's multi_error: 0.000166667	valid_1's multi_error: 0.228333
# [220]	training's multi_error: 0.000166667	valid_1's multi_error: 0.227
# [240]	training's multi_error: 0.000166667	valid_1's multi_error: 0.227667
# Early stopping, best iteration is:
# [194]	training's multi_error: 0.000166667	valid_1's multi_error: 0.225333
# 620
# Training until validation scores don't improve for 50 rounds
# [20]	training's multi_error: 0.0990833	valid_1's multi_error: 0.275333
# [40]	training's multi_error: 0.0395	valid_1's multi_error: 0.256
# [60]	training's multi_error: 0.0110833	valid_1's multi_error: 0.247667
# [80]	training's multi_error: 0.00358333	valid_1's multi_error: 0.243333
# [100]	training's multi_error: 0.00108333	valid_1's multi_error: 0.241667
# [120]	training's multi_error: 0.000666667	valid_1's multi_error: 0.239667
# [140]	training's multi_error: 0.000583333	valid_1's multi_error: 0.237333
# [160]	training's multi_error: 0.0005	valid_1's multi_error: 0.237667
# [180]	training's multi_error: 0.0005	valid_1's multi_error: 0.234
# [200]	training's multi_error: 0.0005	valid_1's multi_error: 0.236667
# [220]	training's multi_error: 0.0005	valid_1's multi_error: 0.236
# Early stopping, best iteration is:
# [175]	training's multi_error: 0.0005	valid_1's multi_error: 0.232333
# 544
# Training until validation scores don't improve for 50 rounds
# [20]	training's multi_error: 0.1025	valid_1's multi_error: 0.295667
# [40]	training's multi_error: 0.0393333	valid_1's multi_error: 0.271333
# [60]	training's multi_error: 0.01175	valid_1's multi_error: 0.259333
# [80]	training's multi_error: 0.00241667	valid_1's multi_error: 0.252333
# [100]	training's multi_error: 0.000916667	valid_1's multi_error: 0.251333
# [120]	training's multi_error: 0.000666667	valid_1's multi_error: 0.25
# [140]	training's multi_error: 0.000416667	valid_1's multi_error: 0.249333
# [60]	training's multi_error: 0.0125833	valid_1's multi_error: 0.251333
# [80]	training's multi_error: 0.00358333	valid_1's multi_error: 0.245667
# [100]	training's multi_error: 0.00133333	valid_1's multi_error: 0.239333
# [120]	training's multi_error: 0.000833333	valid_1's multi_error: 0.235
# [140]	training's multi_error: 0.000666667	valid_1's multi_error: 0.234333
# [160]	training's multi_error: 0.000583333	valid_1's multi_error: 0.235
# Early stopping, best iteration is:
# [129]	training's multi_error: 0.000666667	valid_1's multi_error: 0.233667
# 360
# Training until validation scores don't improve for 50 rounds
# [20]	training's multi_error: 0.0979167	valid_1's multi_error: 0.289667
# [40]	training's multi_error: 0.0404167	valid_1's multi_error: 0.263667
# [60]	training's multi_error: 0.0105	valid_1's multi_error: 0.252667
# [80]	training's multi_error: 0.00275	valid_1's multi_error: 0.243333
# [100]	training's multi_error: 0.00075	valid_1's multi_error: 0.242
# [120]	training's multi_error: 0.000333333	valid_1's multi_error: 0.236667
# [140]	training's multi_error: 0.00025	valid_1's multi_error: 0.238333
# [160]	training's multi_error: 0.000166667	valid_1's multi_error: 0.237667
# [180]	training's multi_error: 0.000166667	valid_1's multi_error: 0.236
# [200]	training's multi_error: 0.000166667	valid_1's multi_error: 0.236667
# [220]	training's multi_error: 0.000166667	valid_1's multi_error: 0.239333
# Early stopping, best iteration is:
# [183]	training's multi_error: 0.000166667	valid_1's multi_error: 0.235667
# 576

# %%
imp['gain'] = imp[[f for f in imp.columns if 'gain' in f]].sum(axis=1)/folds
imp['split'] = imp[[f for f in imp.columns if 'split' in f]].sum(axis=1)
imp = imp.sort_values(by=['gain'], ascending=False)
imp[['feat', 'gain', 'split']]
imp = imp.sort_values(by=['split'], ascending=False)
imp[['feat', 'gain', 'split']]
# Out:
#              feat          gain  split
# 34     acc_zg_std  20726.138112  12129
# 25     acc_yg_max  20115.104391  22009
# 24     acc_yg_min  15407.812712  23211
# 30     acc_zg_min  14108.572476  19868
# 19     acc_xg_max  11625.883332  24622
# 18     acc_xg_min  11180.230170  24368
# 32    acc_zg_mean  10644.444531  19790
# 44      accg_mean  10567.754649  32200
# 26    acc_yg_mean  10291.799002  17940
# 27  acc_yg_median   9986.172430  16318
# 4       acc_x_std   9012.956917  14641
# 36        acc_min   8952.635801  20031
# 39     acc_median   7903.580842  12985
# 10      acc_y_std   7594.549608  17149
# 20    acc_xg_mean   7562.247144  21034
# 21  acc_xg_median   7082.726683  19435
# 45    accg_median   6924.852195  27604
# 8      acc_y_mean   6838.531742  25324
# 33  acc_zg_median   6655.475997  17955
# 31     acc_zg_max   6638.001881  16056
# 22     acc_xg_std   5787.286288  19195
# 14     acc_z_mean   5258.520638  22654
# 28     acc_yg_std   5136.441806  20378
# 9    acc_y_median   4525.166958  16440
# 16      acc_z_std   3368.470962  10588
# 38       acc_mean   3128.335996   8183
# 2      acc_x_mean   3097.894819  23077
# 15   acc_z_median   2650.077907  14805
# 3    acc_x_median   2323.100714  14709
# 41       acc_skew   2319.332295  21318
# 6       acc_y_min   2271.125922  11007
# 42       accg_min   2243.161399  14660
# 46       accg_std   2219.375724  10385
# 29    acc_yg_skew   2125.985335  22580
# 11     acc_y_skew   2109.564512  21805
# 7       acc_y_max   2010.389429  12867
# 40        acc_std   1971.386321  10642
# 5      acc_x_skew   1929.286138  21652
# 23    acc_xg_skew   1859.376878  21565
# 35    acc_zg_skew   1675.555488  18862
# 17     acc_z_skew   1664.214686  19029
# 1       acc_x_max   1578.275902  11049
# 47      accg_skew   1532.278339  17672
# 43       accg_max   1517.277881  11987
# 12      acc_z_min   1511.042402  10470
# 0       acc_x_min   1324.768922  11019
# 13      acc_z_max   1229.676729   9763
# 37        acc_max   1006.131381   7246
#              feat          gain  split
# 44      accg_mean  10567.754649  32200
# 45    accg_median   6924.852195  27604
# 8      acc_y_mean   6838.531742  25324
# 19     acc_xg_max  11625.883332  24622
# 18     acc_xg_min  11180.230170  24368
# 24     acc_yg_min  15407.812712  23211
# 2      acc_x_mean   3097.894819  23077
# 14     acc_z_mean   5258.520638  22654
# 29    acc_yg_skew   2125.985335  22580
# 25     acc_yg_max  20115.104391  22009
# 11     acc_y_skew   2109.564512  21805
# 5      acc_x_skew   1929.286138  21652
# 23    acc_xg_skew   1859.376878  21565
# 41       acc_skew   2319.332295  21318
# 20    acc_xg_mean   7562.247144  21034
# 28     acc_yg_std   5136.441806  20378
# 36        acc_min   8952.635801  20031
# 30     acc_zg_min  14108.572476  19868
# 32    acc_zg_mean  10644.444531  19790
# 21  acc_xg_median   7082.726683  19435
# 22     acc_xg_std   5787.286288  19195
# 17     acc_z_skew   1664.214686  19029
# 35    acc_zg_skew   1675.555488  18862
# 33  acc_zg_median   6655.475997  17955
# 26    acc_yg_mean  10291.799002  17940
# 47      accg_skew   1532.278339  17672
# 10      acc_y_std   7594.549608  17149
# 9    acc_y_median   4525.166958  16440
# 27  acc_yg_median   9986.172430  16318
# 31     acc_zg_max   6638.001881  16056
# 15   acc_z_median   2650.077907  14805
# 3    acc_x_median   2323.100714  14709
# 42       accg_min   2243.161399  14660
# 4       acc_x_std   9012.956917  14641
# 39     acc_median   7903.580842  12985
# 7       acc_y_max   2010.389429  12867
# 34     acc_zg_std  20726.138112  12129
# 43       accg_max   1517.277881  11987
# 1       acc_x_max   1578.275902  11049
# 0       acc_x_min   1324.768922  11019
# 6       acc_y_min   2271.125922  11007
# 40        acc_std   1971.386321  10642
# 16      acc_z_std   3368.470962  10588
# 12      acc_z_min   1511.042402  10470
# 46       accg_std   2219.375724  10385
# 13      acc_z_max   1229.676729   9763
# 38       acc_mean   3128.335996   8183
# 37        acc_max   1006.131381   7246

# %%
def acc_combo(y, y_pred):
    # 数值ID与行为编码的对应关系
    mapping = {
        '0': 'A_1', '1': 'B_2', '2': 'A_3', '3': 'A_4', '4': 'B_3', '5': 'C_5', '6': 'C_2', '7': 'A_5', '8': 'B_1', 
        '9': 'C_1', '10': 'A_2', '11': 'C_3', '12': 'B_5', '13': 'B_4', '14': 'C_4', 
        '15': 'D_6', '16': 'E_7', '17': 'F_8', '18': 'G_9', '19': 'H_0'
              }
    # 将行为ID转为编码
    code_y, code_y_pred = mapping[str(int(y))], mapping[str(int(y_pred))]
    if code_y == code_y_pred: #编码完全相同得分1.0
        return 1.0
    elif code_y.split("_")[0] == code_y_pred.split("_")[0]: #编码仅字母部分相同得分1.0/7
        return 1.0/7
    elif code_y.split("_")[1] == code_y_pred.split("_")[1]: #编码仅数字部分相同得分1.0/3
        return 1.0/3
    else:
        return 0.0

# %%
labels = np.argmax(preds, axis=1)
oof_y = np.argmax(oof_train, axis=1)
print(round(accuracy_score(train_y, oof_y), 5))
score = sum(acc_combo(y_true, y_pred) for y_true, y_pred in zip(train_y, oof_y)) / oof_y.shape[0]
print(round(score, 5))
# Out:
# 0.7738
# 0.79865

# %%
sub = pd.read_csv(root_path+'submit_example.csv')

sub['behavior_id'] = labels

vc = data_train['behavior_id'].value_counts().sort_index()
sns.barplot(vc.index, vc.values)
plt.show()
vc = sub['behavior_id'].value_counts().sort_index()
sns.barplot(vc.index, vc.values)
plt.show()
sub.to_csv('sub%.5f.csv' % score, index=False)
