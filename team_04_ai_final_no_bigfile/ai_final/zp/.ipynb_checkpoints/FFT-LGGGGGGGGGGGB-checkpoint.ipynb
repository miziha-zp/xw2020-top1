# %%
import numpy as np
import pandas as pd
import lightgbm as lgb
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import entropy
import gc
import os
from tqdm import tqdm
pd.set_option('display.max_columns', 600)
pd.set_option('display.max_rows', 600)
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"


def q10(x):
    return x.quantile(0.1)


def q20(x):
    return x.quantile(0.2)


def q25(x):
    return x.quantile(0.25)


def q30(x):
    return x.quantile(0.3)


def q40(x):
    return x.quantile(0.4)


def q60(x):
    return x.quantile(0.6)


def q70(x):
    return x.quantile(0.7)


def q75(x):
    return x.quantile(0.75)


def q80(x):
    return x.quantile(0.8)


def q90(x):
    return x.quantile(0.9)

def feature_test_with_cv(X, y, params=None, cate_feas='auto', nfold=3):
    """
    [For LightGBM ONLY]
    Use cross validation to test if the feature distribution is the same in both train and test sets.
    y: 'istest' column with valus of 0-1
    Example:
        df_fea_auc = get_feature_report(df, features=gcn_feas, all_cate_feas=[], params=None,nfold=3)
    """
    if params is None:
        params = {
            'n_estimators': 100,
            'learning_rate': 0.1,
            'boosting_type': 'gbdt',
            'objective': 'binary',
            'early_stopping_rounds': 25,
            'metric': 'auc',
            'n_jobs': -1,
            'num_leaves': 31,
            'seed': 2020
        }
    sfold = StratifiedKFold(n_splits=nfold, shuffle=True, random_state=2020)
    models = []
    val_auc = 0
    train_auc = 0
    oof = np.zeros(len(X))
    for _, (train_idx, val_idx) in enumerate(sfold.split(X, y)):
        train_set = lgb.Dataset(X.iloc[train_idx],
                                y.iloc[train_idx],
                                categorical_feature=cate_feas)
        val_set = lgb.Dataset(X.iloc[val_idx],
                              y.iloc[val_idx],
                              categorical_feature=cate_feas)
        model = lgb.train(params,
                          train_set,
                          valid_sets=[train_set, val_set],
                          verbose_eval=20)
        val_auc += model.best_score['valid_1']['auc'] / 3
        train_auc += model.best_score['training']['auc'] / 3
        oof[val_idx] = model.predict(X.iloc[val_idx])
        models.append(model)
    return train_auc, val_auc, models, oof

def get_feature_report_by_covariate_shift_test(df_raw,
                                               features=None,
                                               all_cate_feas=[],
                                               params=None,
                                               nfold=3,
                                               y2test='istrain',
                                               train_all_feas=False):
    """
    Use cross validation to test if the feature distribution is the same in both train and test sets.
    Args:
        y2test: target to test, 'istrain' or 'istest'
        train_all_feas: if True, the model will be trained with all features together
    Return:
        result_dict: dict
    """
    df = df_raw.copy()
    del df_raw
    gc.collect()
    if features is None:
#         logger.info(
#             "features is none, all cols will be used except 'istrain' or 'istest'!"
#         )
        features = [
            col for col in df.columns if col not in ['istrain', 'istest']
        ]
    if train_all_feas:
        train_auc, val_auc, models, oof = feature_test_with_cv(
            X=df[features],
            y=df[y2test],
            params=params,
            cate_feas=[col for col in all_cate_feas if col in features],
            nfold=nfold)
        df['pred'] = oof
        if y2test == 'istrain':
            weights = df[df['istrain'] == 1]['pred'].values
            weights = (1. / weights) - 1.
            weights /= np.mean(weights)
        elif y2test == 'istest':
            weights = df[df['istest'] == 0]['pred'].values
            weights = (1. / (1 - weights)) - 1.
            weights /= np.mean(weights)
        else:
            raise NotImplementedError(
                "y2test should be in ['istrain','istest'] !")
        result_dict = {
            'train_auc': train_auc,
            'val_auc': val_auc,
            'models': models,
            'weights': weights
        }
    else:
        score_lst = []
        fea_lst = []
        for fea in features:
            if fea in all_cate_feas:
                cate_feas = [fea]
            else:
                cate_feas = 'auto'
#             logger.info("=" * 30)
#             logger.info(f"Testing: <{fea}> ...")
#             logger.info("=" * 30)
            train_auc, val_auc, _, _ = feature_test_with_cv(
                X=df[[fea]],
                y=df[y2test],
                params=params,
                cate_feas=cate_feas,
                nfold=nfold)
            fea_lst.append(fea)
            score_lst.append((train_auc, val_auc))
        df_fea_auc = pd.DataFrame(score_lst, columns=['train_auc', 'val_auc'])
        df_fea_auc['feat'] = fea_lst
        df_fea_auc = df_fea_auc.sort_values(by='val_auc', ascending=False)
        result_dict = {'df_fea_auc': df_fea_auc}
    return result_dict

def train_lgb(used_feat_,train_x,train_y,test_x,seed_num=3):
    scores = []
    imp = pd.DataFrame()
    imp['feat'] = used_feat_
    print(len(used_feat_)," : ",used_feat_)
    train_x = train_x[used_feat_]
    test_x = test_x[used_feat_]

    params = {
        'learning_rate': 0.1,
        'metric': 'multi_error',
        'objective': 'multiclass',
        'num_class': 19,
        'feature_fraction': 0.80,
        'bagging_fraction': 0.75,
        'bagging_freq': 2,
        'n_jobs': 4,
        'seed': 2020,
        'max_depth': 10,
        'num_leaves': 64,
        'lambda_l1': 0.5,
        'lambda_l2': 0.5,
    }

    oof_train = np.zeros((len(train_x), pd.Series(train_y).nunique()))
    preds = np.zeros((len(test_x), pd.Series(train_y).nunique()))
    folds = 5
    seeds = [44, 2020, 527, 1527]
    for seed in seeds[:seed_num]:
        print("seed:",seed)
        kfold = StratifiedKFold(n_splits=folds, shuffle=True, random_state=seed)
        for fold, (trn_idx, val_idx) in enumerate(kfold.split(train_x, train_y)):
            print("seed:",seed,"fold:",fold)
            x_trn, y_trn, x_val, y_val = train_x.iloc[trn_idx], train_y.iloc[trn_idx], train_x.iloc[val_idx], train_y.iloc[val_idx]
            
            train_set = lgb.Dataset(x_trn, y_trn)
            val_set = lgb.Dataset(x_val, y_val)
            model = lgb.train(params, train_set, num_boost_round=5000,
                              valid_sets=(train_set,val_set), early_stopping_rounds=50,
                              verbose_eval=100)
            oof_train[val_idx] += model.predict(x_val) / seed_num
            preds += model.predict(test_x) / folds / seed_num
           
#             print(model.best_score)
            scores.append(model.best_score['valid_1']['multi_error'])
            imp['gain' + str(fold + 1)] = model.feature_importance(importance_type='gain')
            imp['split' + str(fold + 1)] = model.feature_importance(importance_type='split')
            
            
            del x_trn, y_trn, x_val, y_val, model, train_set, val_set
            gc.collect()
    imp['gain'] = imp[[f for f in imp.columns if 'gain' in f]].sum(axis=1)/folds
    imp['split'] = imp[[f for f in imp.columns if 'split' in f]].sum(axis=1)
    imp = imp.sort_values(by=['gain'], ascending=False)
    imp[['feat', 'gain', 'split']]
    imp = imp.sort_values(by=['split'], ascending=False)
    print(imp[['feat', 'gain', 'split']])
    print("--------------------finished-------------------")
    return oof_train,preds

    
from scipy.stats import entropy    
def entropy_values(x):
    x = pd.Series(x)
    return entropy(x.value_counts() / x.shape[0])
    

def kurt(x):
    return pd.Series(x).kurt()


def mode(x):
    '''
    return the mode of x, if the mode is not unique, return the first one in the sequence.
    sample：
        a = [1,1,2,2,3]# 1
        b = [1,2,2,3]  # 2
        mode(a)
        mode(b)

    '''
    return pd.Series(x).mode()[0]


from scipy.stats import moment
def fourth_moment(x):
    '''sample:
        fourth_moment([1,2,3])#2.3907061857313376
    '''
    return moment(x,4)


def fifth_moment(x):
    '''sample:
        fifth_moment([1,2,3])#2.4703447490385586
    '''
    return moment(x,5)


def range_value(x):
    '''
    range(极差) of x,
    '''
    return x.max() - x.min()


def root_mean_square(x):
    '''
    root_mean_square
    sample:
        root_mean_square([1,2,3])#2.160246899469287
    '''
    return np.sqrt(np.mean(np.array(x) ** 2))

# %%
7 * 400 * 5 / 60 / 60
# Out:
# 3.888888888888889

# %%
# from tensorflow_addons.optimizers import AdamW
# import tensorflow

# %%
root_path  = '../data/final_data/'
data_train = pd.read_csv(root_path+'sensor_train_final.csv')
data_test = pd.read_csv(root_path+'sensor_test_final.csv')
sub = pd.read_csv(root_path+'submit_example.csv')
y = data_train.groupby('fragment_id')['behavior_id'].min()
data_test['fragment_id'] += 100000
label = 'behavior_id'
data = pd.concat([data_train, data_test], sort=False,ignore_index=True)
df = data.drop_duplicates(subset=['fragment_id']).reset_index(drop=True)[['fragment_id', 'behavior_id']]

data['acc'] = (data['acc_x'] ** 2 + data['acc_y'] ** 2 + data['acc_z'] ** 2) ** 0.5
data['accg'] = (data['acc_xg'] ** 2 + data['acc_yg'] ** 2 + data['acc_zg'] ** 2) ** 0.5

# %%
df = pd.read_pickle("one_stageANDoutlier.pkl")
df = df.fillna(0)
df.loc[:15000,"istrain"] = 1
df.loc[15000:,"istrain"] = 0
print(df.shape)
df.tail()
# Out:
# (31000, 249)
#        fragment_id  behavior_id  count  acc_x_min_x  acc_x_max_x  \
# 30995       115995          0.0    0.0        -0.42         0.26
# 30996       115996          0.0    0.0        -0.20         0.19
# 30997       115997          0.0    0.0        -0.85         1.24
# 30998       115998          0.0    0.0        -1.11         1.30
# 30999       115999          0.0    0.0        -0.36         0.86
#
#        acc_x_mean_x  acc_x_sum_x  acc_x_median_x  acc_x_skew_x  acc_x_kurt_x  \
# 30995      0.030000         1.26           0.040     -1.155347      4.060239
# 30996     -0.019615        -1.02           0.000      0.338360     -0.062589
# 30997     -0.043030        -1.42           0.070      0.270252     -0.184293
# 30998      0.488333         5.86           0.645     -1.041517      0.831268
# 30999      0.202857         5.68           0.245     -0.068749      0.724135
#
#        acc_x_mad_x  acc_x_std_x  acc_x_var_x  acc_x_mode_x  acc_x_min_y  \
# 30995     0.082381     0.120568     0.014537         -0.02        -0.42
# 30996     0.069527     0.087693     0.007690          0.00        -0.20
# 30997     0.416455     0.492681     0.242734         -0.47        -0.85
# 30998     0.543889     0.726834     0.528288         -1.11        -1.11
# 30999     0.199082     0.261277     0.068266         -0.00        -0.36
#
#        acc_x_max_y  acc_x_mean_y  acc_x_sum_y  acc_x_median_y  acc_x_skew_y  \
# 30995         0.26      0.030000         1.26           0.040     -1.155347
# 30996         0.19     -0.019615        -1.02           0.000      0.338360
# 30997         1.24     -0.043030        -1.42           0.070      0.270252
# 30998         1.30      0.488333         5.86           0.645     -1.041517
# 30999         0.86      0.202857         5.68           0.245     -0.068749
#
#        acc_x_kurt_y  acc_x_mad_y  acc_x_std_y  acc_x_var_y  acc_x_mode_y  \
# 30995      4.060239     0.082381     0.120568     0.014537         -0.02
# 30996     -0.062589     0.069527     0.087693     0.007690          0.00
# 30997     -0.184293     0.416455     0.492681     0.242734         -0.47
# 30998      0.831268     0.543889     0.726834     0.528288         -1.11
# 30999      0.724135     0.199082     0.261277     0.068266         -0.00
#
#        acc_x_q10  acc_x_q20  acc_x_q25  acc_x_q30  acc_x_q40  acc_x_q60  \
# 30995     -0.068     -0.020     -0.020     -0.017      0.014      0.056
# 30996     -0.100     -0.100     -0.100     -0.100     -0.000      0.000
# 30997     -0.632     -0.514     -0.470     -0.452     -0.176      0.218
# 30998     -0.440      0.120      0.175      0.290      0.532      0.746
# 30999     -0.192      0.016      0.085      0.121      0.150      0.302
#
#        acc_x_q70  acc_x_q75  acc_x_q80  acc_x_q90  acc_x_entropy_values  \
# 30995      0.080     0.0875      0.110      0.129              3.079604
# 30996      0.000     0.0000      0.000      0.100              1.269749
# 30997      0.264     0.2900      0.306      0.454              3.370481
# 30998      0.812     0.9225      1.126      1.272              2.484907
# 30999      0.319     0.3375      0.372      0.476              3.134162
#
#        acc_x_fourth_moment  acc_x_fifth_moment  acc_x_range_value  \
# 30995             0.001299           -0.000429               0.68
# 30996             0.000161            0.000011               0.39
# 30997             0.147705            0.087190               2.09
# 30998             0.717989           -0.877694               2.41
# 30999             0.014708            0.001242               1.22
#
#        acc_x_root_mean_square  acc_y_min  acc_y_max  acc_y_mean  acc_y_sum  \
# 30995                0.122843      -2.70      -0.03   -1.273333     -53.48
# 30996                0.089033      -0.21       0.10   -0.056154      -2.92
# 30997                0.487063      -0.80       1.38   -0.004242      -0.14
# 30998                0.850137      -0.80       0.21   -0.294167      -3.53
# 30999                0.327076      -2.99       3.20   -0.336429      -9.42
#
#        acc_y_median  acc_y_skew  acc_y_kurt  acc_y_mad  acc_y_std  acc_y_var  \
# 30995        -1.140   -0.157372   -1.447890   0.803810   0.927464   0.860189
# 30996        -0.100   -0.056058    0.003212   0.059527   0.067770   0.004593
# 30997         0.050    0.506520   -0.469534   0.466795   0.569298   0.324100
# 30998        -0.345    0.139250   -1.320155   0.280833   0.331511   0.109899
# 30999        -1.440    0.483284   -1.418456   1.938367   2.163115   4.679068
#
#        acc_y_mode  acc_y_q10  acc_y_q20  acc_y_q25  acc_y_q30  acc_y_q40  \
# 30995       -0.78     -2.509     -2.390     -2.295     -2.081     -1.350
# 30996       -0.10     -0.100     -0.100     -0.100     -0.100     -0.100
# 30997       -0.55     -0.648     -0.550     -0.530     -0.442     -0.236
# 30998       -0.10     -0.628     -0.590     -0.535     -0.507     -0.460
# 30999       -2.99     -2.472     -2.132     -2.015     -1.949     -1.858
#
#        acc_y_q60  acc_y_q70  acc_y_q75  acc_y_q80  acc_y_q90  \
# 30995     -0.962     -0.780    -0.2950     -0.240     -0.113
# 30996      0.000      0.000     0.0000      0.000      0.000
# 30997      0.118      0.200     0.3000      0.484      0.758
# 30998     -0.176     -0.100    -0.0500      0.060      0.100
# 30999      0.252      1.428     1.6875      2.250      2.798
#
#        acc_y_entropy_values  acc_y_fourth_moment  acc_y_fifth_moment  \
# 30995              3.473614             1.113574       -2.787120e-01
# 30996              1.042640             0.000059       -7.698790e-07
# 30997              3.412490             0.239242        1.776943e-01
# 30998              2.253858             0.017330        8.978297e-04
# 30999              3.332205            32.889730        6.207422e+01
#
#        acc_y_range_value  acc_y_root_mean_square  acc_z_min  acc_z_max  \
# 30995               2.67                1.568785      -2.94       2.93
# 30996               0.31                0.087508      -0.30       0.38
# 30997               2.18                0.560622      -1.34       1.89
# 30998               1.01                0.432753      -1.11       0.80
# 30999               6.19                2.150615      -6.37       2.57
#
#        acc_z_mean  acc_z_sum  acc_z_median  acc_z_skew  acc_z_kurt  acc_z_mad  \
# 30995   -0.027143      -1.14        -0.725    0.081919   -1.745561   2.102653
# 30996    0.060192       3.13         0.100   -0.126054   -0.156943   0.119416
# 30997   -0.045758      -1.51        -0.060    0.569539    1.535274   0.474674
# 30998   -0.003333      -0.04         0.050   -0.884650    2.361183   0.319444
# 30999   -1.555000     -43.54        -0.750   -0.189269   -1.566137   2.898929
#
#        acc_z_std  acc_z_var  acc_z_mode  acc_z_q10  acc_z_q20  acc_z_q25  \
# 30995   2.247834   5.052757       -2.94     -2.796     -2.096    -2.0500
# 30996   0.149174   0.022253        0.00     -0.100      0.000     0.0000
# 30997   0.651657   0.424656       -0.24     -0.744     -0.490    -0.3000
# 30998   0.470229   0.221115        0.00     -0.400     -0.268    -0.1525
# 30999   3.219680  10.366337       -6.37     -5.798     -5.308    -4.8475
#
#        acc_z_q30  acc_z_q40  acc_z_q60  acc_z_q70  acc_z_q75  acc_z_q80  \
# 30995     -1.904     -1.236      1.548      1.667     2.4775      2.618
# 30996      0.000     -0.000      0.100      0.100     0.1900      0.190
# 30997     -0.256     -0.230      0.042      0.174     0.2800      0.364
# 30998     -0.070      0.000      0.154      0.197     0.2000      0.200
# 30999     -3.778     -2.770      0.382      1.103     1.3000      1.774
#
#        acc_z_q90  acc_z_entropy_values  acc_z_fourth_moment  \
# 30995      2.756              3.737670            32.014559
# 30996      0.281              2.080830             0.001307
# 30997      0.784              3.328472             0.701314
# 30998      0.380              2.253858             0.165339
# 30999      2.413              3.332205           149.182903
#
#        acc_z_fifth_moment  acc_z_range_value  acc_z_root_mean_square  \
# 30995            8.060256               5.87                2.221079
# 30996           -0.000074               0.68                0.159525
# 30997            0.694882               3.23                0.643336
# 30998           -0.110628               1.91                0.450222
# 30999         -177.426510               8.94                3.523370
#
#        acc_xg_min  acc_xg_max  acc_xg_mean  acc_xg_sum  acc_xg_median  \
# 30995       -0.34        0.25     0.039524        1.66          0.030
# 30996       -0.21        0.20    -0.014423       -0.75          0.000
# 30997        3.01        4.78     3.900909      128.73          3.980
# 30998       -0.31        1.90     1.260833       15.13          1.495
# 30999       -0.38        0.72     0.083571        2.34          0.005
#
#        acc_xg_skew  acc_xg_kurt  acc_xg_mad  acc_xg_std  acc_xg_var  \
# 30995    -0.749734     1.537188    0.088073    0.117638    0.013839
# 30996     0.127732    -0.798854    0.092411    0.111644    0.012464
# 30997    -0.182168    -1.063342    0.428760    0.503055    0.253065
# 30998    -1.576728     2.109832    0.475556    0.657992    0.432954
# 30999     0.572749    -0.353579    0.237653    0.288909    0.083468
#
#        acc_xg_mode  acc_xg_q10  acc_xg_q20  acc_xg_q25  acc_xg_q30  \
# 30995         0.00      -0.087      -0.030       0.000       0.000
# 30996        -0.10      -0.100      -0.100      -0.100      -0.100
# 30997         3.77       3.166       3.404       3.450       3.644
# 30998        -0.31       0.370       1.040       1.150       1.230
# 30999        -0.13      -0.245      -0.130      -0.115      -0.078
#
#        acc_xg_q40  acc_xg_q60  acc_xg_q70  acc_xg_q75  acc_xg_q80  acc_xg_q90  \
# 30995       0.010       0.060       0.087      0.1375       0.140       0.180
# 30996      -0.100       0.000       0.070      0.1000       0.100       0.100
# 30997       3.770       4.088       4.228      4.3100       4.390       4.522
# 30998       1.368       1.550       1.577      1.6325       1.748       1.808
# 30999      -0.050       0.124       0.250      0.3100       0.316       0.493
#
#        acc_xg_entropy_values  acc_xg_fourth_moment  acc_xg_fifth_moment  \
# 30995               3.079604              0.000770            -0.000191
# 30996               1.587623              0.000323             0.000009
# 30997               3.412490              0.115296            -0.019631
# 30998               2.484907              0.608982            -0.848212
# 30999               3.183673              0.016193             0.005254
#
#        acc_xg_range_value  acc_xg_root_mean_square  acc_yg_min  acc_yg_max  \
# 30995                0.59                 0.122766        3.27        7.83
# 30996                0.41                 0.111502        5.37        5.80
# 30997                1.77                 3.932237       -1.81        1.06
# 30998                2.21                 1.409459        4.60        5.43
# 30999                1.10                 0.295756        3.64        7.65
#
#        acc_yg_mean  acc_yg_sum  acc_yg_median  acc_yg_skew  acc_yg_kurt  \
# 30995     6.030476      253.28           6.23    -0.357594    -1.476351
# 30996     5.631346      292.83           5.60    -0.241507     0.080886
# 30997    -0.568182      -18.75          -0.62     0.431908     0.146998
# 30998     4.924167       59.09           4.90     0.777095     0.549750
# 30999     5.736786      160.63           5.88    -0.092076    -1.616569
#
#        acc_yg_mad  acc_yg_std  acc_yg_var  acc_yg_mode  acc_yg_q10  \
# 30995    1.427528    1.606582    2.581107         4.67       3.751
# 30996    0.075784    0.092800    0.008612         5.60       5.500
# 30997    0.505510    0.634589    0.402703        -1.09      -1.324
# 30998    0.179861    0.234151    0.054827         4.70       4.700
# 30999    1.341786    1.491179    2.223615         3.64       3.753
#
#        acc_yg_q20  acc_yg_q25  acc_yg_q30  acc_yg_q40  acc_yg_q60  acc_yg_q70  \
# 30995       4.662      4.6750       4.710       5.918       7.134       7.509
# 30996       5.600      5.6000       5.600       5.600       5.690       5.697
# 30997      -1.096     -1.0900      -0.928      -0.758      -0.436      -0.336
# 30998       4.718      4.7675       4.793       4.836       4.952       5.001
# 30999       4.098      4.1475       4.481       5.086       6.458       6.918
#
#        acc_yg_q75  acc_yg_q80  acc_yg_q90  acc_yg_entropy_values  \
# 30995      7.6200       7.674       7.758               3.605642
# 30996      5.7000       5.700       5.710               1.743533
# 30997     -0.1300      -0.044       0.182               3.370481
# 30998      5.0325       5.082       5.172               2.369382
# 30999      7.0050       7.404       7.583               3.332205
#
#        acc_yg_fourth_moment  acc_yg_fifth_moment  acc_yg_range_value  \
# 30995              9.866486           -12.043733                4.56
# 30996              0.000211            -0.000018                0.43
# 30997              0.449721             0.309460                2.87
# 30998              0.007286             0.002467                0.83
# 30999              6.671682            -1.807493                4.01
#
#        acc_yg_root_mean_square  acc_zg_min  acc_zg_max  acc_zg_mean  \
# 30995                 6.235888      -12.07        8.37    -2.397143
# 30996                 5.632096        7.30        7.98     7.686923
# 30997                 0.844589        7.41       11.20     9.101515
# 30998                 4.929267        6.78        8.80     8.113333
# 30999                 5.920719       -8.98       12.33     3.332857
#
#        acc_zg_sum  acc_zg_median  acc_zg_skew  acc_zg_kurt  acc_zg_mad  \
# 30995     -100.68         -4.250     0.124290    -1.679985    7.155034
# 30996      399.72          7.700    -0.589012     0.322181    0.120710
# 30997      300.35          8.990     0.607462     1.316916    0.544261
# 30998       97.36          8.145    -1.478408     3.381612    0.353333
# 30999       93.32          5.610    -0.338671    -1.532488    7.040306
#
#        acc_zg_std  acc_zg_var  acc_zg_mode  acc_zg_q10  acc_zg_q20  \
# 30995    7.767172   60.328957       -12.07     -11.744      -9.888
# 30996    0.166516    0.027728         7.70       7.410       7.592
# 30997    0.762000    0.580645         8.78       8.350       8.646
# 30998    0.522395    0.272897         8.09       7.709       7.910
# 30999    7.894310   62.320125        -8.98      -8.180      -5.432
#
#        acc_zg_q25  acc_zg_q30  acc_zg_q40  acc_zg_q60  acc_zg_q70  acc_zg_q75  \
# 30995     -9.8475      -9.358      -5.960       1.790       3.167      6.3075
# 30996      7.6000       7.631       7.690       7.710       7.780      7.7925
# 30997      8.7100       8.760       8.930       9.116       9.264      9.2700
# 30998      7.9925       8.048       8.090       8.260       8.370      8.4250
# 30999     -3.7100      -3.154       1.868       8.588      10.159     10.7900
#
#        acc_zg_q80  acc_zg_q90  acc_zg_entropy_values  acc_zg_fourth_moment  \
# 30995       6.516       7.460               3.737670           4765.216292
# 30996       7.808       7.889               2.966517              0.002351
# 30997       9.560       9.962               3.370481              1.251993
# 30998       8.480       8.590               2.369382              0.292035
# 30999      11.246      12.135               3.332205           5492.566363
#
#        acc_zg_fifth_moment  acc_zg_range_value  acc_zg_root_mean_square  \
# 30995          9126.113954               20.44                 8.039829
# 30996            -0.000466                0.68                 7.688692
# 30997             1.079255                3.79                 9.132394
# 30998            -0.336459                2.02                 8.128735
# 30999        -29193.955349               21.31                 8.438148
#
#         acc_min   acc_max  acc_mean     acc_sum  acc_median  acc_skew  \
# 30995  2.067172  3.101677  2.714056  113.990366    2.755744 -0.993112
# 30996  0.000000  0.405463  0.180770    9.400044    0.173205  0.606284
# 30997  0.173494  1.915907  0.909160   30.002273    0.855628  0.452667
# 30998  0.253180  1.807595  0.945573   11.346871    0.771877  0.657552
# 30999  0.900389  6.766639  3.754227  105.118367    3.661923  0.182361
#
#        acc_kurt   acc_mad   acc_std   acc_var  acc_mode   acc_q10   acc_q20  \
# 30995  1.153936  0.161438  0.210524  0.044320  2.067172  2.445518  2.578698
# 30996  0.575158  0.068935  0.092297  0.008519  0.141421  0.100000  0.108284
# 30997  0.522964  0.291618  0.378386  0.143176  0.173494  0.511154  0.642047
# 30998 -0.536121  0.397842  0.488338  0.238474  0.253180  0.478952  0.666329
# 30999 -1.166339  1.463692  1.779065  3.165072  0.900389  1.706387  1.932788
#
#         acc_q25   acc_q30   acc_q40   acc_q60   acc_q70   acc_q75   acc_q80  \
# 30995  2.618895  2.659065  2.707259  2.807241  2.833159  2.857354  2.869793
# 30996  0.141421  0.141421  0.141421  0.173205  0.207000  0.223607  0.234205
# 30997  0.672309  0.707420  0.789734  0.981981  1.079361  1.099318  1.133393
# 30998  0.669417  0.681706  0.722016  0.847272  1.165730  1.303858  1.337587
# 30999  2.006803  2.194721  3.394338  4.029079  4.736505  5.239745  5.734653
#
#         acc_q90  acc_entropy_values  acc_fourth_moment  acc_fifth_moment  \
# 30995  2.913434            3.737670           0.007266         -0.003165
# 30996  0.323833            2.425464           0.000238          0.000022
# 30997  1.450973            3.496508           0.063043          0.026241
# 30998  1.686017            2.484907           0.105180          0.048759
# 30999  6.156606            3.332205          16.998574         10.642514
#
#        acc_range_value  acc_root_mean_square  accg_min   accg_max  accg_mean  \
# 30995         1.034505              2.722015  7.259043  12.525358  10.024395
# 30996         0.405463              0.202565  9.263908   9.748867   9.530791
# 30997         1.742414              0.982552  8.824517  11.837652   9.957521
# 30998         1.554415              1.054850  8.487721  10.253780   9.599893
# 30999         5.866250              4.140804  6.848518  12.887839  10.110741
#
#          accg_sum  accg_median  accg_skew  accg_kurt  accg_mad  accg_std  \
# 30995  421.024590    10.304351  -0.229264  -1.296185  1.492513  1.768093
# 30996  495.601150     9.536199  -0.361843  -0.221194  0.090253  0.114844
# 30997  328.598181     9.826424   0.951426   1.094224  0.491078  0.661427
# 30998  115.198716     9.683714  -1.195047   1.889222  0.344000  0.470169
# 30999  283.100739    10.290701  -0.243415  -1.416767  1.781672  2.066435
#
#        accg_var  accg_mode  accg_q10  accg_q20  accg_q25  accg_q30   accg_q40  \
# 30995  3.126152   7.259043  7.515121  7.963817  8.094057  8.476993  10.054233
# 30996  0.013189   9.440869  9.364149  9.440869  9.440869  9.475816   9.521239
# 30997  0.437485   8.824517  9.266273  9.438087  9.532649  9.686926   9.760918
# 30998  0.221059   8.487721  9.094702  9.393965  9.484650  9.528344   9.545090
# 30999  4.270153   6.848518  7.231384  7.769768  8.109839  8.446073   9.947686
#
#         accg_q60   accg_q70   accg_q75   accg_q80   accg_q90  \
# 30995  10.752559  10.977186  11.372029  11.426706  12.306900
# 30996   9.563909   9.600323   9.607705   9.620146   9.668657
# 30997   9.927351  10.042709  10.227189  10.470311  10.689017
# 30998   9.823437   9.870456   9.898267   9.926156   9.945631
# 30999  11.227967  11.583266  11.699978  12.042143  12.677249
#
#        accg_entropy_values  accg_fourth_moment  accg_fifth_moment  \
# 30995             3.737670           15.958076          -9.408191
# 30996             3.737968            0.000449          -0.000042
# 30997             3.496508            0.676479           0.851468
# 30998             2.484907            0.153058          -0.134523
# 30999             3.332205           27.416071         -24.440577
#
#        accg_range_value  accg_root_mean_square  acc_time_diff_min  \
# 30995          5.266316              10.175471              -85.0
# 30996          0.484958               9.531470              -97.0
# 30997          3.013135               9.978800              -94.0
# 30998          1.766059               9.610441              -90.0
# 30999          6.039321              10.312358              -85.0
#
#        acc_time_diff_max  acc_time_diff_mean  acc_time_diff_sum  \
# 30995              -82.0          -83.341463            -3417.0
# 30996              -79.0          -86.137255            -4393.0
# 30997              -83.0          -85.312500            -2730.0
# 30998              -81.0          -85.090909             -936.0
# 30999              -82.0          -83.333333            -2250.0
#
#        acc_time_diff_median  acc_time_diff_skew  acc_time_diff_kurt  \
# 30995                 -83.0           -0.310965            0.172704
# 30996                 -85.0           -0.319761           -0.381380
# 30997                 -85.0           -2.671416            9.158799
# 30998                 -85.0           -0.252386           -0.760410
# 30999                 -83.0           -0.213470           -0.627438
#
#        acc_time_diff_mad  acc_time_diff_std  acc_time_diff_var  \
# 30995           0.530637           0.616837           0.380488
# 30996           3.523260           4.223835          17.840784
# 30997           1.363281           2.085859           4.350806
# 30998           2.297521           2.981763           8.890909
# 30999           0.765432           0.919866           0.846154
#
#        acc_time_diff_mode  acc_time_diff_q10  acc_time_diff_q20  \
# 30995               -83.0              -84.0              -84.0
# 30996               -90.0              -91.0              -90.0
# 30997               -85.0              -87.0              -86.6
# 30998               -85.0              -89.0              -88.0
# 30999               -83.0              -84.4              -84.0
#
#        acc_time_diff_q25  acc_time_diff_q30  acc_time_diff_q40  \
# 30995              -84.0              -84.0              -83.0
# 30996              -90.0              -89.0              -87.0
# 30997              -85.0              -85.0              -85.0
# 30998              -87.0              -86.0              -85.0
# 30999              -84.0              -84.0              -83.6
#
#        acc_time_diff_q60  acc_time_diff_q70  acc_time_diff_q75  \
# 30995              -83.0              -83.0              -83.0
# 30996              -85.0              -83.0              -83.0
# 30997              -84.4              -84.0              -84.0
# 30998              -84.0              -84.0              -83.5
# 30999              -83.0              -83.0              -83.0
#
#        acc_time_diff_q80  acc_time_diff_q90  acc_time_diff_entropy_values  \
# 30995              -83.0              -83.0                      0.918294
# 30996              -83.0              -80.0                      2.597438
# 30997              -84.0              -84.0                      1.428769
# 30998              -83.0              -81.0                      2.019815
# 30999              -83.0              -82.0                      1.282674
#
#        acc_time_diff_fourth_moment  acc_time_diff_fifth_moment  \
# 30995                          0.0                         0.0
# 30996                          0.0                         0.0
# 30997                          0.0                         0.0
# 30998                          0.0                         0.0
# 30999                          0.0                         0.0
#
#        acc_time_diff_range_value  acc_time_diff_root_mean_square  istrain
# 30995                        3.0                             0.0        0
# 30996                       18.0                             0.0        0
# 30997                       11.0                             0.0        0
# 30998                        9.0                             0.0        0
# 30999                        3.0                             0.0        0

# %%
data = data.sort_values(['fragment_id','time_point'],ascending=False)
# data = data.set_index(['fragment_id','time_point'])
data['acc_time_diff'] = data.groupby(["fragment_id"])["time_point"].diff(1)
data['acc_time_diff2'] = data.groupby(["fragment_id"])["time_point"].diff(2)
data['acc_time_diff3'] = data.groupby(["fragment_id"])["time_point"].diff(3)

data['acc_xg_diff1'] = data.groupby(["fragment_id"])["acc_xg"].diff(1)
data['acc_yg_diff1'] = data.groupby(["fragment_id"])["acc_yg"].diff(1)

# data = data.reset_index()

all_stat_funtion = ['min', 'max', 'mean','sum', 'median',"skew",kurt, 'mad','std','var',\
                    q10, q20, q25, q30, q40, q60, q70, q75, q80, q90,\
                    entropy_values,range_value,root_mean_square]
all_stat_name = ['min', 'max', 'mean','sum','median',"skew",'kurt', 'mad','std','var',\
                 'q10', 'q20', 'q25', 'q30', 'q40', 'q60', 'q70', 'q75', 'q80', 'q90',\
                 'entropy_values',"range_value","root_mean_square"]

# oral_item = ["acc_x","acc_y","acc_z","acc_xg","acc_yg","acc_zg","acc","accg","acc_time_diff"]
second_item = ["acc_time_diff2","acc_time_diff3","time_point"]
# stat_cols =["acc","accg","xy","xy_g",\
#             "x/xy","y/xy","x/xy__g","y/xy__g",\
#             "acc_x","acc_y","acc_z","acc_xg","acc_yg","acc_zg",\
#             "g_x","g_y","g_z",\
#             'acc_xy/acc',"acc_xyg/g",\
#             "acc_xg/g",'acc_yg/g','acc_zg/g','acc_x/acc','acc_y/acc','acc_z/acc'\
#            ]

for item in tqdm(second_item):
    for name,i in zip(all_stat_name,all_stat_funtion):
        print(item+"_"+name)
        df = df.merge(data.groupby(["fragment_id"])[item].agg(i).reset_index().rename(columns={item:item+"_"+name}),on='fragment_id',how='left')
df.head()
# df["time_count"] = df.merge(d/"ata.groupby("fragment_id")["acc"].count(),on='fragment_id',how='left')
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# acc_time_diff2_min
# acc_time_diff2_max
# acc_time_diff2_mean
# acc_time_diff2_sum
# acc_time_diff2_median
# acc_time_diff2_skew
# acc_time_diff2_kurt
# acc_time_diff2_mad
# acc_time_diff2_std
# acc_time_diff2_var
# acc_time_diff2_q10
# acc_time_diff2_q20
# acc_time_diff2_q25
# acc_time_diff2_q30
# acc_time_diff2_q40
# acc_time_diff2_q60
# acc_time_diff2_q70
# acc_time_diff2_q75
# acc_time_diff2_q80
# acc_time_diff2_q90
# acc_time_diff2_entropy_values
# acc_time_diff2_range_value
# acc_time_diff2_root_mean_square
#  33%|███▎      | 1/3 [03:14<06:28, 194.17s/it]
# acc_time_diff3_min
# acc_time_diff3_max
# acc_time_diff3_mean
# acc_time_diff3_sum
# acc_time_diff3_median
# acc_time_diff3_skew
# acc_time_diff3_kurt
# acc_time_diff3_mad
# acc_time_diff3_std
# acc_time_diff3_var
# acc_time_diff3_q10
# acc_time_diff3_q20
# acc_time_diff3_q25
# acc_time_diff3_q30
# acc_time_diff3_q40
# acc_time_diff3_q60
# acc_time_diff3_q70
# acc_time_diff3_q75
# acc_time_diff3_q80
# acc_time_diff3_q90
# acc_time_diff3_entropy_values
# acc_time_diff3_range_value
# acc_time_diff3_root_mean_square
#  67%|██████▋   | 2/3 [06:26<03:13, 193.50s/it]
# time_point_min
# time_point_max
# time_point_mean
# time_point_sum
# time_point_median
# time_point_skew
# time_point_kurt
# time_point_mad
# time_point_std
# time_point_var
# time_point_q10
# time_point_q20
# time_point_q25
# time_point_q30
# time_point_q40
# time_point_q60
# time_point_q70
# time_point_q75
# time_point_q80
# time_point_q90
# time_point_entropy_values

# %%
df["count"] = data.groupby("fragment_id")["time_point"].count().values
train_df = df[df["istrain"]==1].reset_index(drop=True)
test_df = df[df["istrain"]==0].reset_index(drop=True)

sns.distplot(train_df["count"])
plt.show()
sns.distplot(test_df["count"])
plt.show()

drop_feat = ["istrain"] 
used_feat = [f for f in train_df.columns if f not in (['fragment_id', label] + drop_feat)]
# used_feat = ["count"]
print(used_feat)
# df["istrain"] = (df[label].isna()==False).astype(np.int8)
result_dict = get_feature_report_by_covariate_shift_test(df,
                                               features=used_feat,
                                               all_cate_feas=[],
                                               params=None,
                                               nfold=3,
                                               y2test='istrain',
                                               train_all_feas=False)

result_df = result_dict["df_fea_auc"]
drop_bylgb = list(result_df[result_df["val_auc"] > 0.6]["feat"])
result_df

# %%
train_df = df[df["istrain"]==1].reset_index(drop=True)
test_df = df[df["istrain"]==0].reset_index(drop=True)

drop_feat = drop_bylgb
used_feat = [f for f in train_df.columns if f not in (['fragment_id', label] + drop_feat)]
print(len(used_feat))
print(used_feat)

train_x = train_df[used_feat]
train_y = train_df[label]
test_x = test_df[used_feat]
print()

# %%
scores = []
imp = pd.DataFrame()
imp['feat'] = used_feat

params = {
    'learning_rate': 0.1,
    'metric': 'multi_error',
    'objective': 'multiclass',
    'num_class': 20,
    'feature_fraction': 0.80,
    'bagging_fraction': 0.75,
    'bagging_freq': 2,
    'n_jobs': 20,
    'seed': 2020,
    'max_depth': 10,
    'num_leaves': 64,
    'lambda_l1': 0.5,
    'lambda_l2': 0.5,
}

oof_train = np.zeros((len(train_x), 20))
preds = np.zeros((len(test_x), 20))
folds = 5
seeds = [44, 2020, 527, 1527][:1]
for seed in seeds:
    kfold = StratifiedKFold(n_splits=folds, shuffle=True, random_state=seed)
    for fold, (trn_idx, val_idx) in enumerate(kfold.split(train_x, train_y)):
        x_trn, y_trn, x_val, y_val = train_x.iloc[trn_idx], train_y.iloc[trn_idx], train_x.iloc[val_idx], train_y.iloc[val_idx]
        train_set = lgb.Dataset(x_trn, y_trn)
        val_set = lgb.Dataset(x_val, y_val)

        model = lgb.train(params, train_set, num_boost_round=500000,
                          valid_sets=(train_set, val_set), early_stopping_rounds=50,
                          verbose_eval=20)
        oof_train[val_idx] += model.predict(x_val) / len(seeds)
        preds += model.predict(test_x) / folds / len(seeds)
        scores.append(model.best_score['valid_1']['multi_error'])
        imp['gain' + str(fold + 1)] = model.feature_importance(importance_type='gain')
        imp['split' + str(fold + 1)] = model.feature_importance(importance_type='split')
        del x_trn, y_trn, x_val, y_val, model, train_set, val_set
        gc.collect()

# %%
imp['gain'] = imp[[f for f in imp.columns if 'gain' in f]].sum(axis=1)/folds
imp['split'] = imp[[f for f in imp.columns if 'split' in f]].sum(axis=1)
imp = imp.sort_values(by=['gain'], ascending=False)
imp[['feat', 'gain', 'split']]
imp = imp.sort_values(by=['split'], ascending=False)
imp[['feat', 'gain', 'split']]
# Out:
#                                 feat          gain  split
# 150                       acc_zg_std  12365.600402    965
# 115          acc_xg_root_mean_square  10678.050075   7336
# 117                       acc_yg_max  10503.568065   4724
# 116                       acc_yg_min   6804.334383   5171
# 142                       acc_zg_min   6543.674395   4634
# 127                       acc_yg_q10   6301.817444   3621
# 136                       acc_yg_q90   5125.719654   3016
# 141          acc_yg_root_mean_square   4883.293576   3247
# 149                       acc_zg_mad   4748.137324   1241
# 153                       acc_zg_q10   4389.820936   3978
# 8                        acc_x_mad_x   4378.002350   1404
# 232                acc_time_diff_q20   4172.798160   1840
# 110                       acc_xg_q90   3671.754151   3455
# 91                        acc_xg_max   3668.350208   5140
# 63            acc_y_root_mean_square   3428.448386   1423
# 90                        acc_xg_min   3209.018276   4496
# 233                acc_time_diff_q25   3204.524835   1316
# 144                      acc_zg_mean   2796.818094   2365
# 219            accg_root_mean_square   2740.950388   3370
# 59              acc_y_entropy_values   2638.511763   4110
# 180                          acc_q20   2602.556735   1394
# 154                       acc_zg_q20   2526.843558   2466
# 162                       acc_zg_q90   2510.971135   2635
# 161                       acc_zg_q80   2447.021111   1974
# 196                        accg_mean   2442.878550   4254
# 179                          acc_q10   2402.160722   2031
# 135                       acc_yg_q80   2334.734919   1731
# 101                       acc_xg_q10   2222.623330   3389
# 40                        acc_y_mean   1978.330304   4120
# 155                       acc_zg_q25   1900.622113   1995
# 151                       acc_zg_var   1895.502887    209
# 128                       acc_yg_q20   1840.692365   2105
# 268               acc_time_diff2_q20   1780.917467   1346
# 209                         accg_q40   1659.030880   4047
# 143                       acc_zg_max   1655.831267   3121
# 166               acc_zg_range_value   1655.110507    925
# 109                       acc_xg_q80   1640.698325   2083
# 19                       acc_x_mad_y   1612.229571    246
# 241     acc_time_diff_entropy_values   1548.110370   3972
# 276               acc_time_diff2_q90   1536.957826   2439
# 167          acc_zg_root_mean_square   1512.029303   1529
# 129                       acc_yg_q25   1497.389325   1697
# 49                         acc_y_q10   1450.368381   1704
# 152                      acc_zg_mode   1444.910967   4244
# 240                acc_time_diff_q90   1443.469214   3530
# 118                      acc_yg_mean   1392.810318   1920
# 126                      acc_yg_mode   1372.840663   2916
# 133                       acc_yg_q70   1358.045294   1541
# 134                       acc_yg_q75   1348.570608   1532
# 275               acc_time_diff2_q80   1338.728186   1390
# 211                         accg_q70   1302.545401   2473
# 269               acc_time_diff2_q25   1299.857998   1070
# 156                       acc_zg_q30   1288.836727   1938
# 102                       acc_xg_q20   1244.437769   1827
# 208                         accg_q30   1234.112753   2965
# 45                         acc_y_mad   1168.986514   1676
# 106                       acc_xg_q60   1159.542543   1764
# 100                      acc_xg_mode   1155.780251   3186
# 160                       acc_zg_q75   1135.738957   1719
# 181                          acc_q25   1097.805828   1011
# 97                        acc_xg_mad   1083.997966   2148
# 120                    acc_yg_median   1078.294501   1763
# 130                       acc_yg_q30   1055.419773   1468
# 131                       acc_yg_q40   1044.180806   1287
# 239                acc_time_diff_q80   1034.650438   2051
# 66                        acc_z_mean   1032.116136   3132
# 157                       acc_zg_q40   1024.966251   1886
# 207                         accg_q25   1024.569803   2477
# 52                         acc_y_q30   1024.459538   1693
# 300               acc_time_diff3_q80   1019.741128   1688
# 182                          acc_q30   1004.094308   1070
# 33              acc_x_entropy_values    993.933775   2806
# 57                         acc_y_q80    991.578457   1758
# 93                        acc_xg_sum    989.578725   4196
# 92                       acc_xg_mean    966.644035   1939
# 107                       acc_xg_q70    950.669175   1754
# 50                         acc_y_q20    950.535239   1707
# 198                      accg_median    936.001473   3766
# 237                acc_time_diff_q70    915.384478   1735
# 105                       acc_xg_q40    912.256030   1503
# 37            acc_x_root_mean_square    856.749676    851
# 301               acc_time_diff3_q90    850.646721   2179
# 210                         accg_q60    848.394953   2920
# 164             acc_zg_fourth_moment    840.405397    848
# 274               acc_time_diff2_q75    838.933981   1164
# 108                       acc_xg_q75    836.669567   1724
# 238                acc_time_diff_q75    835.122617   1230
# 146                    acc_zg_median    825.043809   1896
# 58                         acc_y_q90    821.190849   2257
# 94                     acc_xg_median    814.240587   1670
# 159                       acc_zg_q70    813.521922   1790
# 41                         acc_y_sum    799.722516   3448
# 119                       acc_yg_sum    793.442927   3670
# 55                         acc_y_q70    792.765969   1768
# 183                          acc_q40    783.998385    940
# 302    acc_time_diff3_entropy_values    771.051865   2905
# 234                acc_time_diff_q30    757.725334   1681
# 212                         accg_q75    739.862198   1777
# 206                         accg_q20    733.740891   2294
# 132                       acc_yg_q60    728.625014   1477
# 123                       acc_yg_mad    718.041696   2076
# 56                         acc_y_q75    716.805099   1591
# 231                acc_time_diff_q10    698.974631   1848
# 104                       acc_xg_q30    698.545874   1355
# 205                         accg_q10    695.081522   2312
# 124                       acc_yg_std    694.769077   1712
# 158                       acc_zg_q60    691.202460   1832
# 51                         acc_y_q25    691.160240   1331
# 213                         accg_q80    690.506497   1868
# 225               acc_time_diff_skew    680.298537   3952
# 53                         acc_y_q40    664.391647   1834
# 214                         accg_q90    662.242426   1999
# 98                        acc_xg_std    641.470882   1392
# 288              acc_time_diff3_kurt    627.924028   4036
# 168                          acc_min    620.142097   1886
# 270               acc_time_diff2_q30    605.217033   1277
# 103                       acc_xg_q25    589.835227   1487
# 299               acc_time_diff3_q75    588.783508   1088
# 82                         acc_z_q75    581.890388   1161
# 80                         acc_z_q60    580.083851   1705
# 67                         acc_z_sum    574.128348   3342
# 7                       acc_x_kurt_x    556.974934   3761
# 222               acc_time_diff_mean    553.839537   2163
# 44                        acc_y_kurt    553.682485   4013
# 31                         acc_x_q80    550.282796   1674
# 221                acc_time_diff_max    547.366897   1754
# 85              acc_z_entropy_values    544.828258   2357
# 340                 acc_yg_diff1_std    534.086115   1216
# 298               acc_time_diff3_q70    533.824986   1356
# 3                       acc_x_mean_x    521.689579   2759
# 235                acc_time_diff_q40    516.842011   1480
# 75                         acc_z_q10    513.473252   1550
# 277    acc_time_diff2_entropy_values    511.879857   2880
# 172                       acc_median    503.783788    756
# 339                 acc_yg_diff1_mad    500.386217    950
# 267               acc_time_diff2_q10    488.241961   1743
# 178                         acc_mode    480.346496   2541
# 54                         acc_y_q60    472.957343   2019
# 315                 acc_xg_diff1_std    462.023466   1201
# 272               acc_time_diff2_q60    461.492322   1267
# 76                         acc_z_q20    457.159499   1448
# 244        acc_time_diff_range_value    456.866719    918
# 29                         acc_x_q70    453.434458   1579
# 227                acc_time_diff_mad    442.645965   2222
# 251          acc_time_diff2_median_x    437.929631    553
# 138             acc_yg_fourth_moment    431.246183   1377
# 26                         acc_x_q30    425.430511   1692
# 122                      acc_yg_kurt    425.148401   4138
# 9                        acc_x_std_x    423.848399    688
# 71                         acc_z_mad    413.736390    851
# 70                        acc_z_kurt    410.411917   3201
# 249            acc_time_diff2_mean_x    401.716358   1655
# 314                 acc_xg_diff1_mad    397.862308    953
# 139              acc_yg_fifth_moment    395.293082   2702
# 30                         acc_x_q75    395.287952   1429
# 46                         acc_y_std    393.062826    865
# 338                acc_yg_diff1_kurt    389.935114   3430
# 24                         acc_x_q20    386.414551   1463
# 121                      acc_yg_skew    385.930138   3392
# 200                        accg_kurt    385.773954   3141
# 325                 acc_xg_diff1_q80    381.356484   1623
# 112             acc_xg_fourth_moment    377.814904   1217
# 292               acc_time_diff3_q10    374.982636   1479
# 96                       acc_xg_kurt    364.467163   3699
# 273               acc_time_diff2_q70    364.394545   1424
# 295               acc_time_diff3_q30    363.637411   1125
# 226               acc_time_diff_kurt    358.608693   3264
# 204                        accg_mode    358.517714   2240
# 342                 acc_yg_diff1_q10    357.590799   1630
# 27                         acc_x_q40    355.374481   1739
# 113              acc_xg_fifth_moment    351.482574   2428
# 28                         acc_x_q60    347.831202   1772
# 4                        acc_x_sum_x    347.616404   2899
# 86               acc_z_fourth_moment    346.900497    681
# 284              acc_time_diff3_mean    346.776115   1613
# 42                      acc_y_median    345.441178   1617
# 289               acc_time_diff3_mad    345.071126   1924
# 313                acc_xg_diff1_kurt    343.439247   3347
# 228                acc_time_diff_std    342.193906   1892
# 253            acc_time_diff2_kurt_x    341.352491   3198
# 43                        acc_y_skew    340.902304   3394
# 335                 acc_yg_diff1_sum    339.823375   2670
# 79                         acc_z_q40    339.077697   1855
# 25                         acc_x_q25    335.660369   1370
# 309                acc_xg_diff1_mean    334.587872   2349
# 252            acc_time_diff2_skew_x    334.202271   3290
# 137            acc_yg_entropy_values    328.105714   2244
# 170                         acc_mean    328.015998    458
# 293               acc_time_diff3_q20    327.493629   1138
# 6                       acc_x_skew_x    326.695711   3307
# 337                acc_yg_diff1_skew    325.615906   3602
# 194                         accg_min    325.366652   1557
# 111            acc_xg_entropy_values    324.805431   2231
# 74                        acc_z_mode    320.770473   2257
# 297               acc_time_diff3_q60    319.103721   1100
# 334                acc_yg_diff1_mean    318.309896   2332
# 317                 acc_xg_diff1_q10    317.342999   1642
# 148                      acc_zg_kurt    317.256682   2899
# 310                 acc_xg_diff1_sum    316.582325   2666
# 60               acc_y_fourth_moment    314.784757    912
# 184                          acc_q60    314.302736    524
# 173                         acc_skew    314.091495   2811
# 355         acc_yg_diff1_range_value    310.304449   1151
# 322                 acc_xg_diff1_q60    306.961705   2358
# 332                 acc_yg_diff1_min    304.798540   1502
# 248             acc_time_diff2_max_x    303.674036   1276
# 78                         acc_z_q30    302.249132   1514
# 147                      acc_zg_skew    302.134767   3040
# 95                       acc_xg_skew    299.910689   3304
# 324                 acc_xg_diff1_q75    294.558029   1525
# 69                        acc_z_skew    293.339721   2827
# 351                 acc_yg_diff1_q90    293.159690   1611
# 84                         acc_z_q90    292.632509   1446
# 236                acc_time_diff_q60    292.629357   1123
# 287              acc_time_diff3_skew    289.736054   3188
# 294               acc_time_diff3_q25    289.659431    986
# 61                acc_y_fifth_moment    288.953441   2368
# 23                         acc_x_q10    288.240111   1401
# 114               acc_xg_range_value    287.946108   1130
# 174                         acc_kurt    287.097502   3024
# 312                acc_xg_diff1_skew    286.112541   3474
# 348                 acc_yg_diff1_q70    284.259802   1922
# 307                 acc_xg_diff1_min    280.736473   1494
# 81                         acc_z_q70    279.706651   1488
# 32                         acc_x_q90    279.156543   1470
# 346                 acc_yg_diff1_q40    278.912746   2065
# 326                 acc_xg_diff1_q90    277.240680   1521
# 296               acc_time_diff3_q40    275.697214   1099
# 347                 acc_yg_diff1_q60    272.087450   2426
# 323                 acc_xg_diff1_q70    271.012900   1778
# 254             acc_time_diff2_mad_x    271.008135   1783
# 87                acc_z_fifth_moment    270.395571   2146
# 35                acc_x_fifth_moment    267.308976   2016
# 345                 acc_yg_diff1_q30    265.471048   1670
# 199                        accg_skew    264.687799   2552
# 38                         acc_y_min    263.595387   1134
# 224             acc_time_diff_median    263.351235    829
# 89            acc_z_root_mean_square    260.925098    589
# 77                         acc_z_q25    259.933477   1359
# 286            acc_time_diff3_median    259.733773    605
# 283               acc_time_diff3_max    259.142423   1198
# 320                 acc_xg_diff1_q30    256.966316   1884
# 145                       acc_zg_sum    256.613260   2354
# 163            acc_zg_entropy_values    255.504099   1993
# 321                 acc_xg_diff1_q40    253.926380   2146
# 271               acc_time_diff2_q40    251.649361   1144
# 185                          acc_q70    250.689531    477
# 349                 acc_yg_diff1_q75    250.687670   1559
# 333                 acc_yg_diff1_max    250.375982   1439
# 350                 acc_yg_diff1_q80    246.438558   1567
# 5                     acc_x_median_x    245.424405   1456
# 195                         accg_max    242.514800   1342
# 191                 acc_fifth_moment    242.085960   1699
# 165              acc_zg_fifth_moment    240.314604   2036
# 318                 acc_xg_diff1_q20    238.373434   1302
# 336              acc_yg_diff1_median    237.532936   2095
# 83                         acc_z_q80    233.352149   1206
# 230               acc_time_diff_mode    232.669318   1602
# 68                      acc_z_median    232.480499   1653
# 176                          acc_std    229.627032    721
# 140               acc_yg_range_value    228.230958   1145
# 343                 acc_yg_diff1_q20    226.306753   1510
# 308                 acc_xg_diff1_max    222.223922   1361
# 217                accg_fifth_moment    221.192697   1882
# 330         acc_xg_diff1_range_value    221.184721   1066
# 189               acc_entropy_values    213.103322   1367
# 64                         acc_z_min    212.397685   1082
# 202                         accg_std    211.027524    778
# 39                         acc_y_max    209.689460   1232
# 48                        acc_y_mode    207.633402   1859
# 72                         acc_z_std    207.209754    586
# 311              acc_xg_diff1_median    206.451710   2285
# 290               acc_time_diff3_std    204.894573   1372
# 344                 acc_yg_diff1_q25    196.229450   1340
# 255             acc_time_diff2_std_x    190.788903   1394
# 216               accg_fourth_moment    189.689008    737
# 201                         accg_mad    189.029185    902
# 34               acc_x_fourth_moment    184.621319    811
# 316                 acc_xg_diff1_var    180.402232    237
# 319                 acc_xg_diff1_q25    175.315070   1374
# 187                          acc_q80    174.287462    478
# 2                        acc_x_max_x    167.863688   1041
# 352      acc_yg_diff1_entropy_values    164.620206   1641
# 11                      acc_x_mode_x    162.124889   1866
# 190                acc_fourth_moment    159.138635    677
# 193             acc_root_mean_square    157.971001    358
# 175                          acc_mad    150.264441    873
# 327      acc_xg_diff1_entropy_values    148.670639   1518
# 62                 acc_y_range_value    139.240394    694
# 1                        acc_x_min_x    138.476742   1006
# 125                       acc_yg_var    136.482222    383
# 188                          acc_q90    132.709938    511
# 65                         acc_z_max    132.484548    854
# 171                          acc_sum    132.453860   1007
# 218                 accg_range_value    129.167113    773
# 99                        acc_xg_var    125.338199    298
# 36                 acc_x_range_value    124.183096    600
# 305       acc_time_diff3_range_value    124.137492    754
# 47                         acc_y_var    112.850885    219
# 10                       acc_x_var_x    110.312844    178
# 169                          acc_max    108.135854    464
# 186                          acc_q75    104.824136    396
# 88                 acc_z_range_value     99.585998    574
# 229                acc_time_diff_var     96.200897    696
# 192                  acc_range_value     94.657260    597
# 18                      acc_x_kurt_y     93.480839    784
# 14                      acc_x_mean_y     89.648763    481
# 282               acc_time_diff3_min     89.067431    802
# 197                         accg_sum     88.517803    869
# 280       acc_time_diff2_range_value     85.617979    684
# 223                acc_time_diff_sum     83.975084    841
# 263            acc_time_diff2_kurt_y     79.939704    689
# 259            acc_time_diff2_mean_y     77.681912    350
# 262            acc_time_diff2_skew_y     77.432632    613
# 220                acc_time_diff_min     76.247406    623
# 15                       acc_x_sum_y     72.958210    619
# 291               acc_time_diff3_var     69.054052    524
# 247             acc_time_diff2_min_x     67.481994    582
# 177                          acc_var     59.616936    181
# 17                      acc_x_skew_y     55.336473    646
# 341                 acc_yg_diff1_var     55.170227    216
# 264             acc_time_diff2_mad_y     53.466165    337
# 215              accg_entropy_values     50.182776    619
# 250             acc_time_diff2_sum_x     47.073096    539
# 16                    acc_x_median_y     41.236278    287
# 256             acc_time_diff2_var_x     37.308559    364
# 258             acc_time_diff2_max_y     36.924723    236
# 22                      acc_x_mode_y     34.395850    389
# 203                         accg_var     29.687165    141
# 261          acc_time_diff2_median_y     28.223890    109
# 13                       acc_x_max_y     27.791721    180
# 73                         acc_z_var     27.069676    115
# 20                       acc_x_std_y     23.820593     27
# 285               acc_time_diff3_sum     23.085920    357
# 257             acc_time_diff2_min_y     22.129930    142
# 12                       acc_x_min_y     20.178316    194
# 0                              count     19.334676    214
# 260             acc_time_diff2_sum_y     11.240865    115
# 265             acc_time_diff2_std_y     10.569627     68
# 266             acc_time_diff2_var_y      2.448081     30
# 21                       acc_x_var_y      2.306963     12
# 354        acc_yg_diff1_fifth_moment      0.000000      0
# 353       acc_yg_diff1_fourth_moment      0.000000      0
# 242      acc_time_diff_fourth_moment      0.000000      0
# 243       acc_time_diff_fifth_moment      0.000000      0
# 245   acc_time_diff_root_mean_square      0.000000      0
# 246                          istrain      0.000000      0
# 331    acc_xg_diff1_root_mean_square      0.000000      0
# 329        acc_xg_diff1_fifth_moment      0.000000      0
# 278     acc_time_diff2_fourth_moment      0.000000      0
# 279      acc_time_diff2_fifth_moment      0.000000      0
# 281  acc_time_diff2_root_mean_square      0.000000      0
# 303     acc_time_diff3_fourth_moment      0.000000      0
# 304      acc_time_diff3_fifth_moment      0.000000      0
# 306  acc_time_diff3_root_mean_square      0.000000      0
# 328       acc_xg_diff1_fourth_moment      0.000000      0
# 356    acc_yg_diff1_root_mean_square      0.000000      0
#                                 feat          gain  split
# 115          acc_xg_root_mean_square  10678.050075   7336
# 116                       acc_yg_min   6804.334383   5171
# 91                        acc_xg_max   3668.350208   5140
# 117                       acc_yg_max  10503.568065   4724
# 142                       acc_zg_min   6543.674395   4634
# 90                        acc_xg_min   3209.018276   4496
# 196                        accg_mean   2442.878550   4254
# 152                      acc_zg_mode   1444.910967   4244
# 93                        acc_xg_sum    989.578725   4196
# 122                      acc_yg_kurt    425.148401   4138
# 40                        acc_y_mean   1978.330304   4120
# 59              acc_y_entropy_values   2638.511763   4110
# 209                         accg_q40   1659.030880   4047
# 288              acc_time_diff3_kurt    627.924028   4036
# 44                        acc_y_kurt    553.682485   4013
# 153                       acc_zg_q10   4389.820936   3978
# 241     acc_time_diff_entropy_values   1548.110370   3972
# 225               acc_time_diff_skew    680.298537   3952
# 198                      accg_median    936.001473   3766
# 7                       acc_x_kurt_x    556.974934   3761
# 96                       acc_xg_kurt    364.467163   3699
# 119                       acc_yg_sum    793.442927   3670
# 127                       acc_yg_q10   6301.817444   3621
# 337                acc_yg_diff1_skew    325.615906   3602
# 240                acc_time_diff_q90   1443.469214   3530
# 312                acc_xg_diff1_skew    286.112541   3474
# 110                       acc_xg_q90   3671.754151   3455
# 41                         acc_y_sum    799.722516   3448
# 338                acc_yg_diff1_kurt    389.935114   3430
# 43                        acc_y_skew    340.902304   3394
# 121                      acc_yg_skew    385.930138   3392
# 101                       acc_xg_q10   2222.623330   3389
# 219            accg_root_mean_square   2740.950388   3370
# 313                acc_xg_diff1_kurt    343.439247   3347
# 67                         acc_z_sum    574.128348   3342
# 6                       acc_x_skew_x    326.695711   3307
# 95                       acc_xg_skew    299.910689   3304
# 252            acc_time_diff2_skew_x    334.202271   3290
# 226               acc_time_diff_kurt    358.608693   3264
# 141          acc_yg_root_mean_square   4883.293576   3247
# 70                        acc_z_kurt    410.411917   3201
# 253            acc_time_diff2_kurt_x    341.352491   3198
# 287              acc_time_diff3_skew    289.736054   3188
# 100                      acc_xg_mode   1155.780251   3186
# 200                        accg_kurt    385.773954   3141
# 66                        acc_z_mean   1032.116136   3132
# 143                       acc_zg_max   1655.831267   3121
# 147                      acc_zg_skew    302.134767   3040
# 174                         acc_kurt    287.097502   3024
# 136                       acc_yg_q90   5125.719654   3016
# 208                         accg_q30   1234.112753   2965
# 210                         accg_q60    848.394953   2920
# 126                      acc_yg_mode   1372.840663   2916
# 302    acc_time_diff3_entropy_values    771.051865   2905
# 148                      acc_zg_kurt    317.256682   2899
# 4                        acc_x_sum_x    347.616404   2899
# 277    acc_time_diff2_entropy_values    511.879857   2880
# 69                        acc_z_skew    293.339721   2827
# 173                         acc_skew    314.091495   2811
# 33              acc_x_entropy_values    993.933775   2806
# 3                       acc_x_mean_x    521.689579   2759
# 139              acc_yg_fifth_moment    395.293082   2702
# 335                 acc_yg_diff1_sum    339.823375   2670
# 310                 acc_xg_diff1_sum    316.582325   2666
# 162                       acc_zg_q90   2510.971135   2635
# 199                        accg_skew    264.687799   2552
# 178                         acc_mode    480.346496   2541
# 207                         accg_q25   1024.569803   2477
# 211                         accg_q70   1302.545401   2473
# 154                       acc_zg_q20   2526.843558   2466
# 276               acc_time_diff2_q90   1536.957826   2439
# 113              acc_xg_fifth_moment    351.482574   2428
# 347                 acc_yg_diff1_q60    272.087450   2426
# 61                acc_y_fifth_moment    288.953441   2368
# 144                      acc_zg_mean   2796.818094   2365
# 322                 acc_xg_diff1_q60    306.961705   2358
# 85              acc_z_entropy_values    544.828258   2357
# 145                       acc_zg_sum    256.613260   2354
# 309                acc_xg_diff1_mean    334.587872   2349
# 334                acc_yg_diff1_mean    318.309896   2332
# 205                         accg_q10    695.081522   2312
# 206                         accg_q20    733.740891   2294
# 311              acc_xg_diff1_median    206.451710   2285
# 74                        acc_z_mode    320.770473   2257
# 58                         acc_y_q90    821.190849   2257
# 137            acc_yg_entropy_values    328.105714   2244
# 204                        accg_mode    358.517714   2240
# 111            acc_xg_entropy_values    324.805431   2231
# 227                acc_time_diff_mad    442.645965   2222
# 301               acc_time_diff3_q90    850.646721   2179
# 222               acc_time_diff_mean    553.839537   2163
# 97                        acc_xg_mad   1083.997966   2148
# 321                 acc_xg_diff1_q40    253.926380   2146
# 87                acc_z_fifth_moment    270.395571   2146
# 128                       acc_yg_q20   1840.692365   2105
# 336              acc_yg_diff1_median    237.532936   2095
# 109                       acc_xg_q80   1640.698325   2083
# 123                       acc_yg_mad    718.041696   2076
# 346                 acc_yg_diff1_q40    278.912746   2065
# 239                acc_time_diff_q80   1034.650438   2051
# 165              acc_zg_fifth_moment    240.314604   2036
# 179                          acc_q10   2402.160722   2031
# 54                         acc_y_q60    472.957343   2019
# 35                acc_x_fifth_moment    267.308976   2016
# 214                         accg_q90    662.242426   1999
# 155                       acc_zg_q25   1900.622113   1995
# 163            acc_zg_entropy_values    255.504099   1993
# 161                       acc_zg_q80   2447.021111   1974
# 92                       acc_xg_mean    966.644035   1939
# 156                       acc_zg_q30   1288.836727   1938
# 289               acc_time_diff3_mad    345.071126   1924
# 348                 acc_yg_diff1_q70    284.259802   1922
# 118                      acc_yg_mean   1392.810318   1920
# 146                    acc_zg_median    825.043809   1896
# 228                acc_time_diff_std    342.193906   1892
# 168                          acc_min    620.142097   1886
# 157                       acc_zg_q40   1024.966251   1886
# 320                 acc_xg_diff1_q30    256.966316   1884
# 217                accg_fifth_moment    221.192697   1882
# 213                         accg_q80    690.506497   1868
# 11                      acc_x_mode_x    162.124889   1866
# 48                        acc_y_mode    207.633402   1859
# 79                         acc_z_q40    339.077697   1855
# 231                acc_time_diff_q10    698.974631   1848
# 232                acc_time_diff_q20   4172.798160   1840
# 53                         acc_y_q40    664.391647   1834
# 158                       acc_zg_q60    691.202460   1832
# 102                       acc_xg_q20   1244.437769   1827
# 159                       acc_zg_q70    813.521922   1790
# 254             acc_time_diff2_mad_x    271.008135   1783
# 323                 acc_xg_diff1_q70    271.012900   1778
# 212                         accg_q75    739.862198   1777
# 28                         acc_x_q60    347.831202   1772
# 55                         acc_y_q70    792.765969   1768
# 106                       acc_xg_q60   1159.542543   1764
# 120                    acc_yg_median   1078.294501   1763
# 57                         acc_y_q80    991.578457   1758
# 221                acc_time_diff_max    547.366897   1754
# 107                       acc_xg_q70    950.669175   1754
# 267               acc_time_diff2_q10    488.241961   1743
# 27                         acc_x_q40    355.374481   1739
# 237                acc_time_diff_q70    915.384478   1735
# 135                       acc_yg_q80   2334.734919   1731
# 108                       acc_xg_q75    836.669567   1724
# 160                       acc_zg_q75   1135.738957   1719
# 124                       acc_yg_std    694.769077   1712
# 50                         acc_y_q20    950.535239   1707
# 80                         acc_z_q60    580.083851   1705
# 49                         acc_y_q10   1450.368381   1704
# 191                 acc_fifth_moment    242.085960   1699
# 129                       acc_yg_q25   1497.389325   1697
# 52                         acc_y_q30   1024.459538   1693
# 26                         acc_x_q30    425.430511   1692
# 300               acc_time_diff3_q80   1019.741128   1688
# 234                acc_time_diff_q30    757.725334   1681
# 45                         acc_y_mad   1168.986514   1676
# 31                         acc_x_q80    550.282796   1674
# 94                     acc_xg_median    814.240587   1670
# 345                 acc_yg_diff1_q30    265.471048   1670
# 249            acc_time_diff2_mean_x    401.716358   1655
# 68                      acc_z_median    232.480499   1653
# 317                 acc_xg_diff1_q10    317.342999   1642
# 352      acc_yg_diff1_entropy_values    164.620206   1641
# 342                 acc_yg_diff1_q10    357.590799   1630
# 325                 acc_xg_diff1_q80    381.356484   1623
# 42                      acc_y_median    345.441178   1617
# 284              acc_time_diff3_mean    346.776115   1613
# 351                 acc_yg_diff1_q90    293.159690   1611
# 230               acc_time_diff_mode    232.669318   1602
# 56                         acc_y_q75    716.805099   1591
# 29                         acc_x_q70    453.434458   1579
# 350                 acc_yg_diff1_q80    246.438558   1567
# 349                 acc_yg_diff1_q75    250.687670   1559
# 194                         accg_min    325.366652   1557
# 75                         acc_z_q10    513.473252   1550
# 133                       acc_yg_q70   1358.045294   1541
# 134                       acc_yg_q75   1348.570608   1532
# 167          acc_zg_root_mean_square   1512.029303   1529
# 324                 acc_xg_diff1_q75    294.558029   1525
# 326                 acc_xg_diff1_q90    277.240680   1521
# 327      acc_xg_diff1_entropy_values    148.670639   1518
# 78                         acc_z_q30    302.249132   1514
# 343                 acc_yg_diff1_q20    226.306753   1510
# 105                       acc_xg_q40    912.256030   1503
# 332                 acc_yg_diff1_min    304.798540   1502
# 307                 acc_xg_diff1_min    280.736473   1494
# 81                         acc_z_q70    279.706651   1488
# 103                       acc_xg_q25    589.835227   1487
# 235                acc_time_diff_q40    516.842011   1480
# 292               acc_time_diff3_q10    374.982636   1479
# 132                       acc_yg_q60    728.625014   1477
# 32                         acc_x_q90    279.156543   1470
# 130                       acc_yg_q30   1055.419773   1468
# 24                         acc_x_q20    386.414551   1463
# 5                     acc_x_median_x    245.424405   1456
# 76                         acc_z_q20    457.159499   1448
# 84                         acc_z_q90    292.632509   1446
# 333                 acc_yg_diff1_max    250.375982   1439
# 30                         acc_x_q75    395.287952   1429
# 273               acc_time_diff2_q70    364.394545   1424
# 63            acc_y_root_mean_square   3428.448386   1423
# 8                        acc_x_mad_x   4378.002350   1404
# 23                         acc_x_q10    288.240111   1401
# 255             acc_time_diff2_std_x    190.788903   1394
# 180                          acc_q20   2602.556735   1394
# 98                        acc_xg_std    641.470882   1392
# 275               acc_time_diff2_q80   1338.728186   1390
# 138             acc_yg_fourth_moment    431.246183   1377
# 319                 acc_xg_diff1_q25    175.315070   1374
# 290               acc_time_diff3_std    204.894573   1372
# 25                         acc_x_q25    335.660369   1370
# 189               acc_entropy_values    213.103322   1367
# 308                 acc_xg_diff1_max    222.223922   1361
# 77                         acc_z_q25    259.933477   1359
# 298               acc_time_diff3_q70    533.824986   1356
# 104                       acc_xg_q30    698.545874   1355
# 268               acc_time_diff2_q20   1780.917467   1346
# 195                         accg_max    242.514800   1342
# 344                 acc_yg_diff1_q25    196.229450   1340
# 51                         acc_y_q25    691.160240   1331
# 233                acc_time_diff_q25   3204.524835   1316
# 318                 acc_xg_diff1_q20    238.373434   1302
# 131                       acc_yg_q40   1044.180806   1287
# 270               acc_time_diff2_q30    605.217033   1277
# 248             acc_time_diff2_max_x    303.674036   1276
# 272               acc_time_diff2_q60    461.492322   1267
# 149                       acc_zg_mad   4748.137324   1241
# 39                         acc_y_max    209.689460   1232
# 238                acc_time_diff_q75    835.122617   1230
# 112             acc_xg_fourth_moment    377.814904   1217
# 340                 acc_yg_diff1_std    534.086115   1216
# 83                         acc_z_q80    233.352149   1206
# 315                 acc_xg_diff1_std    462.023466   1201
# 283               acc_time_diff3_max    259.142423   1198
# 274               acc_time_diff2_q75    838.933981   1164
# 82                         acc_z_q75    581.890388   1161
# 355         acc_yg_diff1_range_value    310.304449   1151
# 140               acc_yg_range_value    228.230958   1145
# 271               acc_time_diff2_q40    251.649361   1144
# 293               acc_time_diff3_q20    327.493629   1138
# 38                         acc_y_min    263.595387   1134
# 114               acc_xg_range_value    287.946108   1130
# 295               acc_time_diff3_q30    363.637411   1125
# 236                acc_time_diff_q60    292.629357   1123
# 297               acc_time_diff3_q60    319.103721   1100
# 296               acc_time_diff3_q40    275.697214   1099
# 299               acc_time_diff3_q75    588.783508   1088
# 64                         acc_z_min    212.397685   1082
# 182                          acc_q30   1004.094308   1070
# 269               acc_time_diff2_q25   1299.857998   1070
# 330         acc_xg_diff1_range_value    221.184721   1066
# 2                        acc_x_max_x    167.863688   1041
# 181                          acc_q25   1097.805828   1011
# 171                          acc_sum    132.453860   1007
# 1                        acc_x_min_x    138.476742   1006
# 294               acc_time_diff3_q25    289.659431    986
# 150                       acc_zg_std  12365.600402    965
# 314                 acc_xg_diff1_mad    397.862308    953
# 339                 acc_yg_diff1_mad    500.386217    950
# 183                          acc_q40    783.998385    940
# 166               acc_zg_range_value   1655.110507    925
# 244        acc_time_diff_range_value    456.866719    918
# 60               acc_y_fourth_moment    314.784757    912
# 201                         accg_mad    189.029185    902
# 175                          acc_mad    150.264441    873
# 197                         accg_sum     88.517803    869
# 46                         acc_y_std    393.062826    865
# 65                         acc_z_max    132.484548    854
# 71                         acc_z_mad    413.736390    851
# 37            acc_x_root_mean_square    856.749676    851
# 164             acc_zg_fourth_moment    840.405397    848
# 223                acc_time_diff_sum     83.975084    841
# 224             acc_time_diff_median    263.351235    829
# 34               acc_x_fourth_moment    184.621319    811
# 282               acc_time_diff3_min     89.067431    802
# 18                      acc_x_kurt_y     93.480839    784
# 202                         accg_std    211.027524    778
# 218                 accg_range_value    129.167113    773
# 172                       acc_median    503.783788    756
# 305       acc_time_diff3_range_value    124.137492    754
# 216               accg_fourth_moment    189.689008    737
# 176                          acc_std    229.627032    721
# 229                acc_time_diff_var     96.200897    696
# 62                 acc_y_range_value    139.240394    694
# 263            acc_time_diff2_kurt_y     79.939704    689
# 9                        acc_x_std_x    423.848399    688
# 280       acc_time_diff2_range_value     85.617979    684
# 86               acc_z_fourth_moment    346.900497    681
# 190                acc_fourth_moment    159.138635    677
# 17                      acc_x_skew_y     55.336473    646
# 220                acc_time_diff_min     76.247406    623
# 215              accg_entropy_values     50.182776    619
# 15                       acc_x_sum_y     72.958210    619
# 262            acc_time_diff2_skew_y     77.432632    613
# 286            acc_time_diff3_median    259.733773    605
# 36                 acc_x_range_value    124.183096    600
# 192                  acc_range_value     94.657260    597
# 89            acc_z_root_mean_square    260.925098    589
# 72                         acc_z_std    207.209754    586
# 247             acc_time_diff2_min_x     67.481994    582
# 88                 acc_z_range_value     99.585998    574
# 251          acc_time_diff2_median_x    437.929631    553
# 250             acc_time_diff2_sum_x     47.073096    539
# 291               acc_time_diff3_var     69.054052    524
# 184                          acc_q60    314.302736    524
# 188                          acc_q90    132.709938    511
# 14                      acc_x_mean_y     89.648763    481
# 187                          acc_q80    174.287462    478
# 185                          acc_q70    250.689531    477
# 169                          acc_max    108.135854    464
# 170                         acc_mean    328.015998    458
# 186                          acc_q75    104.824136    396
# 22                      acc_x_mode_y     34.395850    389
# 125                       acc_yg_var    136.482222    383
# 256             acc_time_diff2_var_x     37.308559    364
# 193             acc_root_mean_square    157.971001    358
# 285               acc_time_diff3_sum     23.085920    357
# 259            acc_time_diff2_mean_y     77.681912    350
# 264             acc_time_diff2_mad_y     53.466165    337
# 99                        acc_xg_var    125.338199    298
# 16                    acc_x_median_y     41.236278    287
# 19                       acc_x_mad_y   1612.229571    246
# 316                 acc_xg_diff1_var    180.402232    237
# 258             acc_time_diff2_max_y     36.924723    236
# 47                         acc_y_var    112.850885    219
# 341                 acc_yg_diff1_var     55.170227    216
# 0                              count     19.334676    214
# 151                       acc_zg_var   1895.502887    209
# 12                       acc_x_min_y     20.178316    194
# 177                          acc_var     59.616936    181
# 13                       acc_x_max_y     27.791721    180
# 10                       acc_x_var_x    110.312844    178
# 257             acc_time_diff2_min_y     22.129930    142
# 203                         accg_var     29.687165    141
# 260             acc_time_diff2_sum_y     11.240865    115
# 73                         acc_z_var     27.069676    115
# 261          acc_time_diff2_median_y     28.223890    109
# 265             acc_time_diff2_std_y     10.569627     68
# 266             acc_time_diff2_var_y      2.448081     30
# 20                       acc_x_std_y     23.820593     27
# 21                       acc_x_var_y      2.306963     12
# 278     acc_time_diff2_fourth_moment      0.000000      0
# 328       acc_xg_diff1_fourth_moment      0.000000      0
# 306  acc_time_diff3_root_mean_square      0.000000      0
# 304      acc_time_diff3_fifth_moment      0.000000      0
# 303     acc_time_diff3_fourth_moment      0.000000      0
# 281  acc_time_diff2_root_mean_square      0.000000      0
# 279      acc_time_diff2_fifth_moment      0.000000      0
# 246                          istrain      0.000000      0
# 329        acc_xg_diff1_fifth_moment      0.000000      0
# 331    acc_xg_diff1_root_mean_square      0.000000      0
# 245   acc_time_diff_root_mean_square      0.000000      0
# 243       acc_time_diff_fifth_moment      0.000000      0
# 242      acc_time_diff_fourth_moment      0.000000      0
# 353       acc_yg_diff1_fourth_moment      0.000000      0
# 354        acc_yg_diff1_fifth_moment      0.000000      0
# 356    acc_yg_diff1_root_mean_square      0.000000      0

# %%
def acc_combo(y, y_pred):
    # 数值ID与行为编码的对应关系
    mapping = {
        '0': 'A_1', '1': 'B_2', '2': 'A_3', '3': 'A_4', '4': 'B_3', '5': 'C_5', '6': 'C_2', '7': 'A_5', '8': 'B_1', 
        '9': 'C_1', '10': 'A_2', '11': 'C_3', '12': 'B_5', '13': 'B_4', '14': 'C_4', 
        '15': 'D_6', '16': 'E_7', '17': 'F_8', '18': 'G_9', '19': 'H_0'
              }
    # 将行为ID转为编码
    code_y, code_y_pred = mapping[str(int(y))], mapping[str(int(y_pred))]
    if code_y == code_y_pred: #编码完全相同得分1.0
        return 1.0
    elif code_y.split("_")[0] == code_y_pred.split("_")[0]: #编码仅字母部分相同得分1.0/7
        return 1.0/7
    elif code_y.split("_")[1] == code_y_pred.split("_")[1]: #编码仅数字部分相同得分1.0/3
        return 1.0/3
    else:
        return 0.0

# %%
labels = np.argmax(preds, axis=1)
oof_y = np.argmax(oof_train, axis=1)
print(round(accuracy_score(train_y, oof_y), 5))
score = sum(acc_combo(y_true, y_pred) for y_true, y_pred in zip(train_y, oof_y)) / oof_y.shape[0]
print(round(score, 5))
# Out:
# 0.8076
# 0.83264

# %%
LGB_OOF = {
    "oof":oof_train,
    "test":preds
}
import joblib 
# joblib.dump(LGB_OOF,"LGB_OOF.pkl")
# Out:
# ['LGB_OOF.pkl']

# %%
sub = pd.read_csv(root_path+'submit_example.csv')

sub['behavior_id'] = labels

vc = data_train['behavior_id'].value_counts().sort_index()
sns.barplot(vc.index, vc.values)
plt.show()
vc = sub['behavior_id'].value_counts().sort_index()
sns.barplot(vc.index, vc.values)
plt.show()
sub.to_csv('LGB%.5f.csv' % score, index=False)
