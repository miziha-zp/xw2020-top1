# %%
import numpy as np
import pandas as pd
import lightgbm as lgb
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import entropy
import gc
import os
from tqdm import tqdm
pd.set_option('display.max_columns', 600)
pd.set_option('display.max_rows', 600)
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
root_path  = '../data/final_data/'
data_train = pd.read_csv(root_path+'sensor_train_final.csv')
data_test = pd.read_csv(root_path+'sensor_test_final.csv')
sub = pd.read_csv(root_path+'submit_example.csv')
y = data_train.groupby('fragment_id')['behavior_id'].min()
data_test['fragment_id'] += 100000
label = 'behavior_id'
data = pd.concat([data_train, data_test], sort=False,ignore_index=True)
df = data.drop_duplicates(subset=['fragment_id']).reset_index(drop=True)[['fragment_id', 'behavior_id']]
df["count"] = data.groupby("fragment_id")["time_point"].count()

featureList = ["count"]

# %%
# LGB model
import joblib
# lgboof = joblib.load("LGB_OOF.pkl")
lgboof = joblib.load("LGB_OOF859_____5fold.pkl")
# lgboof = joblib.load("LGB_OOF859_____5foldmoremroe.pkl")
oof = lgboof["oof"]
preds = lgboof["test"]

stack_array = np.concatenate([oof,preds],axis=0)
print(stack_array.shape)
for i in range(20):
    df["lgb_"+str(i)] = stack_array[:,i]
featureList += ["lgb_"+str(i)for i in range(20)]
# Out:
# (31000, 20)

# %%
# LSTM model
import joblib 
lstmoof = joblib.load("LSTM8370.83753_dict.pkl")
oof = lstmoof["oof"]
preds = lstmoof["test"]

stack_array = np.concatenate([oof,preds],axis=0)
print(stack_array.shape)
for i in range(20):
    df["lstm_"+str(i)] = stack_array[:,i]
featureList += ["lstm_"+str(i)for i in range(20)]
# Out:
# (31000, 20)

# %%
# CNN
import joblib 

cnnoof = joblib.load("all_stragety-add2net0.85679_dict.pkl")
oof = cnnoof["oof"]
preds = cnnoof["test"]

stack_array = np.concatenate([oof,preds],axis=0)
print(stack_array.shape)
for i in range(20):
    df["CNN_"+str(i)] = stack_array[:,i]
featureList += ["CNN_"+str(i)for i in range(20)]

# cnnoof = joblib.load("all_stragety_lcy1_0.84695_dict.pkl")
# oof = cnnoof["oof"]
# preds = cnnoof["test"]

# stack_array = np.concatenate([oof,preds],axis=0)
# print(stack_array.shape)
# for i in range(20):
#     df["CNN_"+str(i)] = stack_array[:,i]
# featureList += ["CNN_"+str(i)for i in range(20)]
# Out:
# (31000, 20)

# %%
df = df.fillna(0)
df.loc[:15000,"istrain"] = 1
df.loc[15000:,"istrain"] = 0

train_df = df[df["istrain"]==1].reset_index(drop=True)
test_df = df[df["istrain"]==0].reset_index(drop=True)

drop_feat = ["istrain"]
used_feat = [f for f in train_df.columns if f not in (['fragment_id', label] + drop_feat)]
print(len(used_feat))
print(used_feat)

train_x = train_df[used_feat]
train_y = train_df[label]
test_x = test_df[used_feat]
print()
# Out:
# 61
# ['count', 'lgb_0', 'lgb_1', 'lgb_2', 'lgb_3', 'lgb_4', 'lgb_5', 'lgb_6', 'lgb_7', 'lgb_8', 'lgb_9', 'lgb_10', 'lgb_11', 'lgb_12', 'lgb_13', 'lgb_14', 'lgb_15', 'lgb_16', 'lgb_17', 'lgb_18', 'lgb_19', 'lstm_0', 'lstm_1', 'lstm_2', 'lstm_3', 'lstm_4', 'lstm_5', 'lstm_6', 'lstm_7', 'lstm_8', 'lstm_9', 'lstm_10', 'lstm_11', 'lstm_12', 'lstm_13', 'lstm_14', 'lstm_15', 'lstm_16', 'lstm_17', 'lstm_18', 'lstm_19', 'CNN_0', 'CNN_1', 'CNN_2', 'CNN_3', 'CNN_4', 'CNN_5', 'CNN_6', 'CNN_7', 'CNN_8', 'CNN_9', 'CNN_10', 'CNN_11', 'CNN_12', 'CNN_13', 'CNN_14', 'CNN_15', 'CNN_16', 'CNN_17', 'CNN_18', 'CNN_19']

# %%
scores = []
imp = pd.DataFrame()
imp['feat'] = used_feat

params = {
    'learning_rate': 0.05,
    'metric': 'multi_error',
    'objective': 'multiclass',
    'num_class': 20,
    'feature_fraction': 0.80,
    'bagging_fraction': 0.75,
    'bagging_freq': 2,
    'n_jobs': 4,
    'seed': 2020,
    'max_depth': 10,
    'num_leaves': 64,
    'lambda_l1': 0.5,
    'lambda_l2': 0.5,
}

oof_train = np.zeros((len(train_x), 20))
preds = np.zeros((len(test_x), 20))
folds = 5
seeds = [44, 2020, 527, 1527]
for seed in seeds:
    kfold = StratifiedKFold(n_splits=folds, shuffle=True, random_state=seed)
    for fold, (trn_idx, val_idx) in enumerate(kfold.split(train_x, train_y)):
        x_trn, y_trn, x_val, y_val = train_x.iloc[trn_idx], train_y.iloc[trn_idx], train_x.iloc[val_idx], train_y.iloc[val_idx]
        train_set = lgb.Dataset(x_trn, y_trn)
        val_set = lgb.Dataset(x_val, y_val)

        model = lgb.train(params, train_set, num_boost_round=500000,
                          valid_sets=(train_set, val_set), early_stopping_rounds=50,
                          verbose_eval=20)
        oof_train[val_idx] += model.predict(x_val) / len(seeds)
        preds += model.predict(test_x) / folds / len(seeds)
        scores.append(model.best_score['valid_1']['multi_error'])
        imp['gain' + str(fold + 1)] = model.feature_importance(importance_type='gain')
        imp['split' + str(fold + 1)] = model.feature_importance(importance_type='split')
        del x_trn, y_trn, x_val, y_val, model, train_set, val_set
        gc.collect()
# Out:
# Training until validation scores don't improve for 50 rounds
# [20]	training's multi_error: 0.0740833	valid_1's multi_error: 0.103667
# [40]	training's multi_error: 0.05575	valid_1's multi_error: 0.0996667
# [60]	training's multi_error: 0.04075	valid_1's multi_error: 0.101667
# [80]	training's multi_error: 0.0243333	valid_1's multi_error: 0.101667
# Early stopping, best iteration is:
# [42]	training's multi_error: 0.0540833	valid_1's multi_error: 0.0986667
# 3352
# Training until validation scores don't improve for 50 rounds
# [20]	training's multi_error: 0.0736667	valid_1's multi_error: 0.116
# [40]	training's multi_error: 0.05425	valid_1's multi_error: 0.114333
# [60]	training's multi_error: 0.0385	valid_1's multi_error: 0.117
# [80]	training's multi_error: 0.0235	valid_1's multi_error: 0.116
# Early stopping, best iteration is:
# [34]	training's multi_error: 0.0583333	valid_1's multi_error: 0.113
# 12
# Training until validation scores don't improve for 50 rounds
# [20]	training's multi_error: 0.0743333	valid_1's multi_error: 0.112333
# [40]	training's multi_error: 0.05775	valid_1's multi_error: 0.111667
# [60]	training's multi_error: 0.0381667	valid_1's multi_error: 0.113667
# Early stopping, best iteration is:
# [24]	training's multi_error: 0.0715	valid_1's multi_error: 0.11
# 6260
# Training until validation scores don't improve for 50 rounds
# [20]	training's multi_error: 0.0710833	valid_1's multi_error: 0.125333
# [40]	training's multi_error: 0.0543333	valid_1's multi_error: 0.125333
# [60]	training's multi_error: 0.0374167	valid_1's multi_error: 0.123667
# [80]	training's multi_error: 0.0238333	valid_1's multi_error: 0.124667
# Early stopping, best iteration is:
# [48]	training's multi_error: 0.04675	valid_1's multi_error: 0.122667
# 32
# Training until validation scores don't improve for 50 rounds
# [20]	training's multi_error: 0.0735	valid_1's multi_error: 0.125333
# [40]	training's multi_error: 0.0554167	valid_1's multi_error: 0.123
# [60]	training's multi_error: 0.0385	valid_1's multi_error: 0.123
# [80]	training's multi_error: 0.0235833	valid_1's multi_error: 0.123
# Early stopping, best iteration is:
# [31]	training's multi_error: 0.0633333	valid_1's multi_error: 0.121333
# 8
# Training until validation scores don't improve for 50 rounds
# [20]	training's multi_error: 0.0731667	valid_1's multi_error: 0.117333
# [40]	training's multi_error: 0.0549167	valid_1's multi_error: 0.119
# [60]	training's multi_error: 0.0383333	valid_1's multi_error: 0.117333
# [80]	training's multi_error: 0.0246667	valid_1's multi_error: 0.120667
# Early stopping, best iteration is:
# [49]	training's multi_error: 0.04775	valid_1's multi_error: 0.117
# 40
# Training until validation scores don't improve for 50 rounds
# [20]	training's multi_error: 0.0725	valid_1's multi_error: 0.117667
# [40]	training's multi_error: 0.0548333	valid_1's multi_error: 0.116
# [60]	training's multi_error: 0.0375	valid_1's multi_error: 0.118667
# [80]	training's multi_error: 0.0231667	valid_1's multi_error: 0.117
# Early stopping, best iteration is:
# [42]	training's multi_error: 0.0526667	valid_1's multi_error: 0.114667
# 29
# Training until validation scores don't improve for 50 rounds
# [20]	training's multi_error: 0.0750833	valid_1's multi_error: 0.115
# [40]	training's multi_error: 0.0563333	valid_1's multi_error: 0.112667
# [60]	training's multi_error: 0.03925	valid_1's multi_error: 0.112
# [80]	training's multi_error: 0.024	valid_1's multi_error: 0.112333
# [100]	training's multi_error: 0.0125	valid_1's multi_error: 0.111333
# Early stopping, best iteration is:
# [53]	training's multi_error: 0.0455833	valid_1's multi_error: 0.110667
# 56
# Training until validation scores don't improve for 50 rounds
# [20]	training's multi_error: 0.0733333	valid_1's multi_error: 0.118333
# [40]	training's multi_error: 0.0580833	valid_1's multi_error: 0.117333
# [60]	training's multi_error: 0.0405	valid_1's multi_error: 0.114333
# [80]	training's multi_error: 0.023	valid_1's multi_error: 0.111667
# [100]	training's multi_error: 0.012	valid_1's multi_error: 0.113667
# [120]	training's multi_error: 0.00525	valid_1's multi_error: 0.112667
# Early stopping, best iteration is:
# [82]	training's multi_error: 0.022	valid_1's multi_error: 0.110333
# 172
# Training until validation scores don't improve for 50 rounds
# [20]	training's multi_error: 0.0725	valid_1's multi_error: 0.123
# [40]	training's multi_error: 0.0565833	valid_1's multi_error: 0.122
# [60]	training's multi_error: 0.0395	valid_1's multi_error: 0.124
# [80]	training's multi_error: 0.02375	valid_1's multi_error: 0.125333
# Early stopping, best iteration is:
# [45]	training's multi_error: 0.0520833	valid_1's multi_error: 0.120333
# 30
# Training until validation scores don't improve for 50 rounds
# [20]	training's multi_error: 0.07175	valid_1's multi_error: 0.114
# [40]	training's multi_error: 0.0540833	valid_1's multi_error: 0.113
# [60]	training's multi_error: 0.0383333	valid_1's multi_error: 0.114
# [80]	training's multi_error: 0.0230833	valid_1's multi_error: 0.114
# Early stopping, best iteration is:
# [42]	training's multi_error: 0.0524167	valid_1's multi_error: 0.111667
# 29
# Training until validation scores don't improve for 50 rounds
# [20]	training's multi_error: 0.0751667	valid_1's multi_error: 0.119
# [40]	training's multi_error: 0.05675	valid_1's multi_error: 0.115333
# [60]	training's multi_error: 0.0400833	valid_1's multi_error: 0.115667
# [80]	training's multi_error: 0.0250833	valid_1's multi_error: 0.118333
# Early stopping, best iteration is:
# [40]	training's multi_error: 0.05675	valid_1's multi_error: 0.115333
# 12
# Training until validation scores don't improve for 50 rounds
# [20]	training's multi_error: 0.0741667	valid_1's multi_error: 0.121667
# [40]	training's multi_error: 0.0563333	valid_1's multi_error: 0.122
# [60]	training's multi_error: 0.0395	valid_1's multi_error: 0.121
# Early stopping, best iteration is:
# [29]	training's multi_error: 0.0669167	valid_1's multi_error: 0.119667
# 381
# Training until validation scores don't improve for 50 rounds
# [20]	training's multi_error: 0.0756667	valid_1's multi_error: 0.110667
# [40]	training's multi_error: 0.0570833	valid_1's multi_error: 0.11
# [60]	training's multi_error: 0.03825	valid_1's multi_error: 0.110333
# [80]	training's multi_error: 0.0235833	valid_1's multi_error: 0.109667
# [100]	training's multi_error: 0.0120833	valid_1's multi_error: 0.108333
# [120]	training's multi_error: 0.00625	valid_1's multi_error: 0.107667
# [140]	training's multi_error: 0.00258333	valid_1's multi_error: 0.108333
# [160]	training's multi_error: 0.00116667	valid_1's multi_error: 0.108333
# Early stopping, best iteration is:
# [117]	training's multi_error: 0.00708333	valid_1's multi_error: 0.107
# 304
# Training until validation scores don't improve for 50 rounds
# [20]	training's multi_error: 0.074	valid_1's multi_error: 0.118667
# [40]	training's multi_error: 0.0565833	valid_1's multi_error: 0.115667
# [60]	training's multi_error: 0.0399167	valid_1's multi_error: 0.114333
# [80]	training's multi_error: 0.0255	valid_1's multi_error: 0.115
# [100]	training's multi_error: 0.0123333	valid_1's multi_error: 0.115
# [120]	training's multi_error: 0.00608333	valid_1's multi_error: 0.115667
# [140]	training's multi_error: 0.00275	valid_1's multi_error: 0.116333
# Early stopping, best iteration is:
# [94]	training's multi_error: 0.0153333	valid_1's multi_error: 0.113333
# 220
# Training until validation scores don't improve for 50 rounds
# [20]	training's multi_error: 0.0745	valid_1's multi_error: 0.108667
# [40]	training's multi_error: 0.0565	valid_1's multi_error: 0.108333
# [60]	training's multi_error: 0.039	valid_1's multi_error: 0.107
# [80]	training's multi_error: 0.0235	valid_1's multi_error: 0.108667
# Early stopping, best iteration is:
# [43]	training's multi_error: 0.05325	valid_1's multi_error: 0.107
# 29
# Training until validation scores don't improve for 50 rounds
# [20]	training's multi_error: 0.0731667	valid_1's multi_error: 0.117667
# [40]	training's multi_error: 0.05575	valid_1's multi_error: 0.113667
# [60]	training's multi_error: 0.0385	valid_1's multi_error: 0.116
# [80]	training's multi_error: 0.0230833	valid_1's multi_error: 0.118333
# Early stopping, best iteration is:
# [33]	training's multi_error: 0.061	valid_1's multi_error: 0.113
# 12
# Training until validation scores don't improve for 50 rounds
# [20]	training's multi_error: 0.0744167	valid_1's multi_error: 0.113
# [40]	training's multi_error: 0.0580833	valid_1's multi_error: 0.114
# [60]	training's multi_error: 0.03925	valid_1's multi_error: 0.113
# Early stopping, best iteration is:
# [22]	training's multi_error: 0.0716667	valid_1's multi_error: 0.111667
# 344
# Training until validation scores don't improve for 50 rounds
# [20]	training's multi_error: 0.0736667	valid_1's multi_error: 0.117333
# [40]	training's multi_error: 0.0560833	valid_1's multi_error: 0.115667
# [60]	training's multi_error: 0.0401667	valid_1's multi_error: 0.117
# [80]	training's multi_error: 0.0246667	valid_1's multi_error: 0.118
# [100]	training's multi_error: 0.0124167	valid_1's multi_error: 0.119333
# Early stopping, best iteration is:
# [64]	training's multi_error: 0.0366667	valid_1's multi_error: 0.115333
# 100
# Training until validation scores don't improve for 50 rounds
# [20]	training's multi_error: 0.07175	valid_1's multi_error: 0.127333
# [40]	training's multi_error: 0.0539167	valid_1's multi_error: 0.125667
# [60]	training's multi_error: 0.0381667	valid_1's multi_error: 0.127667
# [80]	training's multi_error: 0.02375	valid_1's multi_error: 0.127333
# [100]	training's multi_error: 0.0115833	valid_1's multi_error: 0.126
# Early stopping, best iteration is:
# [52]	training's multi_error: 0.0445	valid_1's multi_error: 0.125333
# 52

# %%
imp['gain'] = imp[[f for f in imp.columns if 'gain' in f]].sum(axis=1)/folds
imp['split'] = imp[[f for f in imp.columns if 'split' in f]].sum(axis=1)
imp = imp.sort_values(by=['gain'], ascending=False)
imp[['feat', 'gain', 'split']]
imp = imp.sort_values(by=['split'], ascending=False)
imp[['feat', 'gain', 'split']]
# Out:
#        feat          gain  split
# 48    CNN_7  27060.073975   3392
# 19   lgb_18  24198.389342   2892
# 9     lgb_8  22004.054508   2742
# 53   CNN_12  21619.363386   4070
# 17   lgb_16  21378.155041   2724
# 46    CNN_5  20176.355505   3620
# 16   lgb_15  19157.039062   3982
# 18   lgb_17  18975.343044   2542
# 40  lstm_19  17587.033549   1606
# 52   CNN_11  17330.950379   3662
# 20   lgb_19  16691.342475   1188
# 2     lgb_1  16598.220857   2670
# 50    CNN_9  16427.268106   3142
# 41    CNN_0  15956.082209   2746
# 14   lgb_13  15406.337180   3246
# 43    CNN_2  14052.028641   3482
# 45    CNN_4  13737.047559   3154
# 60   CNN_19  13651.189665   1794
# 55   CNN_14  13610.854619   3700
# 7     lgb_6  10894.925244   2510
# 13   lgb_12  10539.618319   3712
# 44    CNN_3  10172.633052   2950
# 15   lgb_14   9183.305932   3618
# 6     lgb_5   8776.935322   3476
# 4     lgb_3   8727.070934   2906
# 25   lstm_4   8189.211854   2796
# 1     lgb_0   8034.103666   2080
# 8     lgb_7   7366.728923   3066
# 3     lgb_2   7030.590151   2992
# 5     lgb_4   6556.802585   2996
# 11   lgb_10   6203.387309   3084
# 21   lstm_0   5984.728890   2402
# 54   CNN_13   5952.324289   3014
# 51   CNN_10   5848.368100   2580
# 29   lstm_8   5239.667841   2924
# 57   CNN_16   5211.668170   2906
# 10    lgb_9   5183.377633   3044
# 56   CNN_15   5165.420235   3364
# 42    CNN_1   4771.043428   2784
# 33  lstm_12   4590.323513   3234
# 28   lstm_7   4533.405274   2620
# 47    CNN_6   4528.047215   3010
# 34  lstm_13   4314.186720   2870
# 12   lgb_11   3446.459772   2992
# 24   lstm_3   3376.327145   2918
# 26   lstm_5   3048.287473   3680
# 39  lstm_18   2937.867812   2870
# 22   lstm_1   2916.354743   2908
# 32  lstm_11   2761.876880   3108
# 59   CNN_18   2528.838637   3466
# 37  lstm_16   1757.105646   2566
# 49    CNN_8   1647.010255   3134
# 58   CNN_17   1632.188868   3014
# 27   lstm_6   1545.239014   2794
# 38  lstm_17   1510.867391   3062
# 30   lstm_9   1447.526996   3162
# 23   lstm_2   1146.667516   3072
# 35  lstm_14   1059.391911   3144
# 36  lstm_15    921.541496   2738
# 31  lstm_10    876.937587   3270
# 0     count    317.313803   1230
#        feat          gain  split
# 53   CNN_12  21619.363386   4070
# 16   lgb_15  19157.039062   3982
# 13   lgb_12  10539.618319   3712
# 55   CNN_14  13610.854619   3700
# 26   lstm_5   3048.287473   3680
# 52   CNN_11  17330.950379   3662
# 46    CNN_5  20176.355505   3620
# 15   lgb_14   9183.305932   3618
# 43    CNN_2  14052.028641   3482
# 6     lgb_5   8776.935322   3476
# 59   CNN_18   2528.838637   3466
# 48    CNN_7  27060.073975   3392
# 56   CNN_15   5165.420235   3364
# 31  lstm_10    876.937587   3270
# 14   lgb_13  15406.337180   3246
# 33  lstm_12   4590.323513   3234
# 30   lstm_9   1447.526996   3162
# 45    CNN_4  13737.047559   3154
# 35  lstm_14   1059.391911   3144
# 50    CNN_9  16427.268106   3142
# 49    CNN_8   1647.010255   3134
# 32  lstm_11   2761.876880   3108
# 11   lgb_10   6203.387309   3084
# 23   lstm_2   1146.667516   3072
# 8     lgb_7   7366.728923   3066
# 38  lstm_17   1510.867391   3062
# 10    lgb_9   5183.377633   3044
# 54   CNN_13   5952.324289   3014
# 58   CNN_17   1632.188868   3014
# 47    CNN_6   4528.047215   3010
# 5     lgb_4   6556.802585   2996
# 3     lgb_2   7030.590151   2992
# 12   lgb_11   3446.459772   2992
# 44    CNN_3  10172.633052   2950
# 29   lstm_8   5239.667841   2924
# 24   lstm_3   3376.327145   2918
# 22   lstm_1   2916.354743   2908
# 57   CNN_16   5211.668170   2906
# 4     lgb_3   8727.070934   2906
# 19   lgb_18  24198.389342   2892
# 39  lstm_18   2937.867812   2870
# 34  lstm_13   4314.186720   2870
# 25   lstm_4   8189.211854   2796
# 27   lstm_6   1545.239014   2794
# 42    CNN_1   4771.043428   2784
# 41    CNN_0  15956.082209   2746
# 9     lgb_8  22004.054508   2742
# 36  lstm_15    921.541496   2738
# 17   lgb_16  21378.155041   2724
# 2     lgb_1  16598.220857   2670
# 28   lstm_7   4533.405274   2620
# 51   CNN_10   5848.368100   2580
# 37  lstm_16   1757.105646   2566
# 18   lgb_17  18975.343044   2542
# 7     lgb_6  10894.925244   2510
# 21   lstm_0   5984.728890   2402
# 1     lgb_0   8034.103666   2080
# 60   CNN_19  13651.189665   1794
# 40  lstm_19  17587.033549   1606
# 0     count    317.313803   1230
# 20   lgb_19  16691.342475   1188

# %%
def acc_combo(y, y_pred):
    # 数值ID与行为编码的对应关系
    mapping = {
        '0': 'A_1', '1': 'B_2', '2': 'A_3', '3': 'A_4', '4': 'B_3', '5': 'C_5', '6': 'C_2', '7': 'A_5', '8': 'B_1', 
        '9': 'C_1', '10': 'A_2', '11': 'C_3', '12': 'B_5', '13': 'B_4', '14': 'C_4', 
        '15': 'D_6', '16': 'E_7', '17': 'F_8', '18': 'G_9', '19': 'H_0'
              }
    # 将行为ID转为编码
    code_y, code_y_pred = mapping[str(int(y))], mapping[str(int(y_pred))]
    if code_y == code_y_pred: #编码完全相同得分1.0
        return 1.0
    elif code_y.split("_")[0] == code_y_pred.split("_")[0]: #编码仅字母部分相同得分1.0/7
        return 1.0/7
    elif code_y.split("_")[1] == code_y_pred.split("_")[1]: #编码仅数字部分相同得分1.0/3
        return 1.0/3
    else:
        return 0.0

# %%
labels = np.argmax(preds, axis=1)
oof_y = np.argmax(oof_train, axis=1)
print(round(accuracy_score(train_y, oof_y), 5))
score = sum(acc_combo(y_true, y_pred) for y_true, y_pred in zip(train_y, oof_y)) / oof_y.shape[0]
print(round(score, 5))
# Out:
# 0.88673
# 0.90179

# %%
sub = pd.read_csv(root_path+'submit_example.csv')

sub['behavior_id'] = labels

vc = data_train['behavior_id'].value_counts().sort_index()
sns.barplot(vc.index, vc.values)
plt.show()
vc = sub['behavior_id'].value_counts().sort_index()
sns.barplot(vc.index, vc.values)
plt.show()
sub.to_csv('emsemble%.5f.csv' % score, index=False)
