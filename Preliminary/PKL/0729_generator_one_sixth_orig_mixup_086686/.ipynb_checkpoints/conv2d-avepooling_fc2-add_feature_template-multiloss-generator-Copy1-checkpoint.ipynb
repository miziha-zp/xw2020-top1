# %% [markdown]
# # 多个loss

# %%
# !nvidia-smi
# Out:
# Thu Jul 30 00:25:43 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.100      Driver Version: 440.100      CUDA Version: 10.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce RTX 208...  Off  | 00000000:1A:00.0 Off |                  N/A |
# | 28%   51C    P2    76W / 250W |  10998MiB / 11019MiB |     28%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce RTX 208...  Off  | 00000000:1B:00.0 Off |                  N/A |
# | 35%   56C    P2    61W / 250W |  10998MiB / 11019MiB |     24%      Default |
# +-------------------------------+----------------------+----------------------+
# |   2  GeForce RTX 208...  Off  | 00000000:3D:00.0 Off |                  N/A |
# | 26%   49C    P2    70W / 250W |  11005MiB / 11019MiB |     34%      Default |
# +-------------------------------+----------------------+----------------------+
# |   3  GeForce RTX 208...  Off  | 00000000:3E:00.0 Off |                  N/A |
# | 16%   38C    P8    22W / 250W |    166MiB / 11019MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   4  GeForce RTX 208...  Off  | 00000000:88:00.0 Off |                  N/A |
# | 16%   35C    P8     1W / 250W |      0MiB / 11019MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   5  GeForce RTX 208...  Off  | 00000000:89:00.0 Off |                  N/A |
# | 38%   52C    P8    11W / 250W |      0MiB / 11019MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   6  GeForce RTX 208...  Off  | 00000000:B1:00.0 Off |                  N/A |
# | 16%   36C    P8     1W / 250W |  10996MiB / 11019MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   7  GeForce RTX 208...  Off  | 00000000:B2:00.0 Off |                  N/A |
# | 16%   36C    P8     3W / 250W |      0MiB / 11019MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |    0     26100      C   ...qibot/miniconda3/envs/tf_2.1/bin/python 10987MiB |
# Thu Jul 30 00:25:43 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.100      Driver Version: 440.100      CUDA Version: 10.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce RTX 208...  Off  | 00000000:1A:00.0 Off |                  N/A |
# | 28%   51C    P2    76W / 250W |  10998MiB / 11019MiB |     28%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce RTX 208...  Off  | 00000000:1B:00.0 Off |                  N/A |
# | 35%   56C    P2    61W / 250W |  10998MiB / 11019MiB |     24%      Default |
# +-------------------------------+----------------------+----------------------+
# |   2  GeForce RTX 208...  Off  | 00000000:3D:00.0 Off |                  N/A |
# | 26%   49C    P2    70W / 250W |  11005MiB / 11019MiB |     34%      Default |
# +-------------------------------+----------------------+----------------------+
# |   3  GeForce RTX 208...  Off  | 00000000:3E:00.0 Off |                  N/A |
# | 16%   38C    P8    22W / 250W |    166MiB / 11019MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   4  GeForce RTX 208...  Off  | 00000000:88:00.0 Off |                  N/A |
# | 16%   35C    P8     1W / 250W |      0MiB / 11019MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   5  GeForce RTX 208...  Off  | 00000000:89:00.0 Off |                  N/A |
# | 38%   52C    P8    11W / 250W |      0MiB / 11019MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   6  GeForce RTX 208...  Off  | 00000000:B1:00.0 Off |                  N/A |
# | 16%   36C    P8     1W / 250W |  10996MiB / 11019MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   7  GeForce RTX 208...  Off  | 00000000:B2:00.0 Off |                  N/A |
# | 16%   36C    P8     3W / 250W |      0MiB / 11019MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |    0     26100      C   ...qibot/miniconda3/envs/tf_2.1/bin/python 10987MiB |
# |    1     13548      C   ...qibot/miniconda3/envs/tf_2.1/bin/python 10987MiB |
# |    2     26100      C   ...qibot/miniconda3/envs/tf_2.1/bin/python   155MiB |
# |    2     38554      C   ...qibot/miniconda3/envs/tf_2.1/bin/python 10839MiB |
# |    3     26100      C   ...qibot/miniconda3/envs/tf_2.1/bin/python   155MiB |
# |    6     12396      C   ...qibot/miniconda3/envs/tf_2.1/bin/python 10985MiB |
# +-----------------------------------------------------------------------------+
# |    1     13548      C   ...qibot/miniconda3/envs/tf_2.1/bin/python 10987MiB |
# |    2     26100      C   ...qibot/miniconda3/envs/tf_2.1/bin/python   155MiB |
# |    2     38554      C   ...qibot/miniconda3/envs/tf_2.1/bin/python 10839MiB |
# |    3     26100      C   ...qibot/miniconda3/envs/tf_2.1/bin/python   155MiB |
# |    6     12396      C   ...qibot/miniconda3/envs/tf_2.1/bin/python 10985MiB |
# +-----------------------------------------------------------------------------+

# %%
seed = 0
import random
import numpy as np
import tensorflow as tf
import os
random.seed(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
os.environ["CUDA_DEVICE_ORDER"] = 'PCI_BUS_ID'
os.environ["CUDA_VISIBLE_DEVICES"] = '5'
os.environ["PYTHONHASHSEED"] = str(seed)

os.environ['TF_DETERMINISTIC_OPS'] = '1'

# %%
import numpy as np
import pandas as pd
# 选择比较好的模型
import seaborn as sns

import matplotlib.pyplot as plt
from tqdm import tqdm
from scipy.signal import resample
from tensorflow.keras import layers
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
import os
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score

from sklearn.preprocessing import StandardScaler,MinMaxScaler
# %load_ext autoreload
# %autoreload 2

def acc_combo(y, y_pred):
    # 数值ID与行为编码的对应关系
    mapping = {0: 'A_0', 1: 'A_1', 2: 'A_2', 3: 'A_3', 
        4: 'D_4', 5: 'A_5', 6: 'B_1',7: 'B_5', 
        8: 'B_2', 9: 'B_3', 10: 'B_0', 11: 'A_6', 
        12: 'C_1', 13: 'C_3', 14: 'C_0', 15: 'B_6', 
        16: 'C_2', 17: 'C_5', 18: 'C_6'}
    # 将行为ID转为编码
    code_y, code_y_pred = mapping[y], mapping[y_pred]
    if code_y == code_y_pred: #编码完全相同得分1.0
        return 1.0
    elif code_y.split("_")[0] == code_y_pred.split("_")[0]: #编码仅字母部分相同得分1.0/7
        return 1.0/7
    elif code_y.split("_")[1] == code_y_pred.split("_")[1]: #编码仅数字部分相同得分1.0/3
        return 1.0/3
    else:
        return 0.0


sample_num = 60

# %%
# !ls /home/zhangqibot/proj/zp
# Out:
# jiaozibei
# jiaozibei

# %%
# !pwd
# Out:
# /home/zhangqibot/proj/lcy/NN/online792remove_decay
# /home/zhangqibot/proj/lcy/NN/online792remove_decay

# %%
root_path  = '/home/zhangqibot/proj/zp/jiaozibei/data/'
train = pd.read_csv(root_path+'sensor_train.csv')
test = pd.read_csv(root_path+'sensor_test.csv')
sub = pd.read_csv(root_path+'提交结果示例.csv')
y = train.groupby('fragment_id')['behavior_id'].min()

# %%
def add_features(df):
    print(df.columns)
    df['acc'] = (df.acc_x ** 2 + df.acc_y ** 2 + df.acc_z ** 2) ** .5
    df['accg'] = (df.acc_xg ** 2 + df.acc_yg ** 2 + df.acc_zg ** 2) ** .5
    df['thetax']=np.arctan(df.acc_xg/
                           np.sqrt(df.acc_yg*df.acc_yg+df.acc_zg*df.acc_zg))*180/np.pi
    df['thetay']=np.arctan(df.acc_yg/
                           np.sqrt(df.acc_xg*df.acc_xg+df.acc_zg*df.acc_zg))*180/np.pi
    df['thetaz']=np.arctan(df.acc_zg/
                           np.sqrt(df.acc_yg*df.acc_yg+df.acc_xg*df.acc_xg))*180/np.pi

    df['xy'] = (df['acc_x'] ** 2 + df['acc_y'] ** 2) ** 0.5
    df['xy_g'] = (df['acc_xg'] ** 2 + df['acc_yg'] ** 2) ** 0.5    
    
    df['g'] = ((df["acc_x"] - df["acc_xg"]) ** 2 + 
                 (df["acc_y"] - df["acc_yg"]) ** 2 + (df["acc_z"] - df["acc_zg"]) ** 2) ** 0.5

    print(df.columns)
    return df

# %%
train=add_features(train)
test=add_features(test)
# Out:
# Index(['fragment_id', 'time_point', 'acc_x', 'acc_y', 'acc_z', 'acc_xg',
#        'acc_yg', 'acc_zg', 'behavior_id'],
#       dtype='object')
# Index(['fragment_id', 'time_point', 'acc_x', 'acc_y', 'acc_z', 'acc_xg',
#        'acc_yg', 'acc_zg', 'behavior_id', 'acc', 'accg', 'thetax', 'thetay',
#        'thetaz', 'xy', 'xy_g', 'g'],
#       dtype='object')
# Index(['fragment_id', 'time_point', 'acc_x', 'acc_y', 'acc_z', 'acc_xg',
#        'acc_yg', 'acc_zg'],
#       dtype='object')
# Index(['fragment_id', 'time_point', 'acc_x', 'acc_y', 'acc_z', 'acc_xg',
#        'acc_yg', 'acc_zg', 'acc', 'accg', 'thetax', 'thetay', 'thetaz', 'xy',
#        'xy_g', 'g'],
#       dtype='object')
# Index(['fragment_id', 'time_point', 'acc_x', 'acc_y', 'acc_z', 'acc_xg',
#        'acc_yg', 'acc_zg', 'behavior_id'],
#       dtype='object')
# Index(['fragment_id', 'time_point', 'acc_x', 'acc_y', 'acc_z', 'acc_xg',
#        'acc_yg', 'acc_zg', 'behavior_id', 'acc', 'accg', 'thetax', 'thetay',
#        'thetaz', 'xy', 'xy_g', 'g'],
#       dtype='object')
# Index(['fragment_id', 'time_point', 'acc_x', 'acc_y', 'acc_z', 'acc_xg',
#        'acc_yg', 'acc_zg'],
#       dtype='object')
# Index(['fragment_id', 'time_point', 'acc_x', 'acc_y', 'acc_z', 'acc_xg',
#        'acc_yg', 'acc_zg', 'acc', 'accg', 'thetax', 'thetay', 'thetaz', 'xy',
#        'xy_g', 'g'],
#       dtype='object')

# %%
group1 = [x for x in train.columns if x not in ['fragment_id', 'time_point','behavior_id']]
group1
# Out:
# ['acc_x',
#  'acc_y',
#  'acc_z',
#  'acc_xg',
#  'acc_yg',
#  'acc_zg',
#  'acc',
#  'accg',
#  'thetax',
#  'thetay',
#  'thetaz',
#  'xy',
#  'xy_g',
#  'g']
# ['acc_x',
#  'acc_y',
#  'acc_z',
#  'acc_xg',
#  'acc_yg',
#  'acc_zg',
#  'acc',
#  'accg',
#  'thetax',
#  'thetay',
#  'thetaz',
#  'xy',
#  'xy_g',
#  'g']

# %%
FEATURE_NUM=14

# %%
x = np.zeros((7292, sample_num, FEATURE_NUM, 1))
t = np.zeros((7500, sample_num, FEATURE_NUM, 1))

from scipy.fftpack import fft
from scipy.signal import resample
def get_fft_values(y_values, N, f_s):
    f_values = np.linspace(0.0, f_s/2.0, N//2)
    fft_values_ = fft(y_values)
    plt.plot(fft_values_)
    plt.show()
    print(fft_values_.shape)
    fft_values = 2.0/N * np.abs(fft_values_[0:N//2])
    print(fft_values.shape)
    return f_values, fft_values

# tmp = train[train.fragment_id == 0][:sample_num]

# get_fft_values(tmp["acc"].values,60,5)

# %%
train = train[['fragment_id', 'time_point', 'behavior_id']+group1]
test = test[['fragment_id', 'time_point']+group1]
print(train.columns)

for i in tqdm(range(7292)):
    tmp = train[train.fragment_id == i][:sample_num]
    x[i,:,:,0] = resample(tmp.drop(['fragment_id', 'time_point', 'behavior_id'],
                                    axis=1)[group1], sample_num, np.array(tmp.time_point))[0].reshape(sample_num,FEATURE_NUM)
for i in tqdm(range(7500)):
    tmp = test[test.fragment_id == i][:sample_num]
    t[i,:,:,0] = resample(tmp.drop(['fragment_id', 'time_point'],
                                    axis=1)[group1], sample_num, np.array(tmp.time_point))[0].reshape(sample_num,FEATURE_NUM)
# Out:
#   0%|          | 36/7292 [00:00<00:20, 357.15it/s]
# Index(['fragment_id', 'time_point', 'behavior_id', 'acc_x', 'acc_y', 'acc_z',
#        'acc_xg', 'acc_yg', 'acc_zg', 'acc', 'accg', 'thetax', 'thetay',
#        'thetaz', 'xy', 'xy_g', 'g'],
#       dtype='object')
# Index(['fragment_id', 'time_point', 'behavior_id', 'acc_x', 'acc_y', 'acc_z',
#        'acc_xg', 'acc_yg', 'acc_zg', 'acc', 'accg', 'thetax', 'thetay',
#        'thetaz', 'xy', 'xy_g', 'g'],
#       dtype='object')
# 100%|██████████| 7292/7292 [00:18<00:00, 390.71it/s]
#   0%|          | 0/7500 [00:00<?, ?it/s]
# 100%|██████████| 7500/7500 [00:18<00:00, 398.38it/s]

# %%
group1
# Out:
# ['acc_x',
#  'acc_y',
#  'acc_z',
#  'acc_xg',
#  'acc_yg',
#  'acc_zg',
#  'acc',
#  'accg',
#  'thetax',
#  'thetay',
#  'thetaz',
#  'xy',
#  'xy_g',
#  'g']
# ['acc_x',
#  'acc_y',
#  'acc_z',
#  'acc_xg',
#  'acc_yg',
#  'acc_zg',
#  'acc',
#  'accg',
#  'thetax',
#  'thetay',
#  'thetaz',
#  'xy',
#  'xy_g',
#  'g']

# %%
# 一个完成了的generator
def data_generator(data,label,shuffle,batch_size):
    """
    data:array  (7292, 60, 14, 1)
    label:array (7292,)
    """
    
    count=0
    np.random.seed(seed)# 保证结果可重复
    length=len(data)
    while True:
        
        if count==0 or (count + 1) * batch_size > length:  # 如果是第一个或者最后一个batch
            count=0
            shuffle_index = list(range(length))
            np.random.shuffle(shuffle_index)   ## 对索引进行打乱
        
        start = count * batch_size  ## batch的起始点
        end = (count + 1) * batch_size ## batch的终点
        inds=shuffle_index[start:end]
        count+=1
        print(count,inds)
        yield data[inds],label[inds]

count=0
for a,b in data_generator(x[:10],y[:10],True,3):
    print(a.shape,b.shape)
    count+=1
    if count==20:
        break
# Out:
# 1 [2, 8, 4]
# (3, 60, 14, 1) (3,)
# 2 [9, 1, 6]
# (3, 60, 14, 1) (3,)
# 3 [7, 3, 0]
# (3, 60, 14, 1) (3,)
# 1 [3, 5, 1]
# (3, 60, 14, 1) (3,)
# 2 [2, 9, 8]
# (3, 60, 14, 1) (3,)
# 3 [0, 6, 7]
# (3, 60, 14, 1) (3,)
# 1 [2, 3, 8]
# (3, 60, 14, 1) (3,)
# 2 [4, 5, 1]
# (3, 60, 14, 1) (3,)
# 3 [0, 6, 9]
# (3, 60, 14, 1) (3,)
# 1 [6, 1, 9]
# (3, 60, 14, 1) (3,)
# 2 [2, 7, 5]
# (3, 60, 14, 1) (3,)
# 3 [8, 0, 3]
# (3, 60, 14, 1) (3,)
# 1 [5, 2, 7]
# (3, 60, 14, 1) (3,)
# 2 [4, 1, 0]
# (3, 60, 14, 1) (3,)
# 3 [6, 8, 9]
# (3, 60, 14, 1) (3,)
# 1 [1, 8, 9]
# (3, 60, 14, 1) (3,)
# 2 [5, 2, 6]
# (3, 60, 14, 1) (3,)
# 3 [3, 7, 4]
# (3, 60, 14, 1) (3,)
# 1 [3, 2, 1]
# (3, 60, 14, 1) (3,)
# 2 [7, 8, 6]
# (3, 60, 14, 1) (3,)
# 1 [2, 8, 4]
# (3, 60, 14, 1) (3,)
# 2 [9, 1, 6]
# (3, 60, 14, 1) (3,)
# 3 [7, 3, 0]
# (3, 60, 14, 1) (3,)
# 1 [3, 5, 1]
# (3, 60, 14, 1) (3,)
# 2 [2, 9, 8]
# (3, 60, 14, 1) (3,)
# 3 [0, 6, 7]
# (3, 60, 14, 1) (3,)
# 1 [2, 3, 8]
# (3, 60, 14, 1) (3,)
# 2 [4, 5, 1]
# (3, 60, 14, 1) (3,)
# 3 [0, 6, 9]
# (3, 60, 14, 1) (3,)
# 1 [6, 1, 9]
# (3, 60, 14, 1) (3,)
# 2 [2, 7, 5]
# (3, 60, 14, 1) (3,)
# 3 [8, 0, 3]
# (3, 60, 14, 1) (3,)
# 1 [5, 2, 7]
# (3, 60, 14, 1) (3,)
# 2 [4, 1, 0]
# (3, 60, 14, 1) (3,)
# 3 [6, 8, 9]
# (3, 60, 14, 1) (3,)
# 1 [1, 8, 9]
# (3, 60, 14, 1) (3,)
# 2 [5, 2, 6]
# (3, 60, 14, 1) (3,)
# 3 [3, 7, 4]
# (3, 60, 14, 1) (3,)
# 1 [3, 2, 1]
# (3, 60, 14, 1) (3,)
# 2 [7, 8, 6]
# (3, 60, 14, 1) (3,)

# %%
# 一个完成了的generator
def data_generator(data,label,class17label,batch_size):
    """
    data:array  (7292, 60, 14, 1)
    label:array (7292,)
    class17label: series
    """
    class17label=np.asarray(class17label)
    length=len(data)
    seq_length=len(data[0])
    half_seq_length=int(seq_length/2)
    
    # index2label
    index2label=dict(zip(range(length),class17label))
    
    label2index={}
#     print(class17label)
    for i in range(length):
#         print(class17label[i],label2index.get(class17label[i],[]))
        label2index[class17label[i]]=label2index.get(class17label[i],[])
        label2index[class17label[i]].append(i)

    count=0
    np.random.seed(seed)# 保证结果可重复
    
    while True:
        
        if count==0 or (count + 1) * batch_size > length:  # 如果是第一个或者最后一个batch
            count=0
            shuffle_index = list(range(length))
            np.random.shuffle(shuffle_index)   ## 对索引进行打乱
        
        start = count * batch_size  ## batch的起始点
        end = (count + 1) * batch_size ## batch的终点
        inds=shuffle_index[start:end]

        count+=1
        
        if random.choice([0,1,1,1,1,1,1]):
            # minxup
            #one specific index -> label -> all the index belong to this
            choice_index=[random.choice(label2index[index2label[x]]) for x in inds]   # get the random choice seq(waiting for concat)
            # 1st 前1/2 seq_length 点原始  后1/2 seq_length 点随机
            res_x_orig=data[inds,:half_seq_length]
            res_x=data[choice_index,half_seq_length:]

    #         print(inds)
    #         print(data.shape,res_x_orig.shape,res_x.shape,np.concatenate((res_x_orig,res_x),axis=1).shape)
            yield np.concatenate((res_x_orig,res_x),axis=1),\
                    [label[0][inds],label[1][inds],label[2][inds]]
        else:
        
            yield data[inds],[label[0][inds],label[1][inds],label[2][inds]]
            
    

count=0
for a,b in data_generator(x,[y,y,y],y,32):
    print(a.shape,b[0].shape)
    count+=1
    if count==20:
        break
# Out:
# (32, 60, 14, 1) (32,)
# (32, 60, 14, 1) (32,)
# (32, 60, 14, 1) (32,)
# (32, 60, 14, 1) (32,)
# (32, 60, 14, 1) (32,)
# (32, 60, 14, 1) (32,)
# (32, 60, 14, 1) (32,)
# (32, 60, 14, 1) (32,)
# (32, 60, 14, 1) (32,)
# (32, 60, 14, 1) (32,)
# (32, 60, 14, 1) (32,)
# (32, 60, 14, 1) (32,)
# (32, 60, 14, 1) (32,)
# (32, 60, 14, 1) (32,)
# (32, 60, 14, 1) (32,)
# (32, 60, 14, 1) (32,)
# (32, 60, 14, 1) (32,)
# (32, 60, 14, 1) (32,)
# (32, 60, 14, 1) (32,)
# (32, 60, 14, 1) (32,)

# %%
def ConvBNRelu(X,filters,kernal_size=(3,3)):
    X = Conv2D(filters=filters,
               kernel_size=kernal_size,
#                activation='relu',
               use_bias=False,
               padding='same')(X)
    X = BatchNormalization()(X)
    X = Activation('relu')(X)
    return X


def ConvRelu(X,filters,kernal_size=(3,3)):
    X = Conv2D(filters=filters,
               kernel_size=kernal_size,
               activation='relu',
               use_bias=False,
               padding='same')(X)
    return X


def squeeze_excitation_layer(x, out_dim,ratio=8):
    '''
    SE module performs inter-channel weighting.
    '''
    squeeze = GlobalAveragePooling2D()(x)

    excitation = Dense(units=out_dim // ratio)(squeeze)
    excitation = Activation('relu')(excitation)
    excitation = Dense(units=out_dim)(excitation)
    excitation = Activation('sigmoid')(excitation)
    excitation = Reshape((1,1,out_dim))(excitation)
    scale = multiply([x,excitation])
    return scale

# def SE_Residual(X):
#     A = 
#     X = squeeze_excitation_layer(X,128)
#     X =  Add()([X,A])
    

def lenet5(input):
    A = ConvBNRelu(input,64,kernal_size=(3,3))
#     B = ConvBNRelu(input,16,kernal_size=(5,1))
#     C = ConvBNRelu(input,16,kernal_size=(7,1))
#     ABC = layers.Concatenate()([A,B,C])
    X = ConvBNRelu(A,128)
#     X = squeeze_excitation_layer(X,128)
    X = Dropout(0.2)(X)

    X = AveragePooling2D()(X)
    
    X = ConvBNRelu(X,256)
    X = Dropout(0.3)(X)
#     X = squeeze_excitation_layer(X,256)
    X = ConvBNRelu(X,512)   
    X = Dropout(0.5)(X)
#     X = squeeze_excitation_layer(X,512)
#     X = GlobalMaxPooling2D()(X)
    X = GlobalAveragePooling2D()(X)
    
#     X = BatchNormalization()(X)
    return X
import tensorflow as tf
def Net(sample_num):
    input1 = Input(shape=(sample_num, FEATURE_NUM, 1))
    part = tf.split(input1,axis=2, num_or_size_splits = [6, 2, 6])
#     res = tf.split(c, axis = 3, num_or_size_splits = [2, 2, 4])
    
    
    X1 = Concatenate(axis=-2)([part[0],part[1]])
    X1 = lenet5(X1)
    X1 = BatchNormalization()(X1)
    X1 = Dense(128, activation='relu')(X1)
    X1 = BatchNormalization()(X1)
    X1 = Dropout(0.2)(X1)

    X2 = Concatenate(axis=-2)([part[0],part[2]])
    X2 = lenet5(X2)    
    X2 = BatchNormalization()(X2)
#     X = Dense(512, activation='relu')(X)
#     X = BatchNormalization()(X)
    X2 = Dense(128, activation='relu')(X2)
    X2 = BatchNormalization()(X2)
    X2 = Dropout(0.2)(X2)
    
    X = Concatenate(axis=-1)([X1,X2])
    
#     X = Dense(256)(X)    
    
    output1 = Dense(4, activation='softmax', name='4class')(X)   # 大类-字母
#     output2 = Dense(128)(X)
#     output2 = Dense(64)(X)
    X = Dense(64)(X)
    output2 = Dense(7, activation='softmax', name='7class')(X)   # 大类-数字
#     X = Dense(32)(X)
#     X = Concatenate(axis=-1)([X,output1,output2])
    X = Dense(64)(X)
    output3 = Dense(19, activation='softmax',name='19class')(X) #小类
    
    
    return Model([input1], [output1,output2,output3])

model = Net(60)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 60, 14, 1)]  0
# __________________________________________________________________________________________________
# tf_op_layer_split (TensorFlowOp [(None, 60, 6, 1), ( 0           input_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 60, 8, 1)     0           tf_op_layer_split[0][0]
#                                                                  tf_op_layer_split[0][1]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 60, 12, 1)    0           tf_op_layer_split[0][0]
#                                                                  tf_op_layer_split[0][2]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 60, 8, 64)    576         concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 60, 12, 64)   576         concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 60, 8, 64)    256         conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 60, 12, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 60, 8, 64)    0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 60, 12, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 60, 8, 128)   73728       activation[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 60, 12, 128)  73728       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 60, 8, 128)   512         conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 60, 12, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 60, 8, 128)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 60, 12, 128)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 60, 8, 128)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 60, 12, 128)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 30, 4, 128)   0           dropout[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 30, 6, 128)   0           dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 30, 4, 256)   294912      average_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 30, 6, 256)   294912      average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 30, 4, 256)   1024        conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 30, 6, 256)   1024        conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 30, 4, 256)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 30, 6, 256)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 30, 4, 256)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 30, 6, 256)   0           activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 30, 4, 512)   1179648     dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 30, 6, 512)   1179648     dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 30, 4, 512)   2048        conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 30, 6, 512)   2048        conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 30, 4, 512)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 30, 6, 512)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 30, 4, 512)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 30, 6, 512)   0           activation_7[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 512)          0           dropout_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 512)          0           dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 512)          2048        global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 512)          2048        global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          65664       batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          65664       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 128)          512         dense[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 128)          512         dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 128)          0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 128)          0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 256)          0           dropout_3[0][0]
#                                                                  dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           16448       concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 64)           4160        dense_2[0][0]
# __________________________________________________________________________________________________
# 4class (Dense)                  (None, 4)            1028        concatenate_2[0][0]
# __________________________________________________________________________________________________
# 7class (Dense)                  (None, 7)            455         dense_2[0][0]
# __________________________________________________________________________________________________
# 19class (Dense)                 (None, 19)           1235        dense_3[0][0]
# ==================================================================================================
# Total params: 3,265,182
# Trainable params: 3,258,782
# Non-trainable params: 6,400
# __________________________________________________________________________________________________
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 60, 14, 1)]  0
# __________________________________________________________________________________________________
# tf_op_layer_split (TensorFlowOp [(None, 60, 6, 1), ( 0           input_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 60, 8, 1)     0           tf_op_layer_split[0][0]
#                                                                  tf_op_layer_split[0][1]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 60, 12, 1)    0           tf_op_layer_split[0][0]
#                                                                  tf_op_layer_split[0][2]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 60, 8, 64)    576         concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 60, 12, 64)   576         concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 60, 8, 64)    256         conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 60, 12, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 60, 8, 64)    0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 60, 12, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 60, 8, 128)   73728       activation[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 60, 12, 128)  73728       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 60, 8, 128)   512         conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 60, 12, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 60, 8, 128)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 60, 12, 128)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 60, 8, 128)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 60, 12, 128)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 30, 4, 128)   0           dropout[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 30, 6, 128)   0           dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 30, 4, 256)   294912      average_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 30, 6, 256)   294912      average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 30, 4, 256)   1024        conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 30, 6, 256)   1024        conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 30, 4, 256)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 30, 6, 256)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 30, 4, 256)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 30, 6, 256)   0           activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 30, 4, 512)   1179648     dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 30, 6, 512)   1179648     dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 30, 4, 512)   2048        conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 30, 6, 512)   2048        conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 30, 4, 512)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 30, 6, 512)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 30, 4, 512)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 30, 6, 512)   0           activation_7[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 512)          0           dropout_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 512)          0           dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 512)          2048        global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 512)          2048        global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          65664       batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          65664       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 128)          512         dense[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 128)          512         dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 128)          0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 128)          0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 256)          0           dropout_3[0][0]
#                                                                  dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           16448       concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 64)           4160        dense_2[0][0]
# __________________________________________________________________________________________________
# 4class (Dense)                  (None, 4)            1028        concatenate_2[0][0]
# __________________________________________________________________________________________________
# 7class (Dense)                  (None, 7)            455         dense_2[0][0]
# __________________________________________________________________________________________________
# 19class (Dense)                 (None, 19)           1235        dense_3[0][0]
# ==================================================================================================
# Total params: 3,265,182
# Trainable params: 3,258,782
# Non-trainable params: 6,400
# __________________________________________________________________________________________________

# %% [markdown]
# # generator
#
# ----------------
# ```
# generator 什么都不改
# ```
#
# [0.834, 0.834, 0.821, 0.828, 0.844] 0.8321999999999999
#
# [0.8592643363034024, 0.8596233558536488, 0.8481612123587415, 0.8540074466000378, 0.867234959827551] 0.8576582621886765
#
# -------------------
#
# ```
#         if random.choice([0,1]):
#             # minxup
#             #one specific index -> label -> all the index belong to this
#             choice_index=[random.choice(label2index[index2label[x]]) for x in inds]   # get the random choice seq(waiting for concat)
#             # 1st 前1/2 seq_length 点原始  后1/2 seq_length 点随机
#             res_x_orig=data[inds,:half_seq_length]
#             res_x=data[choice_index,half_seq_length:]
#
#     #         print(inds)
#     #         print(data.shape,res_x_orig.shape,res_x.shape,np.concatenate((res_x_orig,res_x),axis=1).shape)
#             yield np.concatenate((res_x_orig,res_x),axis=1),\
#                     [label[0][inds],label[1][inds],label[2][inds]]
#         else:
#
#             yield data[inds],[label[0][inds],label[1][inds],label[2][inds]]
#
#
# ```
#
#
# [0.864, 0.832, 0.857, 0.796, 0.844] 0.8386000000000001
#
# [0.881686739123338, 0.857175495283787, 0.8775230256711722, 0.8275850806714998, 0.8664184466653578] 0.862077757483031
#
#
#
# ---------------------
# mixup
#
# ```
#
#         if random.choice([0,1,1]):
#             # minxup
#             #one specific index -> label -> all the index belong to this
#             choice_index=[random.choice(label2index[index2label[x]]) for x in inds]   # get the random choice seq(waiting for concat)
#             # 1st 前1/2 seq_length 点原始  后1/2 seq_length 点随机
#             res_x_orig=data[inds,:half_seq_length]
#             res_x=data[choice_index,half_seq_length:]
#
#     #         print(inds)
#     #         print(data.shape,res_x_orig.shape,res_x.shape,np.concatenate((res_x_orig,res_x),axis=1).shape)
#             yield np.concatenate((res_x_orig,res_x),axis=1),\
#                     [label[0][inds],label[1][inds],label[2][inds]]
#         else:
#
#             yield data[inds],[label[0][inds],label[1][inds],label[2][inds]]
#
# ```
#
#
#
# [0.855, 0.846, 0.848, 0.84, 0.802] 0.8382
#
#
# [0.8759097881784637, 0.8700349228107948, 0.8704683519498317, 0.8643934940231219, 0.8303285648964647] 0.8622270243717353
#
#
#
#
# --------------------------------------------
# ```
#         if random.choice([0,1,1,1,1,1]):
# ```
#
# [0.853, 0.841, 0.851, 0.838, 0.837] 0.844
#
#
# [0.872319592676, 0.8656940500669065, 0.8718400940623146, 0.8622378992749348, 0.8622052387484468] 0.8668593749657205

# %%
# 两个输出    
mapping = {0: 'A_0', 1: 'A_1', 2: 'A_2', 3: 'A_3', 
4: 'D_4', 5: 'A_5', 6: 'B_1',7: 'B_5', 
8: 'B_2', 9: 'B_3', 10: 'B_0', 11: 'A_6', 
12: 'C_1', 13: 'C_3', 14: 'C_0', 15: 'B_6', 
16: 'C_2', 17: 'C_5', 18: 'C_6'}
# 每一个大类输出 4
new_mapping = {'A':0,'B':1,'C':2,'D':3}

from sklearn.utils.class_weight import compute_class_weight
# y_train_weight = compute_sample_weight("balanced", train['behavior_id'])
classweights1=compute_class_weight("balanced",['A','B','C','D'],\
                                   pd.read_csv(root_path+'sensor_train.csv')['behavior_id'].apply(lambda x:mapping[x][0]))
classweights1=pd.DataFrame(classweights1)[0].to_dict()



classweights2=compute_class_weight("balanced",list(range(7)),\
                                   pd.read_csv(root_path+'sensor_train.csv')['behavior_id'].apply(lambda x:int(mapping[x][2])))
classweights2=pd.DataFrame(classweights2)[0].to_dict()



from sklearn.utils.class_weight import compute_class_weight
# y_train_weight = compute_sample_weight("balanced", train['behavior_id'])
classweights3=compute_class_weight("balanced",np.array(range(19)), pd.read_csv(root_path+'sensor_train.csv')['behavior_id'])
classweights3=pd.DataFrame(classweights3)[0].to_dict()
classweights1,classweights2,classweights3
# Out:
# ({0: 0.7453285438934641,
#   1: 0.7866762590992484,
#   2: 0.8681079382183908,
#   3: 4.251549256356949},
#  {0: 1.757195321956318,
#   1: 0.4815479398086302,
#   2: 0.9616022823865589,
#   3: 1.1412232173040497,
#   4: 2.4294567179182565,
#   5: 1.2367567913331454,
#   6: 0.8210787010495146},
#  {0: 1.6146639588513296,
#   1: 0.5658077637797579,
#   2: 0.9428223116223914,
#   3: 1.1544614165363905,
#   4: 0.895063001338305,
#   5: 1.120093850476494,
#   6: 0.5129293816036677,
#   7: 1.6147804233607677,
#   8: 1.1629774436090226,
#   9: 1.3287818013695207,
#   10: 1.639495846903968,
#   11: 0.8571276001942526,
#   12: 0.5209381219191084,
#   13: 1.3164363042146117,
#   14: 3.1705588145409553,
#   15: 0.8020390423628304,
#   16: 1.108447580802777,
#   17: 1.4649467209444893,
#   18: 1.12076674790857})
# ({0: 0.7453285438934641,
#   1: 0.7866762590992484,
#   2: 0.8681079382183908,
#   3: 4.251549256356949},
#  {0: 1.757195321956318,
#   1: 0.4815479398086302,
#   2: 0.9616022823865589,
#   3: 1.1412232173040497,
#   4: 2.4294567179182565,
#   5: 1.2367567913331454,
#   6: 0.8210787010495146},
#  {0: 1.6146639588513296,
#   1: 0.5658077637797579,
#   2: 0.9428223116223914,
#   3: 1.1544614165363905,
#   4: 0.895063001338305,
#   5: 1.120093850476494,
#   6: 0.5129293816036677,
#   7: 1.6147804233607677,
#   8: 1.1629774436090226,
#   9: 1.3287818013695207,
#   10: 1.639495846903968,
#   11: 0.8571276001942526,
#   12: 0.5209381219191084,
#   13: 1.3164363042146117,
#   14: 3.1705588145409553,
#   15: 0.8020390423628304,
#   16: 1.108447580802777,
#   17: 1.4649467209444893,
#   18: 1.12076674790857})

# %%
# [:,:,:,[1]]
train = x
test = t

    
fold_num=5
kfold = StratifiedKFold(fold_num,random_state=42,shuffle=True)
proba_t = np.zeros((7500, 19))
proba_oof = np.zeros((7292,19))

oof_score = []
oof_comm = []
history = []

from tensorflow.keras.losses import categorical_crossentropy
def custom_loss(y_true, y_pred):
    return categorical_crossentropy(y_true, y_pred, label_smoothing=0.05)

# 两个输出    
mapping = {0: 'A_0', 1: 'A_1', 2: 'A_2', 3: 'A_3', 
4: 'D_4', 5: 'A_5', 6: 'B_1',7: 'B_5', 
8: 'B_2', 9: 'B_3', 10: 'B_0', 11: 'A_6', 
12: 'C_1', 13: 'C_3', 14: 'C_0', 15: 'B_6', 
16: 'C_2', 17: 'C_5', 18: 'C_6'}
# 每一个大类输出 4
new_mapping = {'A':0,'B':1,'C':2,'D':3}
y_1 = to_categorical([new_mapping[mapping[x][0]] for x in y], num_classes=4)
# 每一个大类输出 
new_mapping = {'A':0,'B':1,'C':2,'D':3}
y_2 = to_categorical([mapping[x][2] for x in y], num_classes=7)
# 每一个小类的输出 19
y_3 = to_categorical(y, num_classes=19)
# y_3=y


for fold, (xx, yy) in enumerate(kfold.split(train, y)):

    mapping = {0: 'A_0', 1: 'A_1', 2: 'A_2', 3: 'A_3', 
    4: 'D_4', 5: 'A_5', 6: 'B_1',7: 'B_5', 
    8: 'B_2', 9: 'B_3', 10: 'B_0', 11: 'A_6', 
    12: 'C_1', 13: 'C_3', 14: 'C_0', 15: 'B_6', 
    16: 'C_2', 17: 'C_5', 18: 'C_6'}
    new_mapping = {'A':0,'B':1,'C':2,'D':3}
    
    model = Net(60)
    model.summary()
    model.compile(loss=[custom_loss,custom_loss,custom_loss],loss_weights=[3,7,21],
                  optimizer=Adam(),
                  metrics=["acc"])#'',localscore

    plateau3 = ReduceLROnPlateau(monitor="19class_acc",
                                verbose=1,
                                mode='max',
                                factor=0.5,
                                patience=18)
    early_stopping = EarlyStopping(monitor="val_19class_acc",
                                   verbose=1,
                                   mode='max',
                                   patience=60)

    checkpoint = ModelCheckpoint(f'Conv2d_multiloss_mixup_fold{fold}.h5',
                                 monitor="val_19class_acc",
                                 verbose=0,
                                 mode='max',
                                 save_best_only=True)
    
    train_res = model.fit(data_generator(train[xx], [y_1[xx], y_2[xx], y_3[xx]],y[xx],32),
              epochs=1000,
              steps_per_epoch=len(xx) // 32,
              verbose=1,
              shuffle=True,
              validation_data=(train[yy], [y_1[yy], y_2[yy],y_3[yy]]),
              callbacks=[plateau3, early_stopping, checkpoint],
                         class_weight=[classweights1,classweights2,classweights3])

    history.append(train_res)
    
    model.load_weights(f'Conv2d_multiloss_mixup_fold{fold}.h5')
    proba_t += model.predict(test, verbose=0, batch_size=1024)[2] / fold_num 
    proba_oof[yy] += model.predict(train[yy],verbose=0,batch_size=1024) [2]

    oof_y = np.argmax(proba_oof[yy], axis=1)
    acc = round(accuracy_score(y[yy], oof_y),3)
    print(acc)
    oof_score.append(acc)
    scores = sum(acc_combo(y_true, y_pred) for y_true, y_pred in zip(y[yy], oof_y)) / oof_y.shape[0]
    oof_comm.append(scores)   
    print(round(scores, 5))
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 60, 14, 1)]  0
# __________________________________________________________________________________________________
# tf_op_layer_split_1 (TensorFlow [(None, 60, 6, 1), ( 0           input_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 60, 8, 1)     0           tf_op_layer_split_1[0][0]
#                                                                  tf_op_layer_split_1[0][1]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 60, 12, 1)    0           tf_op_layer_split_1[0][0]
#                                                                  tf_op_layer_split_1[0][2]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 60, 8, 64)    576         concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 60, 12, 64)   576         concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 60, 8, 64)    256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 60, 12, 64)   256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 60, 8, 64)    0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 60, 12, 64)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 60, 8, 128)   73728       activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 60, 12, 128)  73728       activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 60, 8, 128)   512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 60, 12, 128)  512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 60, 8, 128)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 60, 12, 128)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 60, 8, 128)   0           activation_9[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 60, 12, 128)  0           activation_13[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 30, 4, 128)   0           dropout_8[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 30, 6, 128)   0           dropout_12[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 30, 4, 256)   294912      average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 30, 6, 256)   294912      average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 30, 4, 256)   1024        conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 30, 6, 256)   1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 30, 4, 256)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 30, 6, 256)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 30, 4, 256)   0           activation_10[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 30, 6, 256)   0           activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 30, 4, 512)   1179648     dropout_9[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 30, 6, 512)   1179648     dropout_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 30, 4, 512)   2048        conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 30, 6, 512)   2048        conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 30, 4, 512)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 30, 6, 512)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 30, 4, 512)   0           activation_11[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 30, 6, 512)   0           activation_15[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 512)          0           dropout_10[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 512)          0           dropout_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 512)          2048        global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 512)          2048        global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 128)          65664       batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 128)          65664       batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 128)          512         dense_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 128)          512         dense_5[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 128)          0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 128)          0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 256)          0           dropout_11[0][0]
#                                                                  dropout_15[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 64)           16448       concatenate_5[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 64)           4160        dense_6[0][0]
# __________________________________________________________________________________________________
# 4class (Dense)                  (None, 4)            1028        concatenate_5[0][0]
# __________________________________________________________________________________________________
# 7class (Dense)                  (None, 7)            455         dense_6[0][0]
# __________________________________________________________________________________________________
# 19class (Dense)                 (None, 19)           1235        dense_7[0][0]
# ==================================================================================================
# Total params: 3,265,182
# Trainable params: 3,258,782
# Non-trainable params: 6,400
# __________________________________________________________________________________________________
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 60, 14, 1)]  0
# __________________________________________________________________________________________________
# tf_op_layer_split_1 (TensorFlow [(None, 60, 6, 1), ( 0           input_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 60, 8, 1)     0           tf_op_layer_split_1[0][0]
#                                                                  tf_op_layer_split_1[0][1]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 60, 12, 1)    0           tf_op_layer_split_1[0][0]
#                                                                  tf_op_layer_split_1[0][2]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 60, 8, 64)    576         concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 60, 12, 64)   576         concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 60, 8, 64)    256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 60, 12, 64)   256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 60, 8, 64)    0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 60, 12, 64)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 60, 8, 128)   73728       activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 60, 12, 128)  73728       activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 60, 8, 128)   512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 60, 12, 128)  512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 60, 8, 128)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 60, 12, 128)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 60, 8, 128)   0           activation_9[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 60, 12, 128)  0           activation_13[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 30, 4, 128)   0           dropout_8[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 30, 6, 128)   0           dropout_12[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 30, 4, 256)   294912      average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 30, 6, 256)   294912      average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 30, 4, 256)   1024        conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 30, 6, 256)   1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 30, 4, 256)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 30, 6, 256)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 30, 4, 256)   0           activation_10[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 30, 6, 256)   0           activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 30, 4, 512)   1179648     dropout_9[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 30, 6, 512)   1179648     dropout_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 30, 4, 512)   2048        conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 30, 6, 512)   2048        conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 30, 4, 512)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 30, 6, 512)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 30, 4, 512)   0           activation_11[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 30, 6, 512)   0           activation_15[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 512)          0           dropout_10[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 512)          0           dropout_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 512)          2048        global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 512)          2048        global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 128)          65664       batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 128)          65664       batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 128)          512         dense_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 128)          512         dense_5[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 128)          0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 128)          0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 256)          0           dropout_11[0][0]
#                                                                  dropout_15[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 64)           16448       concatenate_5[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 64)           4160        dense_6[0][0]
# __________________________________________________________________________________________________
# 4class (Dense)                  (None, 4)            1028        concatenate_5[0][0]
# __________________________________________________________________________________________________
# 7class (Dense)                  (None, 7)            455         dense_6[0][0]
# __________________________________________________________________________________________________
# 19class (Dense)                 (None, 19)           1235        dense_7[0][0]
# ==================================================================================================
# Total params: 3,265,182
# Trainable params: 3,258,782
# Non-trainable params: 6,400
# __________________________________________________________________________________________________
# Train for 182 steps, validate on 1459 samples
# Epoch 1/1000
# Train for 182 steps, validate on 1459 samples
# Epoch 1/1000
# 182/182 [==============================] - 10s 53ms/step - loss: 57.3626 - 4class_loss: 1.1098 - 7class_loss: 1.4843 - 19class_loss: 2.0783 - 4class_acc: 0.5163 - 7class_acc: 0.4526 - 19class_acc: 0.3292 - val_loss: 72.3889 - val_4class_loss: 1.2803 - val_7class_loss: 1.6307 - val_19class_loss: 2.7052 - val_4class_acc: 0.4407 - val_7class_acc: 0.4085 - val_19class_acc: 0.2200
# 182/182 [==============================] - 10s 53ms/step - loss: 57.3626 - 4class_loss: 1.1098 - 7class_loss: 1.4843 - 19class_loss: 2.0783 - 4class_acc: 0.5163 - 7class_acc: 0.4526 - 19class_acc: 0.3292 - val_loss: 72.3889 - val_4class_loss: 1.2803 - val_7class_loss: 1.6307 - val_19class_loss: 2.7052 - val_4class_acc: 0.4407 - val_7class_acc: 0.4085 - val_19class_acc: 0.2200
# Epoch 2/1000
#   4/182 [..............................] - ETA: 4s - loss: 44.1792 - 4class_loss: 0.8454 - 7class_loss: 1.1467 - 19class_loss: 1.6008 - 4class_acc: 0.6016 - 7class_acc: 0.5781 - 19class_acc: 0.4766Epoch 2/1000
# 182/182 [==============================] - 5s 27ms/step - loss: 47.0466 - 4class_loss: 0.8707 - 7class_loss: 1.2364 - 19class_loss: 1.7038 - 4class_acc: 0.6284 - 7class_acc: 0.5192 - 19class_acc: 0.4358 - val_loss: 55.6293 - val_4class_loss: 0.9330 - val_7class_loss: 1.4679 - val_19class_loss: 2.0211 - val_4class_acc: 0.6539 - val_7class_acc: 0.5065 - val_19class_acc: 0.3242
# 182/182 [==============================] - 5s 27ms/step - loss: 47.0466 - 4class_loss: 0.8707 - 7class_loss: 1.2364 - 19class_loss: 1.7038 - 4class_acc: 0.6284 - 7class_acc: 0.5192 - 19class_acc: 0.4358 - val_loss: 55.6293 - val_4class_loss: 0.9330 - val_7class_loss: 1.4679 - val_19class_loss: 2.0211 - val_4class_acc: 0.6539 - val_7class_acc: 0.5065 - val_19class_acc: 0.3242
# Epoch 3/1000
#   1/182 [..............................] - ETA: 4s - loss: 46.6555 - 4class_loss: 1.1636 - 7class_loss: 1.5142 - 19class_loss: 1.5507 - 4class_acc: 0.7188 - 7class_acc: 0.5625 - 19class_acc: 0.4062Epoch 3/1000
# 182/182 [==============================] - 5s 25ms/step - loss: 43.1142 - 4class_loss: 0.7881 - 7class_loss: 1.1216 - 19class_loss: 1.5666 - 4class_acc: 0.6714 - 7class_acc: 0.5616 - 19class_acc: 0.4919 - val_loss: 78.1135 - val_4class_loss: 1.3936 - val_7class_loss: 1.5555 - val_19class_loss: 2.9859 - val_4class_acc: 0.5147 - val_7class_acc: 0.4626 - val_19class_acc: 0.30710 - 4class_loss: 0.8066 - 7class_loss: 1.1486 - 19c
# 182/182 [==============================] - 5s 25ms/step - loss: 43.1142 - 4class_loss: 0.7881 - 7class_loss: 1.1216 - 19class_loss: 1.5666 - 4class_acc: 0.6714 - 7class_acc: 0.5616 - 19class_acc: 0.4919 - val_loss: 78.1135 - val_4class_loss: 1.3936 - val_7class_loss: 1.5555 - val_19class_loss: 2.9859 - val_4class_acc: 0.5147 - val_7class_acc: 0.4626 - val_19class_acc: 0.3071
# Epoch 4/1000
#   4/182 [..............................] - ETA: 4s - loss: 39.0084 - 4class_loss: 0.7116 - 7class_loss: 1.1194 - 19class_loss: 1.3828 - 4class_acc: 0.7344 - 7class_acc: 0.5938 - 19class_acc: 0.5859Epoch 4/1000
# 182/182 [==============================] - 5s 27ms/step - loss: 42.1169 - 4class_loss: 0.7415 - 7class_loss: 1.1041 - 19class_loss: 1.5316 - 4class_acc: 0.6968 - 7class_acc: 0.5728 - 19class_acc: 0.5072 - val_loss: 64.9620 - val_4class_loss: 1.1771 - val_7class_loss: 1.5843 - val_19class_loss: 2.3841 - val_4class_acc: 0.5545 - val_7class_acc: 0.4839 - val_19class_acc: 0.3667
# 182/182 [==============================] - 5s 27ms/step - loss: 42.1169 - 4class_loss: 0.7415 - 7class_loss: 1.1041 - 19class_loss: 1.5316 - 4class_acc: 0.6968 - 7class_acc: 0.5728 - 19class_acc: 0.5072 - val_loss: 64.9620 - val_4class_loss: 1.1771 - val_7class_loss: 1.5843 - val_19class_loss: 2.3841 - val_4class_acc: 0.5545 - val_7class_acc: 0.4839 - val_19class_acc: 0.3667
# Epoch 5/1000
#   1/182 [..............................] - ETA: 4s - loss: 54.6916 - 4class_loss: 0.6195 - 7class_loss: 1.5850 - 19class_loss: 1.9875 - 4class_acc: 0.7500 - 7class_acc: 0.3438 - 19class_acc: 0.3750Epoch 5/1000
# 182/182 [==============================] - 5s 26ms/step - loss: 38.8495 - 4class_loss: 0.7019 - 7class_loss: 1.0157 - 19class_loss: 1.4111 - 4class_acc: 0.7121 - 7class_acc: 0.6073 - 19class_acc: 0.5428 - val_loss: 61.7125 - val_4class_loss: 1.2423 - val_7class_loss: 1.4662 - val_19class_loss: 2.2578 - val_4class_acc: 0.6038 - val_7class_acc: 0.4709 - val_19class_acc: 0.3612
# 182/182 [==============================] - 5s 26ms/step - loss: 38.8495 - 4class_loss: 0.7019 - 7class_loss: 1.0157 - 19class_loss: 1.4111 - 4class_acc: 0.7121 - 7class_acc: 0.6073 - 19class_acc: 0.5428 - val_loss: 61.7125 - val_4class_loss: 1.2423 - val_7class_loss: 1.4662 - val_19class_loss: 2.2578 - val_4class_acc: 0.6038 - val_7class_acc: 0.4709 - val_19class_acc: 0.3612
# Epoch 6/1000
#   4/182 [..............................] - ETA: 4s - loss: 38.3782 - 4class_loss: 0.6614 - 7class_loss: 1.0211 - 19class_loss: 1.3927 - 4class_acc: 0.7500 - 7class_acc: 0.6172 - 19class_acc: 0.6016Epoch 6/1000
# 182/182 [==============================] - 5s 27ms/step - loss: 38.5532 - 4class_loss: 0.6794 - 7class_loss: 1.0082 - 19class_loss: 1.4027 - 4class_acc: 0.7308 - 7class_acc: 0.6126 - 19class_acc: 0.5508 - val_loss: 49.4310 - val_4class_loss: 0.8623 - val_7class_loss: 1.2129 - val_19class_loss: 1.8162 - val_4class_acc: 0.6813 - val_7class_acc: 0.5182 - val_19class_acc: 0.4071
# 182/182 [==============================] - 5s 27ms/step - loss: 38.5532 - 4class_loss: 0.6794 - 7class_loss: 1.0082 - 19class_loss: 1.4027 - 4class_acc: 0.7308 - 7class_acc: 0.6126 - 19class_acc: 0.5508 - val_loss: 49.4310 - val_4class_loss: 0.8623 - val_7class_loss: 1.2129 - val_19class_loss: 1.8162 - val_4class_acc: 0.6813 - val_7class_acc: 0.5182 - val_19class_acc: 0.4071
# Epoch 7/1000
#   1/182 [..............................] - ETA: 5s - loss: 32.0301 - 4class_loss: 0.5511 - 7class_loss: 0.8496 - 19class_loss: 1.1633 - 4class_acc: 0.7188 - 7class_acc: 0.5312 - 19class_acc: 0.5625Epoch 7/1000
# 182/182 [==============================] - 5s 26ms/step - loss: 37.1631 - 4class_loss: 0.6396 - 7class_loss: 0.9588 - 19class_loss: 1.3587 - 4class_acc: 0.7510 - 7class_acc: 0.6276 - 19class_acc: 0.5719 - val_loss: 61.1073 - val_4class_loss: 1.4745 - val_7class_loss: 1.3347 - val_19class_loss: 2.2375 - val_4class_acc: 0.5682 - val_7class_acc: 0.5476 - val_19class_acc: 0.3818
# 182/182 [==============================] - 5s 26ms/step - loss: 37.1631 - 4class_loss: 0.6396 - 7class_loss: 0.9588 - 19class_loss: 1.3587 - 4class_acc: 0.7510 - 7class_acc: 0.6276 - 19class_acc: 0.5719 - val_loss: 61.1073 - val_4class_loss: 1.4745 - val_7class_loss: 1.3347 - val_19class_loss: 2.2375 - val_4class_acc: 0.5682 - val_7class_acc: 0.5476 - val_19class_acc: 0.3818
# Epoch 8/1000
#   1/182 [..............................] - ETA: 4s - loss: 36.7970 - 4class_loss: 0.5904 - 7class_loss: 0.9248 - 19class_loss: 1.3596 - 4class_acc: 0.7188 - 7class_acc: 0.5938 - 19class_acc: 0.5000Epoch 8/1000
# 182/182 [==============================] - 5s 27ms/step - loss: 37.0112 - 4class_loss: 0.6573 - 7class_loss: 0.9510 - 19class_loss: 1.3515 - 4class_acc: 0.7368 - 7class_acc: 0.6391 - 19class_acc: 0.5752 - val_loss: 52.4971 - val_4class_loss: 0.8792 - val_7class_loss: 1.2794 - val_19class_loss: 1.9401 - val_4class_acc: 0.6902 - val_7class_acc: 0.5188 - val_19class_acc: 0.4126
# 182/182 [==============================] - 5s 27ms/step - loss: 37.0112 - 4class_loss: 0.6573 - 7class_loss: 0.9510 - 19class_loss: 1.3515 - 4class_acc: 0.7368 - 7class_acc: 0.6391 - 19class_acc: 0.5752 - val_loss: 52.4971 - val_4class_loss: 0.8792 - val_7class_loss: 1.2794 - val_19class_loss: 1.9401 - val_4class_acc: 0.6902 - val_7class_acc: 0.5188 - val_19class_acc: 0.4126
# Epoch 9/1000
#   1/182 [..............................] - ETA: 4s - loss: 34.2694 - 4class_loss: 0.7679 - 7class_loss: 0.9954 - 19class_loss: 1.1904 - 4class_acc: 0.7500 - 7class_acc: 0.5312 - 19class_acc: 0.5625Epoch 9/1000
# 182/182 [==============================] - 5s 28ms/step - loss: 35.8406 - 4class_loss: 0.6260 - 7class_loss: 0.9223 - 19class_loss: 1.3098 - 4class_acc: 0.7558 - 7class_acc: 0.6525 - 19class_acc: 0.5792 - val_loss: 59.9634 - val_4class_loss: 0.7716 - val_7class_loss: 1.6155 - val_19class_loss: 2.1910 - val_4class_acc: 0.7327 - val_7class_acc: 0.5188 - val_19class_acc: 0.4284
# 182/182 [==============================] - 5s 28ms/step - loss: 35.8406 - 4class_loss: 0.6260 - 7class_loss: 0.9223 - 19class_loss: 1.3098 - 4class_acc: 0.7558 - 7class_acc: 0.6525 - 19class_acc: 0.5792 - val_loss: 59.9634 - val_4class_loss: 0.7716 - val_7class_loss: 1.6155 - val_19class_loss: 2.1910 - val_4class_acc: 0.7327 - val_7class_acc: 0.5188 - val_19class_acc: 0.4284
# Epoch 10/1000
#   1/182 [..............................] - ETA: 4s - loss: 37.5867 - 4class_loss: 0.7717 - 7class_loss: 1.0074 - 19class_loss: 1.3438 - 4class_acc: 0.6875 - 7class_acc: 0.7188 - 19class_acc: 0.5625Epoch 10/1000
# 182/182 [==============================] - 5s 27ms/step - loss: 35.9564 - 4class_loss: 0.6288 - 7class_loss: 0.9228 - 19class_loss: 1.3148 - 4class_acc: 0.7577 - 7class_acc: 0.6535 - 19class_acc: 0.5824 - val_loss: 54.1387 - val_4class_loss: 1.0214 - val_7class_loss: 1.3361 - val_19class_loss: 1.9747 - val_4class_acc: 0.7012 - val_7class_acc: 0.5415 - val_19class_acc: 0.4332
# 182/182 [==============================] - 5s 27ms/step - loss: 35.9564 - 4class_loss: 0.6288 - 7class_loss: 0.9228 - 19class_loss: 1.3148 - 4class_acc: 0.7577 - 7class_acc: 0.6535 - 19class_acc: 0.5824 - val_loss: 54.1387 - val_4class_loss: 1.0214 - val_7class_loss: 1.3361 - val_19class_loss: 1.9747 - val_4class_acc: 0.7012 - val_7class_acc: 0.5415 - val_19class_acc: 0.4332
# Epoch 11/1000
#   1/182 [..............................] - ETA: 5s - loss: 40.1058 - 4class_loss: 0.5689 - 7class_loss: 1.2102 - 19class_loss: 1.4251 - 4class_acc: 0.8750 - 7class_acc: 0.6250 - 19class_acc: 0.5000Epoch 11/1000
# 182/182 [==============================] - 5s 26ms/step - loss: 34.3901 - 4class_loss: 0.6017 - 7class_loss: 0.8919 - 19class_loss: 1.2544 - 4class_acc: 0.7692 - 7class_acc: 0.6684 - 19class_acc: 0.6087 - val_loss: 62.1456 - val_4class_loss: 1.1117 - val_7class_loss: 1.2992 - val_19class_loss: 2.3558 - val_4class_acc: 0.6066 - val_7class_acc: 0.5141 - val_19class_acc: 0.3790
# 182/182 [==============================] - 5s 26ms/step - loss: 34.3901 - 4class_loss: 0.6017 - 7class_loss: 0.8919 - 19class_loss: 1.2544 - 4class_acc: 0.7692 - 7class_acc: 0.6684 - 19class_acc: 0.6087 - val_loss: 62.1456 - val_4class_loss: 1.1117 - val_7class_loss: 1.2992 - val_19class_loss: 2.3558 - val_4class_acc: 0.6066 - val_7class_acc: 0.5141 - val_19class_acc: 0.3790
# Epoch 12/1000
#   3/182 [..............................] - ETA: 4s - loss: 31.2891 - 4class_loss: 0.5040 - 7class_loss: 0.8063 - 19class_loss: 1.1492 - 4class_acc: 0.8229 - 7class_acc: 0.6979 - 19class_acc: 0.6667Epoch 12/1000
# 182/182 [==============================] - 5s 26ms/step - loss: 34.2179 - 4class_loss: 0.5901 - 7class_loss: 0.8793 - 19class_loss: 1.2520 - 4class_acc: 0.7756 - 7class_acc: 0.6794 - 19class_acc: 0.6140 - val_loss: 63.4836 - val_4class_loss: 1.0646 - val_7class_loss: 1.5080 - val_19class_loss: 2.3530 - val_4class_acc: 0.6676 - val_7class_acc: 0.5716 - val_19class_acc: 0.4181
# 182/182 [==============================] - 5s 26ms/step - loss: 34.2179 - 4class_loss: 0.5901 - 7class_loss: 0.8793 - 19class_loss: 1.2520 - 4class_acc: 0.7756 - 7class_acc: 0.6794 - 19class_acc: 0.6140 - val_loss: 63.4836 - val_4class_loss: 1.0646 - val_7class_loss: 1.5080 - val_19class_loss: 2.3530 - val_4class_acc: 0.6676 - val_7class_acc: 0.5716 - val_19class_acc: 0.4181
# Epoch 13/1000
#   3/182 [..............................] - ETA: 4s - loss: 29.3513 - 4class_loss: 0.4728 - 7class_loss: 0.7767 - 19class_loss: 1.0712 - 4class_acc: 0.8438 - 7class_acc: 0.7292 - 19class_acc: 0.6562Epoch 13/1000
# 182/182 [==============================] - 5s 27ms/step - loss: 34.2748 - 4class_loss: 0.5926 - 7class_loss: 0.8779 - 19class_loss: 1.2548 - 4class_acc: 0.7782 - 7class_acc: 0.6942 - 19class_acc: 0.6161 - val_loss: 55.5491 - val_4class_loss: 1.0388 - val_7class_loss: 1.4765 - val_19class_loss: 1.9894 - val_4class_acc: 0.7347 - val_7class_acc: 0.5579 - val_19class_acc: 0.4812
# 182/182 [==============================] - 5s 27ms/step - loss: 34.2748 - 4class_loss: 0.5926 - 7class_loss: 0.8779 - 19class_loss: 1.2548 - 4class_acc: 0.7782 - 7class_acc: 0.6942 - 19class_acc: 0.6161 - val_loss: 55.5491 - val_4class_loss: 1.0388 - val_7class_loss: 1.4765 - val_19class_loss: 1.9894 - val_4class_acc: 0.7347 - val_7class_acc: 0.5579 - val_19class_acc: 0.4812
# Epoch 14/1000
#   1/182 [..............................] - ETA: 5s - loss: 26.0320 - 4class_loss: 0.5148 - 7class_loss: 0.6776 - 19class_loss: 0.9402 - 4class_acc: 0.7500 - 7class_acc: 0.7188 - 19class_acc: 0.6875Epoch 14/1000
# 182/182 [==============================] - 5s 27ms/step - loss: 33.6140 - 4class_loss: 0.5766 - 7class_loss: 0.8624 - 19class_loss: 1.2308 - 4class_acc: 0.7879 - 7class_acc: 0.6892 - 19class_acc: 0.6250 - val_loss: 48.2252 - val_4class_loss: 0.7752 - val_7class_loss: 1.2050 - val_19class_loss: 1.7731 - val_4class_acc: 0.7512 - val_7class_acc: 0.6251 - val_19class_acc: 0.5031
# 182/182 [==============================] - 5s 27ms/step - loss: 33.6140 - 4class_loss: 0.5766 - 7class_loss: 0.8624 - 19class_loss: 1.2308 - 4class_acc: 0.7879 - 7class_acc: 0.6892 - 19class_acc: 0.6250 - val_loss: 48.2252 - val_4class_loss: 0.7752 - val_7class_loss: 1.2050 - val_19class_loss: 1.7731 - val_4class_acc: 0.7512 - val_7class_acc: 0.6251 - val_19class_acc: 0.5031
# Epoch 15/1000
#   1/182 [..............................] - ETA: 5s - loss: 24.2496 - 4class_loss: 0.4929 - 7class_loss: 0.5622 - 19class_loss: 0.8969 - 4class_acc: 0.8125 - 7class_acc: 0.8750 - 19class_acc: 0.7812Epoch 15/1000
# 182/182 [==============================] - 5s 26ms/step - loss: 32.6909 - 4class_loss: 0.5629 - 7class_loss: 0.8359 - 19class_loss: 1.1976 - 4class_acc: 0.7891 - 7class_acc: 0.7026 - 19class_acc: 0.6315 - val_loss: 63.7992 - val_4class_loss: 1.2197 - val_7class_loss: 1.3940 - val_19class_loss: 2.3844 - val_4class_acc: 0.6059 - val_7class_acc: 0.5497 - val_19class_acc: 0.4147
# 182/182 [==============================] - 5s 26ms/step - loss: 32.6909 - 4class_loss: 0.5629 - 7class_loss: 0.8359 - 19class_loss: 1.1976 - 4class_acc: 0.7891 - 7class_acc: 0.7026 - 19class_acc: 0.6315 - val_loss: 63.7992 - val_4class_loss: 1.2197 - val_7class_loss: 1.3940 - val_19class_loss: 2.3844 - val_4class_acc: 0.6059 - val_7class_acc: 0.5497 - val_19class_acc: 0.4147
# Epoch 16/1000
#   1/182 [..............................] - ETA: 5s - loss: 29.8467 - 4class_loss: 0.5354 - 7class_loss: 0.8061 - 19class_loss: 1.0761 - 4class_acc: 0.9062 - 7class_acc: 0.8125 - 19class_acc: 0.7188Epoch 16/1000
# 182/182 [==============================] - 5s 26ms/step - loss: 32.1688 - 4class_loss: 0.5570 - 7class_loss: 0.8261 - 19class_loss: 1.1769 - 4class_acc: 0.8048 - 7class_acc: 0.7026 - 19class_acc: 0.6415 - val_loss: 56.9412 - val_4class_loss: 0.8785 - val_7class_loss: 1.4688 - val_19class_loss: 2.0864 - val_4class_acc: 0.7258 - val_7class_acc: 0.5168 - val_19class_acc: 0.4263
# 182/182 [==============================] - 5s 26ms/step - loss: 32.1688 - 4class_loss: 0.5570 - 7class_loss: 0.8261 - 19class_loss: 1.1769 - 4class_acc: 0.8048 - 7class_acc: 0.7026 - 19class_acc: 0.6415 - val_loss: 56.9412 - val_4class_loss: 0.8785 - val_7class_loss: 1.4688 - val_19class_loss: 2.0864 - val_4class_acc: 0.7258 - val_7class_acc: 0.5168 - val_19class_acc: 0.4263
# Epoch 17/1000
#   1/182 [..............................] - ETA: 5s - loss: 25.1693 - 4class_loss: 0.5076 - 7class_loss: 0.6565 - 19class_loss: 0.9072 - 4class_acc: 0.9375 - 7class_acc: 0.8125 - 19class_acc: 0.8438Epoch 17/1000
# 182/182 [==============================] - 5s 25ms/step - loss: 32.0430 - 4class_loss: 0.5633 - 7class_loss: 0.8257 - 19class_loss: 1.1702 - 4class_acc: 0.7977 - 7class_acc: 0.7102 - 19class_acc: 0.6514 - val_loss: 50.2287 - val_4class_loss: 0.8271 - val_7class_loss: 1.2410 - val_19class_loss: 1.8491 - val_4class_acc: 0.7382 - val_7class_acc: 0.6121 - val_19class_acc: 0.4955
# 182/182 [==============================] - 5s 25ms/step - loss: 32.0430 - 4class_loss: 0.5633 - 7class_loss: 0.8257 - 19class_loss: 1.1702 - 4class_acc: 0.7977 - 7class_acc: 0.7102 - 19class_acc: 0.6514 - val_loss: 50.2287 - val_4class_loss: 0.8271 - val_7class_loss: 1.2410 - val_19class_loss: 1.8491 - val_4class_acc: 0.7382 - val_7class_acc: 0.6121 - val_19class_acc: 0.4955
# Epoch 18/1000
#   1/182 [..............................] - ETA: 5s - loss: 25.1417 - 4class_loss: 0.4615 - 7class_loss: 0.6536 - 19class_loss: 0.9134 - 4class_acc: 0.8750 - 7class_acc: 0.8438 - 19class_acc: 0.7500Epoch 18/1000
# 182/182 [==============================] - 5s 25ms/step - loss: 32.0618 - 4class_loss: 0.5520 - 7class_loss: 0.8236 - 19class_loss: 1.1734 - 4class_acc: 0.7965 - 7class_acc: 0.7024 - 19class_acc: 0.6394 - val_loss: 50.9008 - val_4class_loss: 0.9929 - val_7class_loss: 1.2518 - val_19class_loss: 1.8530 - val_4class_acc: 0.7300 - val_7class_acc: 0.5997 - val_19class_acc: 0.4770
# 182/182 [==============================] - 5s 25ms/step - loss: 32.0618 - 4class_loss: 0.5520 - 7class_loss: 0.8236 - 19class_loss: 1.1734 - 4class_acc: 0.7965 - 7class_acc: 0.7024 - 19class_acc: 0.6394 - val_loss: 50.9008 - val_4class_loss: 0.9929 - val_7class_loss: 1.2518 - val_19class_loss: 1.8530 - val_4class_acc: 0.7300 - val_7class_acc: 0.5997 - val_19class_acc: 0.4770
# Epoch 19/1000
#   4/182 [..............................] - ETA: 4s - loss: 28.5199 - 4class_loss: 0.5706 - 7class_loss: 0.7298 - 19class_loss: 1.0333 - 4class_acc: 0.7891 - 7class_acc: 0.7734 - 19class_acc: 0.6797Epoch 19/1000
# 182/182 [==============================] - 5s 27ms/step - loss: 31.1633 - 4class_loss: 0.5449 - 7class_loss: 0.7999 - 19class_loss: 1.1395 - 4class_acc: 0.8043 - 7class_acc: 0.7141 - 19class_acc: 0.6623 - val_loss: 45.7947 - val_4class_loss: 0.7740 - val_7class_loss: 1.1491 - val_19class_loss: 1.6794 - val_4class_acc: 0.7437 - val_7class_acc: 0.6134 - val_19class_acc: 0.5326
# 182/182 [==============================] - 5s 27ms/step - loss: 31.1633 - 4class_loss: 0.5449 - 7class_loss: 0.7999 - 19class_loss: 1.1395 - 4class_acc: 0.8043 - 7class_acc: 0.7141 - 19class_acc: 0.6623 - val_loss: 45.7947 - val_4class_loss: 0.7740 - val_7class_loss: 1.1491 - val_19class_loss: 1.6794 - val_4class_acc: 0.7437 - val_7class_acc: 0.6134 - val_19class_acc: 0.5326
# Epoch 20/1000
#   1/182 [..............................] - ETA: 5s - loss: 43.8125 - 4class_loss: 0.6452 - 7class_loss: 1.0214 - 19class_loss: 1.6537 - 4class_acc: 0.6875 - 7class_acc: 0.7188 - 19class_acc: 0.5000Epoch 20/1000
# 182/182 [==============================] - 5s 25ms/step - loss: 32.4588 - 4class_loss: 0.5641 - 7class_loss: 0.8400 - 19class_loss: 1.1851 - 4class_acc: 0.7972 - 7class_acc: 0.7134 - 19class_acc: 0.6511 - val_loss: 49.0294 - val_4class_loss: 0.9293 - val_7class_loss: 1.1492 - val_19class_loss: 1.8079 - val_4class_acc: 0.6600 - val_7class_acc: 0.6244 - val_19class_acc: 0.4805
# 182/182 [==============================] - 5s 25ms/step - loss: 32.4588 - 4class_loss: 0.5641 - 7class_loss: 0.8400 - 19class_loss: 1.1851 - 4class_acc: 0.7972 - 7class_acc: 0.7134 - 19class_acc: 0.6511 - val_loss: 49.0294 - val_4class_loss: 0.9293 - val_7class_loss: 1.1492 - val_19class_loss: 1.8079 - val_4class_acc: 0.6600 - val_7class_acc: 0.6244 - val_19class_acc: 0.4805
# Epoch 21/1000
#   1/182 [..............................] - ETA: 5s - loss: 46.4639 - 4class_loss: 0.7379 - 7class_loss: 1.1527 - 19class_loss: 1.7229 - 4class_acc: 0.5000 - 7class_acc: 0.4062 - 19class_acc: 0.3125Epoch 21/1000
# 182/182 [==============================] - 5s 25ms/step - loss: 30.7160 - 4class_loss: 0.5397 - 7class_loss: 0.7854 - 19class_loss: 1.1238 - 4class_acc: 0.8043 - 7class_acc: 0.7378 - 19class_acc: 0.6727 - val_loss: 48.5542 - val_4class_loss: 0.9411 - val_7class_loss: 1.1583 - val_19class_loss: 1.7847 - val_4class_acc: 0.6402 - val_7class_acc: 0.6162 - val_19class_acc: 0.4750
# 182/182 [==============================] - 5s 25ms/step - loss: 30.7160 - 4class_loss: 0.5397 - 7class_loss: 0.7854 - 19class_loss: 1.1238 - 4class_acc: 0.8043 - 7class_acc: 0.7378 - 19class_acc: 0.6727 - val_loss: 48.5542 - val_4class_loss: 0.9411 - val_7class_loss: 1.1583 - val_19class_loss: 1.7847 - val_4class_acc: 0.6402 - val_7class_acc: 0.6162 - val_19class_acc: 0.4750
# Epoch 22/1000
#   1/182 [..............................] - ETA: 5s - loss: 40.1489 - 4class_loss: 0.6148 - 7class_loss: 1.1305 - 19class_loss: 1.4472 - 4class_acc: 0.6562 - 7class_acc: 0.6562 - 19class_acc: 0.5938Epoch 22/1000
# 182/182 [==============================] - 5s 26ms/step - loss: 30.5669 - 4class_loss: 0.5270 - 7class_loss: 0.7907 - 19class_loss: 1.1167 - 4class_acc: 0.8134 - 7class_acc: 0.7285 - 19class_acc: 0.6647 - val_loss: 46.7909 - val_4class_loss: 0.7039 - val_7class_loss: 1.1710 - val_19class_loss: 1.7357 - val_4class_acc: 0.7306 - val_7class_acc: 0.5737 - val_19class_acc: 0.4880
# 182/182 [==============================] - 5s 26ms/step - loss: 30.5669 - 4class_loss: 0.5270 - 7class_loss: 0.7907 - 19class_loss: 1.1167 - 4class_acc: 0.8134 - 7class_acc: 0.7285 - 19class_acc: 0.6647 - val_loss: 46.7909 - val_4class_loss: 0.7039 - val_7class_loss: 1.1710 - val_19class_loss: 1.7357 - val_4class_acc: 0.7306 - val_7class_acc: 0.5737 - val_19class_acc: 0.4880
# Epoch 23/1000
#   1/182 [..............................] - ETA: 4s - loss: 24.4791 - 4class_loss: 0.5829 - 7class_loss: 0.5424 - 19class_loss: 0.9016 - 4class_acc: 0.7188 - 7class_acc: 0.8750 - 19class_acc: 0.7500Epoch 23/1000
# 182/182 [==============================] - 5s 25ms/step - loss: 30.2353 - 4class_loss: 0.5192 - 7class_loss: 0.7759 - 19class_loss: 1.1070 - 4class_acc: 0.8178 - 7class_acc: 0.7347 - 19class_acc: 0.6741 - val_loss: 51.6654 - val_4class_loss: 0.8882 - val_7class_loss: 1.1977 - val_19class_loss: 1.9214 - val_4class_acc: 0.7108 - val_7class_acc: 0.6093 - val_19class_acc: 0.4907
# 182/182 [==============================] - 5s 25ms/step - loss: 30.2353 - 4class_loss: 0.5192 - 7class_loss: 0.7759 - 19class_loss: 1.1070 - 4class_acc: 0.8178 - 7class_acc: 0.7347 - 19class_acc: 0.6741 - val_loss: 51.6654 - val_4class_loss: 0.8882 - val_7class_loss: 1.1977 - val_19class_loss: 1.9214 - val_4class_acc: 0.7108 - val_7class_acc: 0.6093 - val_19class_acc: 0.4907
# Epoch 24/1000
#   1/182 [..............................] - ETA: 5s - loss: 49.1696 - 4class_loss: 0.8961 - 7class_loss: 1.5044 - 19class_loss: 1.7119 - 4class_acc: 0.7188 - 7class_acc: 0.5312 - 19class_acc: 0.4688Epoch 24/1000
# 182/182 [==============================] - 5s 27ms/step - loss: 28.9545 - 4class_loss: 0.5136 - 7class_loss: 0.7534 - 19class_loss: 1.0543 - 4class_acc: 0.8245 - 7class_acc: 0.7448 - 19class_acc: 0.6999 - val_loss: 43.2352 - val_4class_loss: 0.7418 - val_7class_loss: 1.0804 - val_19class_loss: 1.5851 - val_4class_acc: 0.7594 - val_7class_acc: 0.6484 - val_19class_acc: 0.5435
# 182/182 [==============================] - 5s 27ms/step - loss: 28.9545 - 4class_loss: 0.5136 - 7class_loss: 0.7534 - 19class_loss: 1.0543 - 4class_acc: 0.8245 - 7class_acc: 0.7448 - 19class_acc: 0.6999 - val_loss: 43.2352 - val_4class_loss: 0.7418 - val_7class_loss: 1.0804 - val_19class_loss: 1.5851 - val_4class_acc: 0.7594 - val_7class_acc: 0.6484 - val_19class_acc: 0.5435
# Epoch 25/1000
#   1/182 [..............................] - ETA: 4s - loss: 26.7238 - 4class_loss: 0.4644 - 7class_loss: 0.6624 - 19class_loss: 0.9854 - 4class_acc: 0.8750 - 7class_acc: 0.7812 - 19class_acc: 0.6562Epoch 25/1000
# 182/182 [==============================] - 5s 26ms/step - loss: 28.9242 - 4class_loss: 0.5136 - 7class_loss: 0.7566 - 19class_loss: 1.0518 - 4class_acc: 0.8328 - 7class_acc: 0.7493 - 19class_acc: 0.6963 - val_loss: 46.0885 - val_4class_loss: 0.7682 - val_7class_loss: 1.0677 - val_19class_loss: 1.7248 - val_4class_acc: 0.7183 - val_7class_acc: 0.6230 - val_19class_acc: 0.5134
# 182/182 [==============================] - 5s 26ms/step - loss: 28.9242 - 4class_loss: 0.5136 - 7class_loss: 0.7566 - 19class_loss: 1.0518 - 4class_acc: 0.8328 - 7class_acc: 0.7493 - 19class_acc: 0.6963 - val_loss: 46.0885 - val_4class_loss: 0.7682 - val_7class_loss: 1.0677 - val_19class_loss: 1.7248 - val_4class_acc: 0.7183 - val_7class_acc: 0.6230 - val_19class_acc: 0.5134
# Epoch 26/1000
#   1/182 [..............................] - ETA: 4s - loss: 39.6095 - 4class_loss: 0.6006 - 7class_loss: 0.9438 - 19class_loss: 1.4858 - 4class_acc: 0.7500 - 7class_acc: 0.7500 - 19class_acc: 0.6250Epoch 26/1000
# 182/182 [==============================] - 5s 27ms/step - loss: 28.2172 - 4class_loss: 0.5000 - 7class_loss: 0.7327 - 19class_loss: 1.0280 - 4class_acc: 0.8235 - 7class_acc: 0.7581 - 19class_acc: 0.7155 - val_loss: 42.4401 - val_4class_loss: 0.6974 - val_7class_loss: 1.0947 - val_19class_loss: 1.5456 - val_4class_acc: 0.7786 - val_7class_acc: 0.6614 - val_19class_acc: 0.5792
# 182/182 [==============================] - 5s 27ms/step - loss: 28.2172 - 4class_loss: 0.5000 - 7class_loss: 0.7327 - 19class_loss: 1.0280 - 4class_acc: 0.8235 - 7class_acc: 0.7581 - 19class_acc: 0.7155 - val_loss: 42.4401 - val_4class_loss: 0.6974 - val_7class_loss: 1.0947 - val_19class_loss: 1.5456 - val_4class_acc: 0.7786 - val_7class_acc: 0.6614 - val_19class_acc: 0.5792
# Epoch 27/1000
#   1/182 [..............................] - ETA: 4s - loss: 37.9119 - 4class_loss: 0.6328 - 7class_loss: 1.0343 - 19class_loss: 1.3702 - 4class_acc: 0.6875 - 7class_acc: 0.6250 - 19class_acc: 0.5938Epoch 27/1000
# ...
# Epoch 155/1000
# 182/182 [==============================] - 5s 26ms/step - loss: 13.8934 - 4class_loss: 0.2944 - 7class_loss: 0.3783 - 19class_loss: 0.4934 - 4class_acc: 0.9626 - 7class_acc: 0.9572 - 19class_acc: 0.9468 - val_loss: 27.7899 - val_4class_loss: 0.4386 - val_7class_loss: 0.7062 - val_19class_loss: 1.0184 - val_4class_acc: 0.8889 - val_7class_acc: 0.8230 - val_19class_acc: 0.7826
# Epoch 156/1000
# 182/182 [==============================] - 5s 26ms/step - loss: 13.9094 - 4class_loss: 0.2987 - 7class_loss: 0.3805 - 19class_loss: 0.4928 - 4class_acc: 0.9641 - 7class_acc: 0.9531 - 19class_acc: 0.9490 - val_loss: 27.7560 - val_4class_loss: 0.4582 - val_7class_loss: 0.7180 - val_19class_loss: 1.0111 - val_4class_acc: 0.8889 - val_7class_acc: 0.8128 - val_19class_acc: 0.7737
# Epoch 157/1000
# 182/182 [==============================] - 5s 26ms/step - loss: 14.2268 - 4class_loss: 0.3018 - 7class_loss: 0.3901 - 19class_loss: 0.5043 - 4class_acc: 0.9598 - 7class_acc: 0.9519 - 19class_acc: 0.9437 - val_loss: 27.3493 - val_4class_loss: 0.4362 - val_7class_loss: 0.6816 - val_19class_loss: 1.0086 - val_4class_acc: 0.8868 - val_7class_acc: 0.8278 - val_19class_acc: 0.7586
# Epoch 158/1000
# 182/182 [==============================] - 5s 26ms/step - loss: 14.0057 - 4class_loss: 0.3033 - 7class_loss: 0.3810 - 19class_loss: 0.4966 - 4class_acc: 0.9612 - 7class_acc: 0.9540 - 19class_acc: 0.9481 - val_loss: 27.9403 - val_4class_loss: 0.4505 - val_7class_loss: 0.7357 - val_19class_loss: 1.0151 - val_4class_acc: 0.8930 - val_7class_acc: 0.8141 - val_19class_acc: 0.7723
# Epoch 159/1000
# 182/182 [==============================] - 5s 26ms/step - loss: 13.7237 - 4class_loss: 0.2952 - 7class_loss: 0.3767 - 19class_loss: 0.4858 - 4class_acc: 0.9662 - 7class_acc: 0.9559 - 19class_acc: 0.9519 - val_loss: 37.9479 - val_4class_loss: 0.5957 - val_7class_loss: 0.9346 - val_19class_loss: 1.4023 - val_4class_acc: 0.8320 - val_7class_acc: 0.7551 - val_19class_acc: 0.6907
# Epoch 160/1000
# 182/182 [==============================] - 5s 26ms/step - loss: 13.8163 - 4class_loss: 0.3009 - 7class_loss: 0.3788 - 19class_loss: 0.4887 - 4class_acc: 0.9598 - 7class_acc: 0.9557 - 19class_acc: 0.9512 - val_loss: 27.5151 - val_4class_loss: 0.4390 - val_7class_loss: 0.7173 - val_19class_loss: 1.0072 - val_4class_acc: 0.8923 - val_7class_acc: 0.8148 - val_19class_acc: 0.7723
# Epoch 161/1000
# 182/182 [==============================] - 5s 27ms/step - loss: 14.1142 - 4class_loss: 0.3082 - 7class_loss: 0.3807 - 19class_loss: 0.5012 - 4class_acc: 0.9562 - 7class_acc: 0.9542 - 19class_acc: 0.9437 - val_loss: 26.4034 - val_4class_loss: 0.4306 - val_7class_loss: 0.6637 - val_19class_loss: 0.9700 - val_4class_acc: 0.8875 - val_7class_acc: 0.8244 - val_19class_acc: 0.7936
# Epoch 162/1000
# 182/182 [==============================] - 5s 26ms/step - loss: 14.0459 - 4class_loss: 0.3012 - 7class_loss: 0.3808 - 19class_loss: 0.4989 - 4class_acc: 0.9571 - 7class_acc: 0.9590 - 19class_acc: 0.9476 - val_loss: 27.8343 - val_4class_loss: 0.4212 - val_7class_loss: 0.7082 - val_19class_loss: 1.0232 - val_4class_acc: 0.9040 - val_7class_acc: 0.8251 - val_19class_acc: 0.7764
# Epoch 163/1000
# 182/182 [==============================] - 5s 26ms/step - loss: 13.9725 - 4class_loss: 0.3009 - 7class_loss: 0.3813 - 19class_loss: 0.4953 - 4class_acc: 0.9591 - 7class_acc: 0.9578 - 19class_acc: 0.9468 - val_loss: 26.9093 - val_4class_loss: 0.4157 - val_7class_loss: 0.7099 - val_19class_loss: 0.9814 - val_4class_acc: 0.8978 - val_7class_acc: 0.8032 - val_19class_acc: 0.7709
# Epoch 164/1000
# 182/182 [==============================] - 5s 26ms/step - loss: 13.7159 - 4class_loss: 0.2957 - 7class_loss: 0.3752 - 19class_loss: 0.4858 - 4class_acc: 0.9633 - 7class_acc: 0.9572 - 19class_acc: 0.9500 - val_loss: 27.8172 - val_4class_loss: 0.4392 - val_7class_loss: 0.6979 - val_19class_loss: 1.0249 - val_4class_acc: 0.8916 - val_7class_acc: 0.8169 - val_19class_acc: 0.7675
# Epoch 165/1000
# 182/182 [==============================] - 5s 26ms/step - loss: 13.5362 - 4class_loss: 0.2956 - 7class_loss: 0.3695 - 19class_loss: 0.4792 - 4class_acc: 0.9619 - 7class_acc: 0.9603 - 19class_acc: 0.9545 - val_loss: 31.9849 - val_4class_loss: 0.5303 - val_7class_loss: 0.8059 - val_19class_loss: 1.1726 - val_4class_acc: 0.8587 - val_7class_acc: 0.7675 - val_19class_acc: 0.7209
# Epoch 166/1000
# 182/182 [==============================] - 5s 26ms/step - loss: 13.3897 - 4class_loss: 0.2995 - 7class_loss: 0.3677 - 19class_loss: 0.4722 - 4class_acc: 0.9600 - 7class_acc: 0.9633 - 19class_acc: 0.9557 - val_loss: 30.0330 - val_4class_loss: 0.4548 - val_7class_loss: 0.7555 - val_19class_loss: 1.1087 - val_4class_acc: 0.8841 - val_7class_acc: 0.8093 - val_19class_acc: 0.7503
# Epoch 167/1000
# 182/182 [==============================] - 5s 26ms/step - loss: 13.7750 - 4class_loss: 0.2968 - 7class_loss: 0.3792 - 19class_loss: 0.4872 - 4class_acc: 0.9645 - 7class_acc: 0.9552 - 19class_acc: 0.9495 - val_loss: 28.0775 - val_4class_loss: 0.4495 - val_7class_loss: 0.7411 - val_19class_loss: 1.0214 - val_4class_acc: 0.8930 - val_7class_acc: 0.8210 - val_19class_acc: 0.7826
# Epoch 168/1000
# 182/182 [==============================] - 5s 26ms/step - loss: 13.3722 - 4class_loss: 0.2906 - 7class_loss: 0.3710 - 19class_loss: 0.4716 - 4class_acc: 0.9674 - 7class_acc: 0.9596 - 19class_acc: 0.9591 - val_loss: 30.9303 - val_4class_loss: 0.4689 - val_7class_loss: 0.8147 - val_19class_loss: 1.1298 - val_4class_acc: 0.8752 - val_7class_acc: 0.8004 - val_19class_acc: 0.7497
# Epoch 169/1000
# 182/182 [==============================] - 5s 25ms/step - loss: 13.7960 - 4class_loss: 0.2925 - 7class_loss: 0.3757 - 19class_loss: 0.4899 - 4class_acc: 0.9662 - 7class_acc: 0.9559 - 19class_acc: 0.9518 - val_loss: 35.9908 - val_4class_loss: 0.5448 - val_7class_loss: 0.9247 - val_19class_loss: 1.3188 - val_4class_acc: 0.8477 - val_7class_acc: 0.7483 - val_19class_acc: 0.6914
# Epoch 170/1000
# 182/182 [==============================] - 5s 25ms/step - loss: 13.8415 - 4class_loss: 0.2928 - 7class_loss: 0.3798 - 19class_loss: 0.4907 - 4class_acc: 0.9675 - 7class_acc: 0.9566 - 19class_acc: 0.9533 - val_loss: 28.5495 - val_4class_loss: 0.4827 - val_7class_loss: 0.7030 - val_19class_loss: 1.0498 - val_4class_acc: 0.8848 - val_7class_acc: 0.8217 - val_19class_acc: 0.7785
# Epoch 171/1000
# 182/182 [==============================] - 5s 25ms/step - loss: 13.6787 - 4class_loss: 0.2875 - 7class_loss: 0.3796 - 19class_loss: 0.4838 - 4class_acc: 0.9686 - 7class_acc: 0.9554 - 19class_acc: 0.9552 - val_loss: 33.9693 - val_4class_loss: 0.5227 - val_7class_loss: 0.8366 - val_19class_loss: 1.2598 - val_4class_acc: 0.8525 - val_7class_acc: 0.7606 - val_19class_acc: 0.7051
# Epoch 172/1000
# 182/182 [==============================] - 5s 25ms/step - loss: 13.4962 - 4class_loss: 0.2938 - 7class_loss: 0.3649 - 19class_loss: 0.4791 - 4class_acc: 0.9636 - 7class_acc: 0.9639 - 19class_acc: 0.9564 - val_loss: 30.5971 - val_4class_loss: 0.4676 - val_7class_loss: 0.7888 - val_19class_loss: 1.1211 - val_4class_acc: 0.8711 - val_7class_acc: 0.7737 - val_19class_acc: 0.7236
# Epoch 173/1000
# 182/182 [==============================] - 5s 25ms/step - loss: 13.4876 - 4class_loss: 0.2920 - 7class_loss: 0.3696 - 19class_loss: 0.4774 - 4class_acc: 0.9621 - 7class_acc: 0.9590 - 19class_acc: 0.9531 - val_loss: 34.3989 - val_4class_loss: 0.5562 - val_7class_loss: 0.8698 - val_19class_loss: 1.2606 - val_4class_acc: 0.8471 - val_7class_acc: 0.7853 - val_19class_acc: 0.7188
# Epoch 174/1000
# 182/182 [==============================] - 5s 25ms/step - loss: 13.7020 - 4class_loss: 0.3000 - 7class_loss: 0.3766 - 19class_loss: 0.4841 - 4class_acc: 0.9607 - 7class_acc: 0.9579 - 19class_acc: 0.9524 - val_loss: 34.4709 - val_4class_loss: 0.5739 - val_7class_loss: 0.8608 - val_19class_loss: 1.2655 - val_4class_acc: 0.8505 - val_7class_acc: 0.7702 - val_19class_acc: 0.7030
# Epoch 175/1000
# 182/182 [==============================] - 5s 25ms/step - loss: 13.6095 - 4class_loss: 0.2921 - 7class_loss: 0.3749 - 19class_loss: 0.4814 - 4class_acc: 0.9631 - 7class_acc: 0.9609 - 19class_acc: 0.9557 - val_loss: 28.9961 - val_4class_loss: 0.4387 - val_7class_loss: 0.7511 - val_19class_loss: 1.0619 - val_4class_acc: 0.8813 - val_7class_acc: 0.8182 - val_19class_acc: 0.7620
# Epoch 176/1000
# 182/182 [==============================] - 5s 25ms/step - loss: 13.4234 - 4class_loss: 0.2824 - 7class_loss: 0.3705 - 19class_loss: 0.4754 - 4class_acc: 0.9710 - 7class_acc: 0.9596 - 19class_acc: 0.9566 - val_loss: 29.2122 - val_4class_loss: 0.4467 - val_7class_loss: 0.7678 - val_19class_loss: 1.0660 - val_4class_acc: 0.8909 - val_7class_acc: 0.8073 - val_19class_acc: 0.7716
# Epoch 177/1000
# 182/182 [==============================] - 5s 26ms/step - loss: 13.4885 - 4class_loss: 0.2929 - 7class_loss: 0.3731 - 19class_loss: 0.4761 - 4class_acc: 0.9648 - 7class_acc: 0.9598 - 19class_acc: 0.9560 - val_loss: 27.0622 - val_4class_loss: 0.4242 - val_7class_loss: 0.6839 - val_19class_loss: 0.9948 - val_4class_acc: 0.8964 - val_7class_acc: 0.8333 - val_19class_acc: 0.7963
# Epoch 178/1000
# 182/182 [==============================] - 4s 25ms/step - loss: 13.5432 - 4class_loss: 0.2935 - 7class_loss: 0.3681 - 19class_loss: 0.4803 - 4class_acc: 0.9621 - 7class_acc: 0.9631 - 19class_acc: 0.9555 - val_loss: 36.1539 - val_4class_loss: 0.5654 - val_7class_loss: 0.8841 - val_19class_loss: 1.3358 - val_4class_acc: 0.8457 - val_7class_acc: 0.7558 - val_19class_acc: 0.7030
# Epoch 179/1000
# 182/182 [==============================] - 5s 25ms/step - loss: 13.3794 - 4class_loss: 0.2920 - 7class_loss: 0.3630 - 19class_loss: 0.4744 - 4class_acc: 0.9648 - 7class_acc: 0.9619 - 19class_acc: 0.9596 - val_loss: 28.5204 - val_4class_loss: 0.4432 - val_7class_loss: 0.7242 - val_19class_loss: 1.0492 - val_4class_acc: 0.8944 - val_7class_acc: 0.8333 - val_19class_acc: 0.7826
# Epoch 180/1000
# 182/182 [==============================] - 5s 25ms/step - loss: 13.2192 - 4class_loss: 0.2853 - 7class_loss: 0.3641 - 19class_loss: 0.4674 - 4class_acc: 0.9706 - 7class_acc: 0.9641 - 19class_acc: 0.9602 - val_loss: 26.9374 - val_4class_loss: 0.4272 - val_7class_loss: 0.6777 - val_19class_loss: 0.9914 - val_4class_acc: 0.8896 - val_7class_acc: 0.8347 - val_19class_acc: 0.7860
# Epoch 181/1000
# 182/182 [==============================] - 5s 25ms/step - loss: 13.4788 - 4class_loss: 0.2892 - 7class_loss: 0.3708 - 19class_loss: 0.4769 - 4class_acc: 0.9662 - 7class_acc: 0.9602 - 19class_acc: 0.9559 - val_loss: 28.7879 - val_4class_loss: 0.4621 - val_7class_loss: 0.7367 - val_19class_loss: 1.0533 - val_4class_acc: 0.8813 - val_7class_acc: 0.8210 - val_19class_acc: 0.7682
# Epoch 182/1000
# 182/182 [==============================] - 5s 26ms/step - loss: 13.4453 - 4class_loss: 0.2832 - 7class_loss: 0.3696 - 19class_loss: 0.4766 - 4class_acc: 0.9688 - 7class_acc: 0.9607 - 19class_acc: 0.9569 - val_loss: 32.2612 - val_4class_loss: 0.4928 - val_7class_loss: 0.8310 - val_19class_loss: 1.1830 - val_4class_acc: 0.8505 - val_7class_acc: 0.7894 - val_19class_acc: 0.7209
# Epoch 183/1000
# 182/182 [==============================] - 5s 26ms/step - loss: 13.0834 - 4class_loss: 0.2819 - 7class_loss: 0.3590 - 19class_loss: 0.4631 - 4class_acc: 0.9696 - 7class_acc: 0.9667 - 19class_acc: 0.9617 - val_loss: 27.9664 - val_4class_loss: 0.4435 - val_7class_loss: 0.7087 - val_19class_loss: 1.0273 - val_4class_acc: 0.8882 - val_7class_acc: 0.8011 - val_19class_acc: 0.7634
# Epoch 184/1000
# 182/182 [==============================] - 5s 25ms/step - loss: 13.6019 - 4class_loss: 0.2911 - 7class_loss: 0.3711 - 19class_loss: 0.4824 - 4class_acc: 0.9651 - 7class_acc: 0.9612 - 19class_acc: 0.9548 - val_loss: 39.9447 - val_4class_loss: 0.5902 - val_7class_loss: 0.9772 - val_19class_loss: 1.4823 - val_4class_acc: 0.8416 - val_7class_acc: 0.7311 - val_19class_acc: 0.6708
# Epoch 185/1000
# 182/182 [==============================] - 5s 25ms/step - loss: 13.5069 - 4class_loss: 0.2904 - 7class_loss: 0.3670 - 19class_loss: 0.4794 - 4class_acc: 0.9646 - 7class_acc: 0.9600 - 19class_acc: 0.9566 - val_loss: 31.1596 - val_4class_loss: 0.4952 - val_7class_loss: 0.8093 - val_19class_loss: 1.1386 - val_4class_acc: 0.8745 - val_7class_acc: 0.7846 - val_19class_acc: 0.7380
# Epoch 186/1000
# 182/182 [==============================] - 5s 27ms/step - loss: 13.4113 - 4class_loss: 0.2942 - 7class_loss: 0.3698 - 19class_loss: 0.4733 - 4class_acc: 0.9655 - 7class_acc: 0.9605 - 19class_acc: 0.9581 - val_loss: 26.1861 - val_4class_loss: 0.4455 - val_7class_loss: 0.6553 - val_19class_loss: 0.9593 - val_4class_acc: 0.8964 - val_7class_acc: 0.8374 - val_19class_acc: 0.7984
# Epoch 187/1000
# 182/182 [==============================] - 5s 26ms/step - loss: 13.1434 - 4class_loss: 0.2847 - 7class_loss: 0.3616 - 19class_loss: 0.4647 - 4class_acc: 0.9698 - 7class_acc: 0.9660 - 19class_acc: 0.9636 - val_loss: 27.8711 - val_4class_loss: 0.4618 - val_7class_loss: 0.7161 - val_19class_loss: 1.0166 - val_4class_acc: 0.8875 - val_7class_acc: 0.8155 - val_19class_acc: 0.7737
# Epoch 188/1000
# 182/182 [==============================] - 5s 26ms/step - loss: 13.0477 - 4class_loss: 0.2852 - 7class_loss: 0.3576 - 19class_loss: 0.4614 - 4class_acc: 0.9694 - 7class_acc: 0.9641 - 19class_acc: 0.9602 - val_loss: 28.9008 - val_4class_loss: 0.4473 - val_7class_loss: 0.7529 - val_19class_loss: 1.0581 - val_4class_acc: 0.8964 - val_7class_acc: 0.8073 - val_19class_acc: 0.7723
# Epoch 189/1000
# 182/182 [==============================] - 5s 26ms/step - loss: 12.9975 - 4class_loss: 0.2795 - 7class_loss: 0.3581 - 19class_loss: 0.4596 - 4class_acc: 0.9737 - 7class_acc: 0.9665 - 19class_acc: 0.9617 - val_loss: 28.2769 - val_4class_loss: 0.4467 - val_7class_loss: 0.7041 - val_19class_loss: 1.0423 - val_4class_acc: 0.8992 - val_7class_acc: 0.8278 - val_19class_acc: 0.7984
# Epoch 190/1000
# 182/182 [==============================] - 5s 25ms/step - loss: 12.6798 - 4class_loss: 0.2782 - 7class_loss: 0.3493 - 19class_loss: 0.4476 - 4class_acc: 0.9741 - 7class_acc: 0.9730 - 19class_acc: 0.9700 - val_loss: 28.8822 - val_4class_loss: 0.4711 - val_7class_loss: 0.7544 - val_19class_loss: 1.0499 - val_4class_acc: 0.8916 - val_7class_acc: 0.8141 - val_19class_acc: 0.7778
# Epoch 191/1000
# 182/182 [==============================] - 5s 25ms/step - loss: 13.0289 - 4class_loss: 0.2829 - 7class_loss: 0.3595 - 19class_loss: 0.4602 - 4class_acc: 0.9724 - 7class_acc: 0.9657 - 19class_acc: 0.9610 - val_loss: 38.1181 - val_4class_loss: 0.5489 - val_7class_loss: 0.9282 - val_19class_loss: 1.4185 - val_4class_acc: 0.8519 - val_7class_acc: 0.7449 - val_19class_acc: 0.6900
# Epoch 192/1000
# 182/182 [==============================] - 5s 25ms/step - loss: 13.0026 - 4class_loss: 0.2839 - 7class_loss: 0.3538 - 19class_loss: 0.4607 - 4class_acc: 0.9713 - 7class_acc: 0.9708 - 19class_acc: 0.9645 - val_loss: 29.9962 - val_4class_loss: 0.4772 - val_7class_loss: 0.7741 - val_19class_loss: 1.0956 - val_4class_acc: 0.8916 - val_7class_acc: 0.8189 - val_19class_acc: 0.7743
# Epoch 193/1000
# 182/182 [==============================] - 5s 25ms/step - loss: 12.8622 - 4class_loss: 0.2841 - 7class_loss: 0.3502 - 19class_loss: 0.4552 - 4class_acc: 0.9689 - 7class_acc: 0.9722 - 19class_acc: 0.9672 - val_loss: 31.6436 - val_4class_loss: 0.5123 - val_7class_loss: 0.8123 - val_19class_loss: 1.1567 - val_4class_acc: 0.8738 - val_7class_acc: 0.7874 - val_19class_acc: 0.7215
# Epoch 194/1000
# 175/182 [===========================>..] - ETA: 0s - loss: 12.9317 - 4class_loss: 0.2753 - 7class_loss: 0.3552 - 19class_loss: 0.4581 - 4class_acc: 0.9754 - 7class_acc: 0.9650 - 19class_acc: 0.9639
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
import matplotlib.pyplot as plt   
plt.figure(figsize=(12,20))
start=5
for i in range(5):
    min_acc_index=history[i].history['val_4class_loss'].index(np.min(history[i].history['val_4class_loss']))
    print(str(i)+' val_4class_loss'+str(history[i].history['val_4class_loss'][min_acc_index])+'val_4class_acc'+str(history[i].history['val_4class_acc'][min_acc_index]))
for i in range(5):
    min_acc_index=history[i].history['val_4class_loss'].index(np.min(history[i].history['val_4class_loss']))
    length=len(history[i].history['4class_loss'][start:])
    plt.subplot(5,1,i+1)
    plt.plot(range(length),history[i].history['4class_loss'][start:],label='4class_loss')
    plt.plot(range(length),history[i].history['4class_acc'][start:],label='4class_acc')
    plt.plot(range(length),history[i].history['val_4class_loss'][start:],label='val_4class_loss')
    plt.plot(range(length),history[i].history['val_4class_acc'][start:],label='val_4class_acc')
    plt.title(str(i)+' val_4class_loss'+str(history[i].history['val_4class_loss'][min_acc_index])+'val_4class_acc'+str(history[i].history['val_4class_acc'][min_acc_index]))
    plt.legend(loc='best')
    
print(oof_score,np.mean(oof_score))
print(oof_comm,np.mean(oof_comm))
# Out:
# 0 val_4class_loss0.41935718val_4class_acc0.91569567
# 1 val_4class_loss0.41736606val_4class_acc0.92254966
# 2 val_4class_loss0.42381623val_4class_acc0.9190672
# 3 val_4class_loss0.4066517val_4class_acc0.91769546
# 4 val_4class_loss0.38151085val_4class_acc0.9197531
# [0.853, 0.841, 0.851, 0.838, 0.837] 0.844
# [0.872319592676, 0.8656940500669065, 0.8718400940623146, 0.8622378992749348, 0.8622052387484468] 0.8668593749657205

# %%
import matplotlib.pyplot as plt   
plt.figure(figsize=(12,20))
start=5
for i in range(5):
    min_acc_index=history[i].history['val_7class_loss'].index(np.min(history[i].history['val_7class_loss']))
    print(str(i)+' val_7class_loss'+str(history[i].history['val_7class_loss'][min_acc_index])+'val_7class_acc'+str(history[i].history['val_7class_acc'][min_acc_index]))
for i in range(5):
    min_acc_index=history[i].history['val_7class_loss'].index(np.min(history[i].history['val_7class_loss']))
    length=len(history[i].history['7class_loss'][start:])
    plt.subplot(5,1,i+1)
    plt.plot(range(length),history[i].history['7class_loss'][start:],label='7class_loss')
    plt.plot(range(length),history[i].history['7class_acc'][start:],label='7class_acc')
    plt.plot(range(length),history[i].history['val_7class_loss'][start:],label='val_7class_loss')
    plt.plot(range(length),history[i].history['val_7class_acc'][start:],label='val_7class_acc')
    plt.title(str(i)+' val_7class_loss'+str(history[i].history['val_7class_loss'][min_acc_index])+'val_7class_acc'+str(history[i].history['val_7class_acc'][min_acc_index]))
    plt.legend(loc='best')
    
print(oof_score,np.mean(oof_score))
print(oof_comm,np.mean(oof_comm))
# Out:
# 0 val_7class_loss0.617756val_7class_acc0.875257
# 1 val_7class_loss0.62221307val_7class_acc0.87320083
# 2 val_7class_loss0.60113806val_7class_acc0.87585735
# 3 val_7class_loss0.60123235val_7class_acc0.86899865
# 4 val_7class_loss0.59800154val_7class_acc0.8676269
# [0.853, 0.841, 0.851, 0.838, 0.837] 0.844
# [0.872319592676, 0.8656940500669065, 0.8718400940623146, 0.8622378992749348, 0.8622052387484468] 0.8668593749657205

# %%
import matplotlib.pyplot as plt   
plt.figure(figsize=(12,20))
start=5
for i in range(5):
    min_acc_index=history[i].history['val_19class_loss'].index(np.min(history[i].history['val_19class_loss']))
    print(str(i)+' val_19class_loss'+str(history[i].history['val_19class_loss'][min_acc_index])+'val_19class_acc'+str(history[i].history['val_19class_acc'][min_acc_index]))
for i in range(5):
    min_acc_index=history[i].history['val_19class_loss'].index(np.min(history[i].history['val_19class_loss']))
    length=len(history[i].history['19class_loss'][start:])
    plt.subplot(5,1,i+1)
    plt.plot(range(length),history[i].history['19class_loss'][start:],label='19class_loss')
    plt.plot(range(length),history[i].history['19class_acc'][start:],label='19class_acc')
    plt.plot(range(length),history[i].history['val_19class_loss'][start:],label='val_19class_loss')
    plt.plot(range(length),history[i].history['val_19class_acc'][start:],label='val_19class_acc')
    plt.title(str(i)+' val_19class_loss'+str(history[i].history['val_19class_loss'][min_acc_index])+'val_19class_acc'+str(history[i].history['val_19class_acc'][min_acc_index]))
    plt.legend(loc='best')
    
print(oof_score,np.mean(oof_score))
print(oof_comm,np.mean(oof_comm))
# Out:
# 0 val_19class_loss0.83380914val_19class_acc0.8450994
# 1 val_19class_loss0.85808325val_19class_acc0.84098697
# 2 val_19class_loss0.8317659val_19class_acc0.84910834
# 3 val_19class_loss0.8580642val_19class_acc0.83470505
# 4 val_19class_loss0.8499714val_19class_acc0.83744854
# [0.853, 0.841, 0.851, 0.838, 0.837] 0.844
# [0.872319592676, 0.8656940500669065, 0.8718400940623146, 0.8622378992749348, 0.8622052387484468] 0.8668593749657205

# %%
for index,i in enumerate(oof_comm):
    print(index,i,oof_score[index])

oof_dict = {
    "oof":proba_oof,
    "test":proba_t,
    "acc":oof_comm,
}
import joblib 
joblib.dump(oof_dict,"0730_generator_one_sixth_orig_mixup_%.5f_dict.pkl"% np.mean(oof_comm))
# Out:
# 0 0.8759097881784637 0.855
# 1 0.8700349228107948 0.846
# 2 0.8704683519498317 0.848
# 3 0.8643934940231219 0.84
# 4 0.8303285648964647 0.802
# ['0729_generator_one_third_orig_mixup_0.86223_dict.pkl']

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score

def acc_combo(y, y_pred):
    # 数值ID与行为编码的对应关系
    mapping = {0: 'A_0', 1: 'A_1', 2: 'A_2', 3: 'A_3', 
        4: 'D_4', 5: 'A_5', 6: 'B_1',7: 'B_5', 
        8: 'B_2', 9: 'B_3', 10: 'B_0', 11: 'A_6', 
        12: 'C_1', 13: 'C_3', 14: 'C_0', 15: 'B_6', 
        16: 'C_2', 17: 'C_5', 18: 'C_6'}
    # 将行为ID转为编码
    code_y, code_y_pred = mapping[y], mapping[y_pred]
    if code_y == code_y_pred: #编码完全相同得分1.0
        return 1.0
    elif code_y.split("_")[0] == code_y_pred.split("_")[0]: #编码仅字母部分相同得分1.0/7
        return 1.0/7
    elif code_y.split("_")[1] == code_y_pred.split("_")[1]: #编码仅数字部分相同得分1.0/3
        return 1.0/3
    else:
        return 0.0

train_y = y
labels = np.argmax(proba_t, axis=1)
oof_y = np.argmax(proba_oof, axis=1)
print(round(accuracy_score(train_y, oof_y), 5))
scores = sum(acc_combo(y_true, y_pred) for y_true, y_pred in zip(train_y, oof_y)) / oof_y.shape[0]
print(round(scores, 5))
data_path = '../../../zp/jiaozibei/data/'
sub = pd.read_csv(data_path+'提交结果示例.csv')
sub['behavior_id'] = labels

vc = pd.Series(train_y).value_counts().sort_index()
sns.barplot(vc.index, vc.values)
plt.show()

vc = pd.Series(oof_y).value_counts().sort_index()
sns.barplot(vc.index, vc.values)
plt.show()

vc = sub['behavior_id'].value_counts().sort_index()
sns.barplot(vc.index, vc.values)
plt.show()
sub.to_csv('0729_generator_one_third_orig_mixup_%.5f.csv' % scores, index=False)
sub.info()
# Out:
# 0.83832
# 0.86223
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   fragment_id  7500 non-null   int64
#  1   behavior_id  7500 non-null   int64
# dtypes: int64(2)
# memory usage: 117.3 KB

# %%
# %matplotlib inline
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import numpy as np

def plot_confusion_matrix(cm,classes,title='Confusion Matrix'):

    plt.figure(figsize=(12, 9), dpi=100)
    np.set_printoptions(precision=2)
    
    sns.heatmap(cm,annot=True)
    plt.title(title)
    plt.xticks(ticks=range(19),labels=classes)
    plt.yticks(ticks=range(19),labels=classes)
    
    plt.ylabel('Actual label')
    plt.xlabel('Predict label')
    plt.show()
    
# classes表示不同类别的名称，比如这有6个类别
num2detail_mapping = {0: 'A_0', 1: 'A_1', 2: 'A_2', 3: 'A_3', 
        4: 'D_4', 5: 'A_5', 6: 'B_1',7: 'B_5', 
        8: 'B_2', 9: 'B_3', 10: 'B_0', 11: 'A_6', 
        12: 'C_1', 13: 'C_3', 14: 'C_0', 15: 'B_6', 
        16: 'C_2', 17: 'C_5', 18: 'C_6'}

classes = [num2detail_mapping[int(i)]for i in range(19)]
print(classes)
# 获取混淆矩阵
cm = confusion_matrix(train_y, oof_y,normalize='true')
cm = np.round(cm,2)
plot_confusion_matrix(cm,classes, title='confusion matrix')
# Out:
# ['A_0', 'A_1', 'A_2', 'A_3', 'D_4', 'A_5', 'B_1', 'B_5', 'B_2', 'B_3', 'B_0', 'A_6', 'C_1', 'C_3', 'C_0', 'B_6', 'C_2', 'C_5', 'C_6']

# %%
for i in range(19):
    sns.distplot(proba_test[i],label=num2detail_mapping[i])
plt.xlim([0,1])
plt.legend()
plt.show()

# %%
# Out:
# 1496

# %%
class0_distribution = list(filter(lambda x:x>0.8,proba_test[1]))
sum(sum(proba_test > 0.99))
# Out:
# 1496

# %%
proba_test = np.zeros((7500, 19))
best_fold = [6,10,14,13]
for fold in best_fold:
    model = Net()
    model.load_weights(f'fold{fold}.h5')
    proba_test += model.predict(test, verbose=0, batch_size=1024) / len(best_fold)
    
labels = np.argmax(proba_test, axis=1)
data_path = '../../data/'
sub = pd.read_csv(data_path+'提交结果示例.csv')
sub['behavior_id'] = labels
vc = sub['behavior_id'].value_counts().sort_index()
sns.barplot(vc.index, vc.values)
plt.show()

scores = np.mean(np.array(oof_comm)[best_fold])
print(scores)
sub.to_csv('nn%.5f.csv' % scores, index=False)

# %%
joblib.load('0721_conv2_2_net_dict.pkl')
# Out:
# {'oof': array([[3.18406701e-01, 2.36933485e-01, 1.29989944e-02, ...,
#          8.72732606e-03, 6.40281290e-03, 1.30743925e-02],
#         [1.07079066e-01, 3.62501025e-01, 2.19051819e-03, ...,
#          7.76054990e-03, 6.55048410e-04, 7.28931231e-03],
#         [1.49847195e-01, 2.80115899e-04, 2.89210235e-04, ...,
#          1.19885977e-03, 1.81183306e-04, 2.98684882e-03],
#         ...,
#         [1.10205892e-03, 5.34337130e-04, 7.54885492e-04, ...,
#          1.08488568e-03, 7.02964666e-04, 9.88503635e-01],
#         [1.02081185e-03, 2.95973528e-04, 1.18560542e-03, ...,
#          1.09350705e-03, 1.52534037e-03, 9.87515688e-01],
#         [8.57781339e-03, 1.38868792e-02, 6.18984364e-03, ...,
#          2.84842937e-03, 1.60700958e-02, 4.76815194e-01]]),
#  'test': array([[1.88265373e-03, 3.60564419e-03, 2.64962610e-03, ...,
#          8.61187167e-03, 1.02914133e-02, 1.80201526e-03],
#         [2.53818692e-04, 1.35248894e-03, 7.73188145e-04, ...,
#          9.13258300e-04, 5.26467717e-04, 6.73125087e-04],
#         [2.75521779e-03, 1.01167987e-01, 5.97173462e-03, ...,
#          8.15660664e-03, 1.65569765e-03, 6.93138249e-03],
#         ...,
#         [1.04418015e-02, 3.46966203e-04, 7.18481021e-04, ...,
#          2.77271878e-03, 1.03564035e-04, 3.95393576e-04],
#         [1.45256489e-03, 5.80887428e-04, 1.37690782e-03, ...,
#          2.61072243e-03, 1.41819289e-03, 1.18138443e-03],
#         [1.58706227e-01, 9.83442106e-02, 1.57500958e-02, ...,
#          9.81043407e-03, 1.67188372e-02, 2.21417620e-03]]),
#  'acc': [0.8526714318352413,
#   0.8317503834981544,
#   0.8365667254556124,
#   0.8568489124044661,
#   0.8554118492390078]}
